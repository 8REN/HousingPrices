# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Final Project Submission</a></span></li></ul></li><li><span><a href="#data-scrubbing-and-cleaning" data-toc-modified-id="data-scrubbing-and-cleaning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>data scrubbing and cleaning</a></span><ul class="toc-item"><li><span><a href="#import-modules-and-data" data-toc-modified-id="import-modules-and-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>import modules and data</a></span></li><li><span><a href="#functions" data-toc-modified-id="functions-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>functions</a></span></li><li><span><a href="#fill-in-missing-values-(NaN)-where-applicable" data-toc-modified-id="fill-in-missing-values-(NaN)-where-applicable-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>fill in missing values (NaN) where applicable</a></span><ul class="toc-item"><li><span><a href="#assess-whether-renovation-has-direct-impact-on-home-price" data-toc-modified-id="assess-whether-renovation-has-direct-impact-on-home-price-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>assess whether renovation has direct impact on home price</a></span></li></ul></li><li><span><a href="#convert-date-column-to-DateTime-format,-then-separate-date-to-month,-day,-year-columns-due-to-datetime-being-unusable-in-regression,-(drop-'data'-column-once-all-necessary-calculations-have-been-done)" data-toc-modified-id="convert-date-column-to-DateTime-format,-then-separate-date-to-month,-day,-year-columns-due-to-datetime-being-unusable-in-regression,-(drop-'data'-column-once-all-necessary-calculations-have-been-done)-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>convert date column to DateTime format, then separate date to month, day, year columns due to datetime being unusable in regression, (drop 'data' column once all necessary calculations have been done)</a></span></li><li><span><a href="#create-age-column-from-date-of-sale-and-year-built" data-toc-modified-id="create-age-column-from-date-of-sale-and-year-built-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>create age column from date of sale and year built</a></span></li><li><span><a href="#find-out-if-there-are-historic-homes-on-dataset.-washington-state-qualifies-as-over-50-and-retaining-original-structure.-assess-whether-these-are-abnormalities" data-toc-modified-id="find-out-if-there-are-historic-homes-on-dataset.-washington-state-qualifies-as-over-50-and-retaining-original-structure.-assess-whether-these-are-abnormalities-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>find out if there are historic homes on dataset. washington state qualifies as over 50 and retaining original structure. assess whether these are abnormalities</a></span><ul class="toc-item"><li><span><a href="#remove-1-million-and-up-price-homes,-as-these-are-outliers-and-1/3-could-qualify-as-historic.-these-are-abnormalities-and-would-possibly-require-a-different-model-to-assess-properly" data-toc-modified-id="remove-1-million-and-up-price-homes,-as-these-are-outliers-and-1/3-could-qualify-as-historic.-these-are-abnormalities-and-would-possibly-require-a-different-model-to-assess-properly-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>remove 1 million and up price homes, as these are outliers and 1/3 could qualify as historic. these are abnormalities and would possibly require a different model to assess properly</a></span></li><li><span><a href="#drop-columns-not-to-be-utilized" data-toc-modified-id="drop-columns-not-to-be-utilized-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>drop columns not to be utilized</a></span></li></ul></li><li><span><a href="#sqft_basement-column-contains-string-characters,-remove-these-and-convert-to-int-to-match-other-similar-columns" data-toc-modified-id="sqft_basement-column-contains-string-characters,-remove-these-and-convert-to-int-to-match-other-similar-columns-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>sqft_basement column contains string characters, remove these and convert to int to match other similar columns</a></span></li><li><span><a href="#convert-sq_ft-areas-to-square-meters" data-toc-modified-id="convert-sq_ft-areas-to-square-meters-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>convert sq_ft areas to square meters</a></span></li><li><span><a href="#bedrooms-outlier-present-as-33-bedroom-house,-appears-to-be-typo-due-to-other-info,-should-be-3-bedrooms-as-this-listing-only-has-1.75-bathrooms" data-toc-modified-id="bedrooms-outlier-present-as-33-bedroom-house,-appears-to-be-typo-due-to-other-info,-should-be-3-bedrooms-as-this-listing-only-has-1.75-bathrooms-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>bedrooms outlier present as 33 bedroom house, appears to be typo due to other info, should be 3 bedrooms as this listing only has 1.75 bathrooms</a></span></li><li><span><a href="#assessing-grade-category" data-toc-modified-id="assessing-grade-category-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>assessing grade category</a></span></li><li><span><a href="#assess-for-duplicates" data-toc-modified-id="assess-for-duplicates-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>assess for duplicates</a></span></li><li><span><a href="#evaluate-duplicate-ids" data-toc-modified-id="evaluate-duplicate-ids-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>evaluate duplicate ids</a></span></li><li><span><a href="#use-latitude-and-longitude-in-existing-dataset-to-get-the-distance-from-home-to-Seattle(closest-major-city)" data-toc-modified-id="use-latitude-and-longitude-in-existing-dataset-to-get-the-distance-from-home-to-Seattle(closest-major-city)-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>use latitude and longitude in existing dataset to get the distance from home to Seattle(closest major city)</a></span><ul class="toc-item"><li><span><a href="#import-geopy-modules" data-toc-modified-id="import-geopy-modules-1.13.1"><span class="toc-item-num">1.13.1&nbsp;&nbsp;</span>import geopy modules</a></span></li><li><span><a href="#use-geopy-to-set-up-points-and-calculate-distance" data-toc-modified-id="use-geopy-to-set-up-points-and-calculate-distance-1.13.2"><span class="toc-item-num">1.13.2&nbsp;&nbsp;</span>use geopy to set up points and calculate distance</a></span></li><li><span><a href="#dropping-columns" data-toc-modified-id="dropping-columns-1.13.3"><span class="toc-item-num">1.13.3&nbsp;&nbsp;</span>dropping columns</a></span></li></ul></li></ul></li><li><span><a href="#dropping-all-sqft-columns-due-to-conversion-to-metric-system" data-toc-modified-id="dropping-all-sqft-columns-due-to-conversion-to-metric-system-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>dropping all sqft columns due to conversion to metric system</a></span><ul class="toc-item"><li><span><a href="#create-id-dataframe-to-attach-once-model-is-complete.-remove-id-from-dataset-as-it-isn't-relevant-but-just-identifies-homes" data-toc-modified-id="create-id-dataframe-to-attach-once-model-is-complete.-remove-id-from-dataset-as-it-isn't-relevant-but-just-identifies-homes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>create id dataframe to attach once model is complete. remove id from dataset as it isn't relevant but just identifies homes</a></span></li></ul></li><li><span><a href="#check-for-multicollinearity" data-toc-modified-id="check-for-multicollinearity-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>check for multicollinearity</a></span><ul class="toc-item"><li><span><a href="#heatmap-for-correlation-assessment" data-toc-modified-id="heatmap-for-correlation-assessment-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>heatmap for correlation assessment</a></span></li><li><span><a href="#create-new-dataframe-to-further-assess-correlation" data-toc-modified-id="create-new-dataframe-to-further-assess-correlation-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>create new dataframe to further assess correlation</a></span></li><li><span><a href="#scatter-matrix-to-further-assess-multicollinearity" data-toc-modified-id="scatter-matrix-to-further-assess-multicollinearity-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>scatter matrix to further assess multicollinearity</a></span><ul class="toc-item"><li><span><a href="#assess-for-outliers" data-toc-modified-id="assess-for-outliers-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>assess for outliers</a></span></li></ul></li></ul></li><li><span><a href="#data-exploration" data-toc-modified-id="data-exploration-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>data exploration</a></span><ul class="toc-item"><li><span><a href="#histograms" data-toc-modified-id="histograms-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>histograms</a></span></li><li><span><a href="#pairplot" data-toc-modified-id="pairplot-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>pairplot</a></span></li><li><span><a href="#kde" data-toc-modified-id="kde-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>kde</a></span></li><li><span><a href="#check-price-skew,-visualize-tranformed-data,-normalize-price-using-log-transformation" data-toc-modified-id="check-price-skew,-visualize-tranformed-data,-normalize-price-using-log-transformation-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>check price skew, visualize tranformed data, normalize price using log transformation</a></span></li><li><span><a href="#regression-plots" data-toc-modified-id="regression-plots-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>regression plots</a></span></li><li><span><a href="#age/price-scatter" data-toc-modified-id="age/price-scatter-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>age/price scatter</a></span></li><li><span><a href="#distance-to-seattle/price-scatter" data-toc-modified-id="distance-to-seattle/price-scatter-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>distance to seattle/price scatter</a></span></li><li><span><a href="#visualize-categorical-variables-by-price" data-toc-modified-id="visualize-categorical-variables-by-price-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>visualize categorical variables by price</a></span></li></ul></li><li><span><a href="#one-hot-encoding,-create-new-df:-dummies" data-toc-modified-id="one-hot-encoding,-create-new-df:-dummies-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>one hot encoding, create new df: dummies</a></span><ul class="toc-item"><li><span><a href="#create-dummy-df" data-toc-modified-id="create-dummy-df-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>create dummy df</a></span></li></ul></li><li><span><a href="#models" data-toc-modified-id="models-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>models</a></span><ul class="toc-item"><li><span><a href="#import-libraries" data-toc-modified-id="import-libraries-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>import libraries</a></span><ul class="toc-item"><li><span><a href="#no-dummies-dataframe" data-toc-modified-id="no-dummies-dataframe-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>no dummies dataframe</a></span></li><li><span><a href="#df-with-dummies" data-toc-modified-id="df-with-dummies-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>df with dummies</a></span></li></ul></li></ul></li><li><span><a href="#dataset-without-dummies" data-toc-modified-id="dataset-without-dummies-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>dataset without dummies</a></span><ul class="toc-item"><li><span><a href="#build-model-with-df" data-toc-modified-id="build-model-with-df-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>build model with df</a></span></li><li><span><a href="#regression-on-datasets-with-dummies" data-toc-modified-id="regression-on-datasets-with-dummies-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>regression on datasets with dummies</a></span><ul class="toc-item"><li><span><a href="#with-minmax-scaling-applied-to-dataset,-log-transformed-price" data-toc-modified-id="with-minmax-scaling-applied-to-dataset,-log-transformed-price-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>with minmax scaling applied to dataset, log transformed price</a></span></li><li><span><a href="#with-minmax-scaling-applied-to-continuous,-log-transformed-price" data-toc-modified-id="with-minmax-scaling-applied-to-continuous,-log-transformed-price-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>with minmax scaling applied to continuous, log transformed price</a></span></li><li><span><a href="#no-scaling-applied-to-continuous,-log-transformed-price" data-toc-modified-id="no-scaling-applied-to-continuous,-log-transformed-price-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>no scaling applied to continuous, log transformed price</a></span></li><li><span><a href="#no-scaling-to-variables-or-price" data-toc-modified-id="no-scaling-to-variables-or-price-7.2.4"><span class="toc-item-num">7.2.4&nbsp;&nbsp;</span>no scaling to variables or price</a></span></li></ul></li><li><span><a href="#using-model-2,-log-transformed-price" data-toc-modified-id="using-model-2,-log-transformed-price-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>using model 2, log transformed price</a></span></li><li><span><a href="#train/test-split-data" data-toc-modified-id="train/test-split-data-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>train/test split data</a></span><ul class="toc-item"><li><span><a href="#visualize-training-data-vs-test-data" data-toc-modified-id="visualize-training-data-vs-test-data-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>visualize training data vs test data</a></span></li></ul></li><li><span><a href="#perform-stepwise-selection-on-model-and-review-variable-significance" data-toc-modified-id="perform-stepwise-selection-on-model-and-review-variable-significance-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>perform stepwise selection on model and review variable significance</a></span></li><li><span><a href="#residuals" data-toc-modified-id="residuals-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>residuals</a></span></li></ul></li><li><span><a href="#rename-model-for-save" data-toc-modified-id="rename-model-for-save-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>rename model for save</a></span></li></ul></div>

# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Brennan Mathis
# * Student pace: part time
# * Scheduled project review date/time:
# * Instructor name: Victor G
# * Blog post URL:

# %% [markdown]
# # data scrubbing and cleaning

# %% [markdown]
# ## import modules and data

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm

# %%
data = pd.read_csv("kc_house_data.csv")

# %% [markdown]
# ## functions

# %%
# normalize values
def norm_feat(series):
    return (series - series.mean())/series.std()

# %%
#one hot encode return dummies
def one_hot(series):
    return (pd.get_dummies(series, prefix=series.name, drop_first=True))

# %%
# perform log transformation
def get_log(series):
    return np.log(series)

# %% [markdown]
# In metric terms a square foot is a square with sides 0.3048 metres in length.
# One square foot is the equivalent to 0.09290304 square metres

# %%
#In metric terms a square foot is a square with sides 0.3048 metres in length. 
#One square foot is the equivalent to 0.09290304 square metres
# convert sq feet to sq meters
def ft_to_meter(x):
    return x * 0.092903

# %%
# step wise selection to assess p values
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

# %% [markdown]
# ## fill in missing values (NaN) where applicable

# %%
data.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
#fill nan values
data.waterfront.unique()
# Out:
# array([nan,  0.,  1.])

# %%
data['waterfront'] = data.waterfront.fillna(0)

# %%
# convert to int
data['waterfront'] = data['waterfront'].astype(int)

# %%
#fill nan values
data.yr_renovated = data.yr_renovated.fillna(0)

# %% [markdown]
# ### assess whether renovation has direct impact on home price

# %%
data.yr_renovated = data.yr_renovated.astype(int)

# %%
# create dataframes for renovated and non renovated homes for comparison
renovated = data[data["yr_renovated"]>1]
non_renovated = data[data["yr_renovated"]<1]

# %%
non_renovated.shape
# Out:
# (20853, 21)

# %%
non_renovated.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.085300e+04  2.085300e+04  20853.000000  20853.000000  20853.000000
# mean   4.586246e+09  5.321403e+05      3.370115      2.109037   2071.507313
# std    2.875507e+09  3.518947e+05      0.920686      0.763118    910.209733
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.125059e+09  3.200000e+05      3.000000      1.500000   1420.000000
# 50%    3.904931e+09  4.490000e+05      3.000000      2.250000   1900.000000
# 75%    7.326200e+09  6.350000e+05      4.000000      2.500000   2540.000000
# max    9.900000e+09  6.890000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.085300e+04  20853.000000  20853.000000  20791.000000  20853.000000
# mean   1.505959e+04      1.493718      0.005611      0.220769      3.416631
# std    4.152180e+04      0.541274      0.074696      0.741496      0.653691
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.050000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.620000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.062600e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above      yr_built  yr_renovated       zipcode  \
# count  20853.000000  20853.000000  20853.000000       20853.0  20853.000000
# mean       7.654534   1785.381432   1972.125114           0.0  98077.321345
# std        1.172231    826.815098     28.974784           0.0     53.357658
# min        3.000000    370.000000   1900.000000           0.0  98001.000000
# 25%        7.000000   1190.000000   1953.000000           0.0  98032.000000
# 50%        7.000000   1560.000000   1976.000000           0.0  98065.000000
# 75%        8.000000   2210.000000   1998.000000           0.0  98117.000000
# max       13.000000   9410.000000   2015.000000           0.0  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  20853.000000  20853.000000   20853.000000   20853.000000
# mean      47.559363   -122.212268    1986.539778   12735.717499
# std        0.139088      0.140805     684.145745   27311.862519
# min       47.155900   -122.519000     399.000000     651.000000
# 25%       47.468600   -122.327000    1490.000000    5100.000000
# 50%       47.570600   -122.227000    1840.000000    7622.000000
# 75%       47.678300   -122.123000    2360.000000   10061.000000
# max       47.777600   -121.315000    6210.000000  871200.000000

# %%
renovated.shape
# Out:
# (744, 21)

# %%
renovated.describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  7.440000e+02  7.440000e+02  744.000000  744.000000    744.000000
# mean   4.418716e+09  7.689019e+05    3.459677    2.306116   2327.377688
# std    2.908265e+09  6.271258e+05    1.068823    0.898233   1089.002040
# min    3.600057e+06  1.100000e+05    1.000000    0.750000    520.000000
# 25%    1.922985e+09  4.122500e+05    3.000000    1.750000   1560.000000
# 50%    3.899100e+09  6.075020e+05    3.000000    2.250000   2200.000000
# 75%    7.014200e+09  9.000000e+05    4.000000    2.750000   2872.500000
# max    9.829200e+09  7.700000e+06   11.000000    8.000000  12050.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     744.000000  744.000000  744.000000  743.000000  744.000000
# mean    16215.530914    1.504704    0.038978    0.600269    3.219086
# std     38235.308760    0.493202    0.193674    1.212180    0.520494
# min      1024.000000    1.000000    0.000000    0.000000    1.000000
# 25%      5000.000000    1.000000    0.000000    0.000000    3.000000
# 50%      7375.000000    1.500000    0.000000    0.000000    3.000000
# 75%     12670.750000    2.000000    0.000000    0.000000    3.000000
# max    478288.000000    3.000000    1.000000    4.000000    5.000000
#
#             grade   sqft_above     yr_built  yr_renovated       zipcode  \
# count  744.000000   744.000000   744.000000    744.000000    744.000000
# mean     7.752688  1878.719086  1939.455645   1995.928763  98095.623656
# std      1.196954   849.441413    22.088850     15.599946     54.861316
# min      4.000000   520.000000  1900.000000   1934.000000  98001.000000
# 25%      7.000000  1267.500000  1921.000000   1987.000000  98040.000000
# 50%      8.000000  1730.000000  1941.500000   2000.000000  98112.000000
# 75%      8.000000  2300.000000  1955.000000   2007.250000  98126.000000
# max     13.000000  8570.000000  2003.000000   2015.000000  98199.000000
#
#               lat        long  sqft_living15     sqft_lot15
# count  744.000000  744.000000     744.000000     744.000000
# mean    47.580564 -122.262043    1988.877688   13390.768817
# std      0.120855    0.129586     715.440144   26213.648057
# min     47.196000 -122.497000     828.000000    1281.000000
# 25%     47.523350 -122.358000    1460.000000    5000.000000
# 50%     47.602800 -122.292000    1850.000000    7455.000000
# 75%     47.670950 -122.210000    2380.000000   10925.750000
# max     47.777000 -121.359000    5500.000000  310582.000000

# %%
# price mean
renovated.price.mean()
# Out:
# 768901.8924731183

# %%
# grade mean
renovated.grade.mean()
# Out:
# 7.752688172043011

# %%
# price standard deviation
renovated.price.std()
# Out:
# 627125.7940449169

# %%
# price mean
non_renovated.price.mean()
# Out:
# 532140.319858054

# %%
# grade mean
non_renovated.grade.mean()
# Out:
# 7.654534119790918

# %%
# price std
non_renovated.price.std()
# Out:
# 351894.7303060593

# %%
# assess the number of non renovated homes over grade 7 (renovated homes grade mean)
non_renovated_grade = non_renovated[non_renovated["grade"]>7]
non_renovated_grade.shape
# Out:
# (9925, 21)

# %%
# assess the number of non renovated homes over grade 7 (renovated homes grade mean)
non_renovated_grade = non_renovated[non_renovated["grade"]>7]
non_renovated_grade.shape
# Out:
# (9925, 21)

# %%
len(non_renovated_grade)/len(non_renovated)
# Out:
# 0.47595070253680527

# %%
len(non_renovated)/len(data)
# Out:
# 0.9655507709404084

# %%
len(renovated)/len(data)
# Out:
# 0.03444922905959161

# %%
# price mean
non_renovated_grade.price.mean()
# Out:
# 701337.1032745591

# %% [markdown]
# i will be dropping the year renovated column due to the fact that many non renovated properties with same grade from king county housing deparment sell for similiar price

# %% [markdown]
# ## convert date column to DateTime format, then separate date to month, day, year columns due to datetime being unusable in regression, (drop 'data' column once all necessary calculations have been done)

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data['date']= pd.to_datetime(data['date'])

# %%
data['sale_year'] = data.date.dt.year

# %% [markdown]
# ## create age column from date of sale and year built

# %%
# subtract the year built from sale year to get age of home when sold
data['age'] = data['sale_year'] - (data['yr_built'] - 1)

# %% [markdown]
# ## find out if there are historic homes on dataset. washington state qualifies as over 50 and retaining original structure. assess whether these are abnormalities

# %%
ren_historic_df = data[(data.age > 50) & (data.yr_renovated > 1)]
ren_historic_df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570
# 35     9547205180 2014-06-13   696000.0         3       2.50         2300
# 95     1483300570 2014-09-08   905000.0         4       2.50         3300
# 103    2450000295 2014-10-07  1090000.0         3       2.50         2920
# 125    4389200955 2015-03-02  1450000.0         4       2.75         2750
# ...           ...        ...        ...       ...        ...          ...
# 19472  8075400530 2014-06-27   234000.0         4       1.00         1390
# 19497  6821101285 2014-08-14   819000.0         3       1.75         1850
# 19524   923000115 2014-10-29   588000.0         3       1.75         2310
# 19602  6392000625 2014-07-12   451000.0         2       1.00          900
# 20428  4305600360 2015-02-25   500012.0         4       2.50         2400
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 1          7242     2.0           0   0.0  ...          400.0      1951
# 35         3060     1.5           0   0.0  ...          790.0      1930
# 95        10250     1.0           0   0.0  ...          910.0      1946
# 103        8113     2.0           0   0.0  ...            0.0      1950
# 125       17789     1.5           0   0.0  ...          770.0      1914
# ...         ...     ...         ...   ...  ...            ...       ...
# 19472     18000     1.0           0   0.0  ...            0.0      1955
# 19497      6000     1.5           0   0.0  ...          200.0      1913
# 19524      7620     2.0           0   0.0  ...            0.0      1942
# 19602      6000     1.0           0   0.0  ...            0.0      1944
# 20428      9612     1.0           0   0.0  ...         1170.0      1962
#
#        yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15  \
# 1              1991   98125  47.7210 -122.319           1690        7639
# 35             2002   98115  47.6827 -122.310           1590        3264
# 95             1991   98040  47.5873 -122.249           1950        6045
# 103            2010   98004  47.5814 -122.196           2370        8113
# 125            1992   98004  47.6141 -122.212           3060       11275
# ...             ...     ...      ...      ...            ...         ...
# 19472          2013   98032  47.3885 -122.284           1390       18000
# 19497          1999   98199  47.6528 -122.401           1540        6000
# 19524          1988   98177  47.7266 -122.363           2200        7672
# 19602          2004   98115  47.6855 -122.289           1460        4800
# 20428          2009   98059  47.4799 -122.127           2430        5539
#
#        sale_year  age
# 1           2014   64
# 35          2014   85
# 95          2014   69
# 103         2014   65
# 125         2015  102
# ...          ...  ...
# 19472       2014   60
# 19497       2014  102
# 19524       2014   73
# 19602       2014   71
# 20428       2015   54
#
# [642 rows x 23 columns]

# %%
ren_historic_df.describe()
# Out:
#                  id         price    bedrooms   bathrooms  sqft_living  \
# count  6.420000e+02  6.420000e+02  642.000000  642.000000    642.00000
# mean   4.420703e+09  7.567015e+05    3.439252    2.266745   2284.76947
# std    2.903391e+09  6.206395e+05    1.094684    0.888923   1049.53633
# min    3.600057e+06  1.340000e+05    1.000000    0.750000    520.00000
# 25%    1.912710e+09  4.117500e+05    3.000000    1.750000   1540.00000
# 50%    3.980950e+09  6.084520e+05    3.000000    2.000000   2180.00000
# 75%    7.012701e+09  8.931250e+05    4.000000    2.750000   2802.25000
# max    9.828702e+09  7.700000e+06   11.000000    8.000000  12050.00000
#
#             sqft_lot      floors  waterfront        view   condition  ...  \
# count     642.000000  642.000000  642.000000  641.000000  642.000000  ...
# mean    15300.685358    1.500000    0.034268    0.597504    3.239875  ...
# std     38856.642185    0.484551    0.182058    1.202962    0.540207  ...
# min      1033.000000    1.000000    0.000000    0.000000    1.000000  ...
# 25%      4803.750000    1.000000    0.000000    0.000000    3.000000  ...
# 50%      7082.500000    1.500000    0.000000    0.000000    3.000000  ...
# 75%     11622.000000    2.000000    0.000000    0.000000    3.000000  ...
# max    478288.000000    3.000000    1.000000    4.000000    5.000000  ...
#
#         sqft_above     yr_built  yr_renovated       zipcode         lat  \
# count   642.000000   642.000000    642.000000    642.000000  642.000000
# mean   1824.161994  1933.904984   1994.738318  98099.755452   47.587178
# std     820.784142    18.187668     16.174942     53.636650    0.117805
# min     520.000000  1900.000000   1934.000000  98001.000000   47.196000
# 25%    1240.000000  1918.250000   1985.000000  98052.000000   47.529475
# 50%    1695.000000  1936.500000   1998.000000  98115.000000   47.609950
# 75%    2240.000000  1950.000000   2007.000000  98133.000000   47.673925
# max    8570.000000  1965.000000   2015.000000  98199.000000   47.776300
#
#              long  sqft_living15     sqft_lot15    sale_year         age
# count  642.000000     642.000000     642.000000   642.000000  642.000000
# mean  -122.275407    1951.761682   12584.098131  2014.274143   81.369159
# std      0.121197     694.879391   25877.346653     0.446429   18.188796
# min   -122.497000     830.000000    1281.000000  2014.000000   51.000000
# 25%   -122.361000    1440.000000    5000.000000  2014.000000   65.000000
# 50%   -122.302500    1810.000000    7000.000000  2014.000000   79.000000
# 75%   -122.221000    2340.000000   10264.750000  2015.000000   97.000000
# max   -121.359000    5500.000000  310582.000000  2015.000000  116.000000
#
# [8 rows x 21 columns]

# %%
ren_historic_df.price.mean()
# Out:
# 756701.5327102804

# %%
non_ren_historic_df =  data[(data.age > 50) & (data.yr_renovated < 1)]
non_ren_historic_df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3        1.0         1180
# 2      5631500400 2015-02-25  180000.0         2        1.0          770
# 7      2008000270 2015-01-15  291850.0         3        1.5         1060
# 8      2414600126 2015-04-15  229500.0         3        1.0         1780
# 10     1736800520 2015-04-03  662500.0         3        2.5         3560
# ...           ...        ...       ...       ...        ...          ...
# 21287   522059130 2015-04-29  465000.0         3        1.0         1150
# 21316  9266700190 2015-05-11  245000.0         1        1.0          390
# 21327  2924079034 2014-09-25  332220.0         3        1.5         2580
# 21454   121039156 2015-01-09  249000.0         3        1.0         1030
# 21567  2025049203 2014-06-10  399950.0         2        1.0          710
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0          5650     1.0           0   0.0  ...            0.0      1955
# 2         10000     1.0           0   0.0  ...            0.0      1933
# 7          9711     1.0           0   NaN  ...            0.0      1963
# 8          7470     1.0           0   0.0  ...          730.0      1960
# 10         9796     1.0           0   0.0  ...         1700.0      1965
# ...         ...     ...         ...   ...  ...            ...       ...
# 21287     18200     1.0           0   0.0  ...            0.0      1959
# 21316      2000     1.0           0   0.0  ...            0.0      1920
# 21327     47480     1.0           0   0.0  ...         1220.0      1953
# 21454     24750     1.0           0   2.0  ...            0.0      1943
# 21567      1157     2.0           0   0.0  ...            0.0      1943
#
#        yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0                 0   98178  47.5112 -122.257           1340        5650
# 2                 0   98028  47.7379 -122.233           2720        8062
# 7                 0   98198  47.4095 -122.315           1650        9711
# 8                 0   98146  47.5123 -122.337           1780        8113
# 10                0   98007  47.6007 -122.145           2210        8925
# ...             ...     ...      ...      ...            ...         ...
# 21287             0   98058  47.4262 -122.187           1714       18200
# 21316             0   98103  47.6938 -122.347           1340        5100
# 21327             0   98024  47.5333 -121.933           1760       48181
# 21454             0   98023  47.3343 -122.362           2810       28800
# 21567             0   98102  47.6413 -122.329           1370        1173
#
#        sale_year  age
# 0           2014   60
# 2           2015   83
# 7           2015   53
# 8           2015   56
# 10          2015   51
# ...          ...  ...
# 21287       2015   57
# 21316       2015   96
# 21327       2014   62
# 21454       2015   73
# 21567       2014   72
#
# [8015 rows x 23 columns]

# %%
non_ren_historic_df.describe()
# Out:
#                  id         price     bedrooms    bathrooms  sqft_living  \
# count  8.015000e+03  8.015000e+03  8015.000000  8015.000000  8015.000000
# mean   4.469057e+09  4.966354e+05     3.174298     1.618590  1696.627199
# std    2.816738e+09  3.166074e+05     1.044523     0.654423   724.842751
# min    1.200019e+06  7.800000e+04     1.000000     0.500000   370.000000
# 25%    2.061450e+09  2.950000e+05     3.000000     1.000000  1170.000000
# 50%    3.935900e+09  4.250000e+05     3.000000     1.500000  1570.000000
# 75%    7.132801e+09  6.000000e+05     4.000000     2.000000  2080.000000
# max    9.900000e+09  3.650000e+06    33.000000     6.750000  7710.000000
#
#            sqft_lot       floors   waterfront         view    condition  ...  \
# count  8.015000e+03  8015.000000  8015.000000  7987.000000  8015.000000  ...
# mean   1.119232e+04     1.190643     0.007611     0.261800     3.657268  ...
# std    3.413447e+04     0.337750     0.086912     0.788216     0.763164  ...
# min    5.200000e+02     1.000000     0.000000     0.000000     1.000000  ...
# 25%    5.000000e+03     1.000000     0.000000     0.000000     3.000000  ...
# 50%    7.200000e+03     1.000000     0.000000     0.000000     4.000000  ...
# 75%    9.600000e+03     1.500000     0.000000     0.000000     4.000000  ...
# max    1.651359e+06     3.500000     1.000000     4.000000     5.000000  ...
#
#         sqft_above     yr_built  yr_renovated       zipcode          lat  \
# count  8015.000000  8015.000000        8015.0   8015.000000  8015.000000
# mean   1359.080349  1941.526263           0.0  98105.456893    47.586820
# std     517.504333    17.983807           0.0     53.911632     0.119622
# min     370.000000  1900.000000           0.0  98001.000000    47.155900
# 25%    1010.000000  1926.000000           0.0  98058.500000    47.509200
# 50%    1260.000000  1947.000000           0.0  98116.000000    47.600700
# 75%    1590.000000  1956.000000           0.0  98136.000000    47.682700
# max    6110.000000  1965.000000           0.0  98199.000000    47.777600
#
#               long  sqft_living15     sqft_lot15    sale_year          age
# count  8015.000000    8015.000000    8015.000000  8015.000000  8015.000000
# mean   -122.288600    1703.783157    9412.897817  2014.332002    73.805739
# std       0.098689     523.944732   17228.379012     0.470961    17.973924
# min    -122.514000     460.000000     660.000000  2014.000000    51.000000
# 25%    -122.355000    1340.000000    5000.000000  2014.000000    59.000000
# 50%    -122.308000    1600.000000    7200.000000  2014.000000    68.000000
# 75%    -122.255000    1950.000000    9146.500000  2015.000000    89.000000
# max    -121.315000    4950.000000  425581.000000  2015.000000   116.000000
#
# [8 rows x 21 columns]

# %%
non_ren_historic_df.price.mean()
# Out:
# 496635.38477854023

# %%
non_ren_historic_df.median()
# Out:
# id               3.935900e+09
# price            4.250000e+05
# bedrooms         3.000000e+00
# bathrooms        1.500000e+00
# sqft_living      1.570000e+03
# sqft_lot         7.200000e+03
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        4.000000e+00
# grade            7.000000e+00
# sqft_above       1.260000e+03
# yr_built         1.947000e+03
# yr_renovated     0.000000e+00
# zipcode          9.811600e+04
# lat              4.760070e+01
# long            -1.223080e+02
# sqft_living15    1.600000e+03
# sqft_lot15       7.200000e+03
# sale_year        2.014000e+03
# age              6.800000e+01
# dtype: float64

# %%
historic_df_mil =  data[(data.age > 100) & (data.price > 1000000)]
historic_df_mil
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 125    4389200955 2015-03-02  1450000.0         4       2.75         2750
# 282    7424700045 2015-05-13  2050000.0         5       3.00         3830
# 779    1954700695 2014-06-12  2250000.0         5       4.25         4860
# 1326   4232400860 2014-06-30  1200000.0         4       2.00         2120
# 1704   1336300445 2015-04-22  1270000.0         4       3.00         3130
# ...           ...        ...        ...       ...        ...          ...
# 18908   809002290 2014-05-19  1190000.0         4       3.00         2240
# 19118  7151700360 2014-12-11  1030000.0         5       3.25         2680
# 19257  1337300145 2014-07-21  1800000.0         4       2.50         3320
# 19261  2397100705 2014-07-14  1520000.0         4       4.25         3650
# 19510  7011201325 2014-10-28  1010000.0         4       2.75         2940
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 125       17789     1.5           0   0.0  ...          770.0      1914
# 282        8480     2.0           0   1.0  ...         1200.0      1905
# 779        9453     1.5           0   1.0  ...         1760.0      1905
# 1326       3360     2.0           0   0.0  ...            0.0      1905
# 1704       2646     2.5           0   0.0  ...          840.0      1906
# ...         ...     ...         ...   ...  ...            ...       ...
# 18908      6000     1.5           0   0.0  ...          970.0      1914
# 19118      3011     2.0           0   0.0  ...          810.0      1910
# 19257      8325     2.5           0   0.0  ...            0.0      1905
# 19261      5328     1.5           0   0.0  ...         1320.0      1907
# 19510      5400     1.5           0   2.0  ...         1000.0      1910
#
#        yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15  \
# 125            1992   98004  47.6141 -122.212           3060       11275
# 282            1994   98122  47.6166 -122.287           3050        7556
# 779               0   98112  47.6196 -122.286           3150        8557
# 1326              0   98112  47.6227 -122.310           2090        3600
# 1704              0   98102  47.6272 -122.316           2920        4500
# ...             ...     ...      ...      ...            ...         ...
# 18908             0   98109  47.6369 -122.350           2240        4250
# 19118             0   98122  47.6115 -122.287           3440        5165
# 19257             0   98112  47.6263 -122.314           3680        6050
# 19261          2014   98119  47.6380 -122.362           1710        3600
# 19510             0   98119  47.6366 -122.369           1970        2008
#
#        sale_year  age
# 125         2015  102
# 282         2015  111
# 779         2014  110
# 1326        2014  110
# 1704        2015  110
# ...          ...  ...
# 18908       2014  101
# 19118       2014  105
# 19257       2014  110
# 19261       2014  108
# 19510       2014  105
#
# [102 rows x 23 columns]

# %%
data_mil_df = data.loc[data['price'] > 1000000]
data_mil_df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 5      7237550310 2014-05-12  1230000.0         4       4.50         5420
# 21     2524049179 2014-08-26  2000000.0         3       2.75         3050
# 49      822039084 2015-03-11  1350000.0         3       2.50         2753
# 69     1802000060 2014-06-12  1330000.0         5       2.25         3200
# 70     1525059190 2014-09-12  1040000.0         5       3.25         4770
# ...           ...        ...        ...       ...        ...          ...
# 21574  7430200100 2014-05-14  1220000.0         4       3.50         4910
# 21577  8672200110 2015-03-17  1090000.0         5       3.75         4170
# 21581   191100405 2015-04-21  1580000.0         4       3.25         3410
# 21584   249000205 2014-10-15  1540000.0         5       3.75         4470
# 21590  7936000429 2015-03-26  1010000.0         4       3.50         3510
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 5        101930     1.0           0   0.0  ...         1530.0      2001
# 21        44867     1.0           0   4.0  ...          720.0      1968
# 49        65005     1.0           1   2.0  ...          588.0      1953
# 69        20158     1.0           0   0.0  ...         1600.0      1965
# 70        50094     1.0           0   0.0  ...         1700.0      1973
# ...         ...     ...         ...   ...  ...            ...       ...
# 21574      9444     1.5           0   0.0  ...         1800.0      2007
# 21577      8142     2.0           0   2.0  ...            0.0      2006
# 21581     10125     2.0           0   0.0  ...              ?      2007
# 21584      8088     2.0           0   0.0  ...            0.0      2008
# 21590      7200     2.0           0   0.0  ...          910.0      2009
#
#        yr_renovated zipcode      lat     long  sqft_living15  sqft_lot15  \
# 5                 0   98053  47.6561 -122.005           4760      101930
# 21                0   98040  47.5316 -122.233           4110       20336
# 49                0   98070  47.4041 -122.451           2680       72513
# 69                0   98004  47.6303 -122.215           3390       20158
# 70                0   98005  47.6525 -122.160           3530       38917
# ...             ...     ...      ...      ...            ...         ...
# 21574             0   98074  47.6502 -122.066           4560       11063
# 21577             0   98056  47.5354 -122.181           3030        7980
# 21581             0   98040  47.5653 -122.223           2290       10125
# 21584             0   98004  47.6321 -122.200           2780        8964
# 21590             0   98136  47.5537 -122.398           2050        6200
#
#        sale_year  age
# 5           2014   14
# 21          2014   47
# 49          2015   63
# 69          2014   50
# 70          2014   42
# ...          ...  ...
# 21574       2014    8
# 21577       2015   10
# 21581       2015    9
# 21584       2014    7
# 21590       2015    7
#
# [1458 rows x 23 columns]

# %%
len(historic_df_mil)/len(data_mil_df)
# Out:
# 0.06995884773662552

# %% [markdown]
# 1/3 of the properties with listed price over 1 million dollars qualifies as possible historic home

# %% [markdown]
# ### remove 1 million and up price homes, as these are outliers and 1/3 could qualify as historic. these are abnormalities and would possibly require a different model to assess properly

# %%
# set df to include only homes under 1 million dollars
#data = data[data.price < 999999]

# %% [markdown]
# ### drop columns not to be utilized

# %%
data.drop(['yr_renovated', 'waterfront', 'view'], axis=1, inplace=True)

# %% [markdown]
# ## sqft_basement column contains string characters, remove these and convert to int to match other similar columns

# %%
#convert to int format, coercing strings to 0
data['sqft_basement'] = pd.to_numeric(data['sqft_basement'], 
                        downcast= 'integer', errors ='coerce')

# %%
# replace missing values using data provided for homes without nan values
# sqft_basement + sqft_above = sqft_living
data['sqft_basement'] = data['sqft_basement'].fillna(data['sqft_living'] 
                             - data['sqft_above'])
data['sqft_basement'] = data['sqft_basement'].astype(int)

# %% [markdown]
# this column will probably be dropped due to direct correlation to sqft_living (and sqft_above )

# %% [markdown]
# ## convert sq_ft areas to square meters

# %%
# ft_to_meters 
data['sqm_living'] = ft_to_meter(data.sqft_living)
data['sqm_living15'] = ft_to_meter(data.sqft_living15)
data['sqm_lot'] = ft_to_meter(data.sqft_lot)
data['sqm_lot15'] = ft_to_meter(data.sqft_lot15)

# %% [markdown]
# omitting sqft_above and sqft_basement due to correlation with sqft_living, and will most likely be dropped

# %% [markdown]
# ##  bedrooms outlier present as 33 bedroom house, appears to be typo due to other info, should be 3 bedrooms as this listing only has 1.75 bathrooms

# %%
data['bedrooms'].describe()
# Out:
# count    21597.000000
# mean         3.373200
# std          0.926299
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %%
data.loc[data["bedrooms"] == 33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  condition  grade  ...      lat     long  \
# 15856      6000     1.0          5      7  ...  47.6878 -122.331
#
#        sqft_living15  sqft_lot15  sale_year  age  sqm_living  sqm_living15  \
# 15856           1330        4700       2014   68   150.50286     123.56099
#
#        sqm_lot  sqm_lot15
# 15856  557.418   436.6441
#
# [1 rows x 24 columns]

# %%
data["bedrooms"].replace({33: 3}, inplace=True)

# %%
data = data[data.bathrooms < 6]
data = data[data.bedrooms < 9]

# %%
data = data[data.bedrooms > .75]

# %%
data.shape
# Out:
# (21572, 24)

# %% [markdown]
# ## assessing grade category

# %% [markdown]
# * from king county website regarding grade category
#
# Represents the construction quality of improvements. Grades run from grade 1 to 13. Generally defined as:
#
# 1-3 Falls short of minimum building standards. Normally cabin or inferior structure.
#
# 4 Generally older, low quality construction. Does not meet code.
#
# 5 Low construction costs and workmanship. Small, simple design.
#
# 6 Lowest grade currently meeting building code. Low quality materials and simple designs.
#
# 7 Average grade of construction and design. Commonly seen in plats and older sub-divisions.
#
# 8 Just above average in construction and design. Usually better materials in both the exterior and interior finish work.
#
# 9 Better architectural design with extra interior and exterior design and quality.
#
# 10 Homes of this quality generally have high quality features. Finish work is better and more design quality is seen in the floor plans. Generally have a larger square footage.
#
# 11 Custom design and higher quality finish work with added amenities of solid woods, bathroom fixtures and more luxurious options.
#
# 12 Custom design and excellent builders. All materials are of the highest quality and all conveniences are present.
#
# 13 Generally custom designed and built. Mansion level. Large amount of highest quality cabinet work, wood trim, marble, entry ways etc.

# %%
#removing homes that do not meet code
data = data[data.grade > 6]

# %% [markdown]
# ## assess for duplicates

# %%
data.nunique()
# Out:
# id               19138
# date               368
# price             3348
# bedrooms             8
# bathrooms           22
# sqft_living        988
# sqft_lot          9270
# floors               6
# condition            5
# grade                7
# sqft_above         905
# sqft_basement      298
# yr_built           116
# zipcode             70
# lat               4915
# long               723
# sqft_living15      743
# sqft_lot15        8261
# sale_year            2
# age                117
# sqm_living         988
# sqm_living15       743
# sqm_lot           9270
# sqm_lot15         8261
# dtype: int64

# %% [markdown]
# ## evaluate duplicate ids

# %%
dups = data[data['id'].duplicated(keep=False)]

# %%
dups.head()
# Out:
#              id       date      price  bedrooms  bathrooms  sqft_living  \
# 93   6021501535 2014-07-25   430000.0         3       1.50         1580
# 94   6021501535 2014-12-23   700000.0         3       1.50         1580
# 313  4139480200 2014-06-18  1380000.0         4       3.25         4290
# 314  4139480200 2014-12-09  1400000.0         4       3.25         4290
# 371  2231500030 2014-10-01   315000.0         4       2.25         2180
#
#      sqft_lot  floors  condition  grade  ...      lat     long  sqft_living15  \
# 93       5000     1.0          3      8  ...  47.6870 -122.386           1570
# 94       5000     1.0          3      8  ...  47.6870 -122.386           1570
# 313     12103     1.0          3     11  ...  47.5503 -122.102           3860
# 314     12103     1.0          3     11  ...  47.5503 -122.102           3860
# 371     10754     1.0          5      7  ...  47.7711 -122.341           1810
#
#      sqft_lot15  sale_year  age  sqm_living  sqm_living15      sqm_lot  \
# 93         4500       2014   76   146.78674     145.85771   464.515000
# 94         4500       2014   76   146.78674     145.85771   464.515000
# 313       11244       2014   18   398.55387     358.60558  1124.405009
# 314       11244       2014   18   398.55387     358.60558  1124.405009
# 371        6929       2014   61   202.52854     168.15443   999.078862
#
#        sqm_lot15
# 93    418.063500
# 94    418.063500
# 313  1044.601332
# 314  1044.601332
# 371   643.724887
#
# [5 rows x 24 columns]

# %% [markdown]
# these occurences are from when the house was turned over and sold again, so I am keeping these rows

# %% [markdown]
# ## use latitude and longitude in existing dataset to get the distance from home to Seattle(closest major city)

# %% [markdown]
# ### import geopy modules

# %%
from geopy.distance import geodesic
from geopy import Point

# %%
#seattle coordinates
seattle_lat = 47.3635
seattle_long = -122.1959
seattle_point = Point(latitude=seattle_lat, longitude =seattle_long)

# %% [markdown]
# ### use geopy to set up points and calculate distance

# %%
#create points for each home using longitude and latitude
data['point'] = data.apply(lambda row: Point(latitude=row['lat'], 
                                             longitude=row['long']), axis=1)

# %%
# get distance in km from point to seattle
data['distance_seattle'] = data.apply(lambda row: 
                                      geodesic(row['point'], 
                                      seattle_point).m, axis=1)

# %%
# round distance to seattle values for simplicity
data['distance_seattle'] = data['distance_seattle'].round(2)

# %%
data.dtypes
# Out:
# id                           int64
# date                datetime64[ns]
# price                      float64
# bedrooms                     int64
# bathrooms                  float64
# sqft_living                  int64
# sqft_lot                     int64
# floors                     float64
# condition                    int64
# grade                        int64
# sqft_above                   int64
# sqft_basement                int64
# yr_built                     int64
# zipcode                      int64
# lat                        float64
# long                       float64
# sqft_living15                int64
# sqft_lot15                   int64
# sale_year                    int64
# age                          int64
# sqm_living                 float64
# sqm_living15               float64
# sqm_lot                    float64
# sqm_lot15                  float64
# point                       object
# distance_seattle           float64
# dtype: object

# %% [markdown]
# ### dropping columns

# %% [markdown]
# dropping point, lat and long columns, derived data needed from these for distance to seattle

# %%
data.drop(['point', 'lat', 'long'], axis=1, inplace=True)

# %% [markdown]
# drop date column due to derived data needed and this column will just cause issues. also dropping view column, as it just tells if the home has been viewed according to documentation. yr_built and sale_year used for age column and can be dropped as well. # drop condition due to the fact that it is contingent on perspective, whereas
# the 'grade' category is qualified by king county as an official rating
# regarding the home inspection and quality of materials

# %%
data.drop(['date', 'sale_year', 'yr_built', 'zipcode', 'condition'], axis=1, inplace=True)

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  1.926400e+04  1.926400e+04  19264.000000  19264.000000  19264.000000
# mean   4.604011e+09  5.673467e+05      3.454319      2.218023   2184.655004
# std    2.884299e+09  3.636449e+05      0.855609      0.719508    883.379577
# min    1.000102e+06  9.000000e+04      1.000000      0.500000    550.000000
# 25%    2.130350e+09  3.450000e+05      3.000000      1.750000   1540.000000
# 50%    3.905121e+09  4.800000e+05      3.000000      2.250000   2020.000000
# 75%    7.338220e+09  6.720000e+05      4.000000      2.500000   2640.000000
# max    9.895000e+09  7.060000e+06      8.000000      5.750000  10040.000000
#
#            sqft_lot        floors         grade    sqft_above  sqft_basement  \
# count  1.926400e+04  19264.000000  19264.000000  19264.000000   19264.000000
# mean   1.520821e+04      1.539971      7.868875   1873.114462     311.540542
# std    4.001943e+04      0.546766      1.041295    815.650427     451.131261
# min    5.200000e+02      1.000000      7.000000    550.000000       0.000000
# 25%    5.011750e+03      1.000000      7.000000   1270.000000       0.000000
# 50%    7.691500e+03      1.500000      8.000000   1650.000000       0.000000
# 75%    1.081900e+04      2.000000      8.000000   2310.000000     600.000000
# max    1.074218e+06      3.500000     13.000000   7880.000000    3500.000000
#
#        sqft_living15     sqft_lot15          age    sqm_living  sqm_living15  \
# count   19264.000000   19264.000000  19264.00000  19264.000000  19264.000000
# mean     2056.855118   12869.906198     40.79973    202.961004    191.088011
# std       677.969447   27300.346521     28.24392     82.068613     62.985396
# min       399.000000     651.000000      0.00000     51.096650     37.068297
# 25%      1550.000000    5080.000000     16.00000    143.070620    143.999650
# 50%      1920.000000    7678.000000     37.00000    187.664060    178.373760
# 75%      2430.000000   10160.000000     59.00000    245.263920    225.754290
# max      6210.000000  871200.000000    116.00000    932.746120    576.927630
#
#             sqm_lot     sqm_lot15  distance_seattle
# count  19264.000000  19264.000000      19264.000000
# mean    1412.888375   1195.652896      26447.948933
# std     3717.925079   2536.284093      12118.804325
# min       48.309560     60.479853        196.330000
# 25%      465.606610    471.947240      15703.437500
# 50%      714.563424    713.309234      27639.445000
# 75%     1005.117557    943.894480      36825.880000
# max    99798.074854  80937.093600      76612.170000

# %% [markdown]
# # dropping all sqft columns due to conversion to metric system
# #dropping correlating columns above and basement
# data.drop(['sqft_basement', 'sqft_lot15', 'sqft_above', 'sqft_living', 'sqft_lot',
#            'sqft_living15'], axis=1, inplace=True)

# %%
data.drop(['sqft_living', 'sqft_lot', 'sqft_living15','sqft_above', 'sqft_basement',
       'sqft_lot15', 'floors'], axis=1,inplace=True)

# %%
data.drop(['sqm_lot', 'sqm_lot15'], axis=1,inplace=True)

# %% [markdown]
# ## create id dataframe to attach once model is complete. remove id from dataset as it isn't relevant but just identifies homes

# %%
id_df = data['id']

# %%
data.drop(['id'], axis=1, inplace=True)

# %% [markdown]
# # check for multicollinearity

# %%
data.corr()
# Out:
#                      price  bedrooms  bathrooms     grade       age  \
# price             1.000000  0.279424   0.481059  0.670510  0.024270
# bedrooms          0.279424  1.000000   0.475443  0.278555 -0.073897
# bathrooms         0.481059  0.475443   1.000000  0.592959 -0.455353
# grade             0.670510  0.278555   0.592959  1.000000 -0.344771
# age               0.024270 -0.073897  -0.455353 -0.344771  1.000000
# sqm_living        0.682158  0.558017   0.713459  0.737464 -0.239201
# sqm_living15      0.566187  0.373662   0.525852  0.701062 -0.264619
# distance_seattle  0.260307 -0.061906  -0.015837  0.071214  0.153340
#
#                   sqm_living  sqm_living15  distance_seattle
# price               0.682158      0.566187          0.260307
# bedrooms            0.558017      0.373662         -0.061906
# bathrooms           0.713459      0.525852         -0.015837
# grade               0.737464      0.701062          0.071214
# age                -0.239201     -0.264619          0.153340
# sqm_living          1.000000      0.746312          0.015000
# sqm_living15        0.746312      1.000000          0.000259
# distance_seattle    0.015000      0.000259          1.000000

# %%
abs(data.corr()) > 0.75
# Out:
#                   price  bedrooms  bathrooms  grade    age  sqm_living  \
# price              True     False      False  False  False       False
# bedrooms          False      True      False  False  False       False
# bathrooms         False     False       True  False  False       False
# grade             False     False      False   True  False       False
# age               False     False      False  False   True       False
# sqm_living        False     False      False  False  False        True
# sqm_living15      False     False      False  False  False       False
# distance_seattle  False     False      False  False  False       False
#
#                   sqm_living15  distance_seattle
# price                    False             False
# bedrooms                 False             False
# bathrooms                False             False
# grade                    False             False
# age                      False             False
# sqm_living               False             False
# sqm_living15              True             False
# distance_seattle         False              True

# %% [markdown]
#  HIGHLY CORRELATED VARIABLES OVER 0.75:
#
#  sqft_living/bathrooms
#  sqft_above/sqft_living
#  bathrooms/sqft_living
#  bathrooms/sqft_above
#  sqft_living/sqft_living15
#  sqft_living/sqft_above
#  sqft_living15/sqft_above
#  sqft_lot/sqft_lot15
# Consider dropping redundant variables

# %% [markdown]
# ## heatmap for correlation assessment

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.heatmap(data.corr(), annot = True,  fmt='.2g', vmin=-1, vmax=1, center= 0, 
            cmap= 'coolwarm', linewidths=1, linecolor='black')

# %% [markdown]
# ## create new dataframe to further assess correlation

# %%
data_before = data.copy()
data_before.drop(['price'], axis=1, inplace=True)

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

X1 = sm.tools.add_constant(data_before)
                          
series_before = pd.Series([variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])], index = X1.columns)

print('data before')


display(series_before)
# Out:
# data before
# const               131.009800
# bedrooms              1.609893
# bathrooms             2.598771
# grade                 2.805213
# age                   1.424448
# sqm_living            4.526166
# sqm_living15          2.577448
# distance_seattle      1.055080
# dtype: float64

# %% [markdown]
# no columns over 5, no need to reassess

# %% [markdown]
# ## scatter matrix to further assess multicollinearity

# %%
#define plot
pd.plotting.scatter_matrix(data, alpha=1, figsize = (30, 20))
# show plot
plt.show()

# %% [markdown]
# ### assess for outliers

# %%
# get summary
desc_data = data.describe()

# add std metric
desc_data.loc['+3_std'] = desc_data.loc['mean']+(desc_data.loc['std']*3)
desc_data.loc['-3_std'] = desc_data.loc['mean']-(desc_data.loc['std']*3)
desc_data
# Out:
#                price      bedrooms     bathrooms         grade          age  \
# count   1.926400e+04  19264.000000  19264.000000  19264.000000  19264.00000
# mean    5.673467e+05      3.454319      2.218023      7.868875     40.79973
# std     3.636449e+05      0.855609      0.719508      1.041295     28.24392
# min     9.000000e+04      1.000000      0.500000      7.000000      0.00000
# 25%     3.450000e+05      3.000000      1.750000      7.000000     16.00000
# 50%     4.800000e+05      3.000000      2.250000      8.000000     37.00000
# 75%     6.720000e+05      4.000000      2.500000      8.000000     59.00000
# max     7.060000e+06      8.000000      5.750000     13.000000    116.00000
# +3_std  1.658281e+06      6.021146      4.376548     10.992759    125.53149
# -3_std -5.235881e+05      0.887492      0.059499      4.744990    -43.93203
#
#           sqm_living  sqm_living15  distance_seattle
# count   19264.000000  19264.000000      19264.000000
# mean      202.961004    191.088011      26447.948933
# std        82.068613     62.985396      12118.804325
# min        51.096650     37.068297        196.330000
# 25%       143.070620    143.999650      15703.437500
# 50%       187.664060    178.373760      27639.445000
# 75%       245.263920    225.754290      36825.880000
# max       932.746120    576.927630      76612.170000
# +3_std    449.166842    380.044198      62804.361909
# -3_std    -43.244835      2.131824      -9908.464042

# %% [markdown]
# keeping data as is due to variations seeming accurate and to remove would have negative impact

# %% [markdown]
# # data exploration

# %% [markdown]
# ## histograms

# %%
data.hist(figsize=(18, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c3eff3828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1efeb2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1f011be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c1f0b9d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1f0e8320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c1f10e8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c36f0ce80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c36f3d4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c36f3d4e0>]],
#       dtype=object)

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(data)

# %% [markdown]
# ## kde

# %%
data.sqm_living.plot.kde()
plt.show()

# %% [markdown]
# ## check price skew, visualize tranformed data, normalize price using log transformation

# %%
price_log = get_log(data.price)
price_log.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", price_log.skew())
plt.hist(price_log)
plt.show()
# Out:
# Skew is: 0.5248335806344964

# %%
data['price'].plot.kde()
plt.legend()
plt.show()
print ("Skew is:", data['price'].skew())
plt.hist(data['price'])
plt.show()
# Out:
# Skew is: 3.4789192761811734

# %% [markdown]
# to normalize price, square root is taken, it gives the most normal distribution, out of min/max, log, mean normalization and standard normalization

# %% [markdown]
# ## regression plots

# %%
ax = sns.regplot(x="sqm_living", y="price", data=data)

# %%
ax = sns.regplot(x="bathrooms", y="price", data=data)

# %%
ax = sns.regplot(x="bathrooms", y="price", data=data)

# %%
ax = sns.regplot(x="bedrooms", y="price", data=data)

# %%
ax = sns.regplot(x="distance_seattle", y="price", data=data)

# %% [markdown]
# ## age/price scatter

# %%
# define x & y
x = data['age']
y = data['price']
# create scatter plot
plt.figure(figsize=(10,6))
plt.plot(x, y, 'o', markersize= 2, label='House Sale Price')

# format
plt.title('Home Age x Price')
plt.xlabel('Age')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## distance to seattle/price scatter

# %%
x = data.distance_seattle
y = data.price
# create scatter plot
plt.figure(figsize=(10,6))
plt.plot(x, y, 'o', markersize= 2, label='House Sale Price')

# format
plt.title('Price X Distance(Seattle)')
plt.xlabel('Distance From Seattle (miles)')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
scale_seattle = (data.distance_seattle - np.mean(data.distance_seattle)) / np.sqrt(np.var(data.distance_seattle))
scale_seattle.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", scale_seattle.skew())
plt.hist(scale_seattle)
plt.show()
data['distance_seattle'] = scale_seattle
# Out:
# Skew is: -0.22249914774837917

# %%
data['distance_seattle'].plot.kde()
plt.legend()
plt.show()
print ("Skew is:", data['distance_seattle'].skew())
plt.hist(data['distance_seattle'])
plt.show()
# Out:
# Skew is: -0.22249914774837917

# %%
log_seattle = get_log(data.distance_seattle)
log_seattle.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", log_seattle.skew())
plt.hist(log_seattle)
plt.show()
# Out:
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Skew is: -2.172652703789728
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ## visualize categorical variables by price

# %%
data.dtypes
# Out:
# price               float64
# bedrooms              int64
# bathrooms           float64
# grade                 int64
# age                   int64
# sqm_living          float64
# sqm_living15        float64
# distance_seattle    float64
# dtype: object

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(50,20), sharey=True)

categoricals = ['bathrooms', 'grade', 'bedrooms', 'age', 'distance_seattle', ]

for col, ax in zip(categoricals, axes.flatten()):
    (data.groupby(col)               # group values together by column of interest
         .mean()['price']        # take the mean of the saleprice for each group
         .sort_values()              # sort the groups in ascending order
         .plot
         .bar(ax=ax))                # create a bar graph on the ax
    
    ax.set_title(col)                # Make the title the name of the column
    
fig.tight_layout()

# %%
for column in data:
    data[column].plot.hist(density=True, label = column+' histogram')
    data[column].plot.kde(label =column+' kde')
    plt.legend()
    plt.show()

# %%
sns.lmplot(x="sqm_living", y="price", hue="bedrooms", data=data);

# %% [markdown]
# # one hot encoding, create new df: dummies

# %%
data.head()
# Out:
#        price  bedrooms  bathrooms  grade  age  sqm_living  sqm_living15  \
# 0   221900.0         3       1.00      7   60   109.62554     124.49002
# 1   538000.0         3       2.25      7   64   238.76071     157.00607
# 3   604000.0         4       3.00      7   50   182.08988     126.34808
# 4   510000.0         3       2.00      8   29   156.07704     167.22540
# 5  1230000.0         4       4.50     11   14   503.53426     442.21828
#
#    distance_seattle
# 0         -0.775032
# 1          1.185417
# 3         -0.288360
# 4          0.323738
# 5          0.752585

# %%
data.dtypes
# Out:
# price               float64
# bedrooms              int64
# bathrooms           float64
# grade                 int64
# age                   int64
# sqm_living          float64
# sqm_living15        float64
# distance_seattle    float64
# dtype: object

# %%
#round age and bathroom for dummy conversion
round_df = pd.DataFrame()
round_df['age'] = data['age'].round(-1)
# round_df['age'] = data['age'].astype(int)
round_df['bathrooms'] = data['bathrooms'].round()
round_df['bathrooms'] = data['bathrooms'].astype(int)

# %%
# create bedroom dummies
dumbed = pd.get_dummies(data['bedrooms'], prefix= 'bed', drop_first=True)

# create bedroom dummies
age_dummy = pd.get_dummies(round_df['age'], prefix= 'home_age', drop_first=True)

#create grade dummies
dumgrade = pd.get_dummies(data['grade'], prefix= 'grade', drop_first=True)



# create bathroom dummies
bath_dummy = pd.get_dummies(round_df['bathrooms'], prefix="bathrooms", drop_first=True)

# %% [markdown]
# ## create dummy df

# %%
dummies = pd.concat([dumgrade, dumbed, bath_dummy, age_dummy], axis=1)

# %%
dummies.columns
# Out:
# Index(['grade_8', 'grade_9', 'grade_10', 'grade_11', 'grade_12', 'grade_13',
#        'bed_2', 'bed_3', 'bed_4', 'bed_5', 'bed_6', 'bed_7', 'bed_8',
#        'bathrooms_1', 'bathrooms_2', 'bathrooms_3', 'bathrooms_4',
#        'bathrooms_5', 'home_age_10', 'home_age_20', 'home_age_30',
#        'home_age_40', 'home_age_50', 'home_age_60', 'home_age_70',
#        'home_age_80', 'home_age_90', 'home_age_100', 'home_age_110',
#        'home_age_120'],
#       dtype='object')

# %%
data
# Out:
#            price  bedrooms  bathrooms  grade  age  sqm_living  sqm_living15  \
# 0       221900.0         3       1.00      7   60   109.62554     124.49002
# 1       538000.0         3       2.25      7   64   238.76071     157.00607
# 3       604000.0         4       3.00      7   50   182.08988     126.34808
# 4       510000.0         3       2.00      8   29   156.07704     167.22540
# 5      1230000.0         4       4.50     11   14   503.53426     442.21828
# ...          ...       ...        ...    ...  ...         ...           ...
# 21592   360000.0         3       2.50      8    6   142.14159     142.14159
# 21593   400000.0         4       2.50      8    2   214.60593     170.01249
# 21594   402101.0         2       0.75      7    6    94.76106      94.76106
# 21595   400000.0         3       2.50      8   12   148.64480     130.99323
# 21596   325000.0         2       0.75      7    7    94.76106      94.76106
#
#        distance_seattle
# 0             -0.775032
# 1              1.185417
# 3             -0.288360
# 4              0.323738
# 5              0.752585
# ...                 ...
# 21592          1.036430
# 21593         -0.481641
# 21594          0.030858
# 21595         -0.426068
# 21596          0.028225
#
# [19264 rows x 8 columns]

# %% [markdown]
# # models

# %% [markdown]
# ## import libraries

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.formula.api import ols
from statsmodels.stats import diagnostic
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
from statsmodels.graphics.gofplots import ProbPlot
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline

# %% [markdown]
# ### no dummies dataframe

# %%
df = data.copy()

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'grade', 'age', 'sqm_living',
#        'sqm_living15', 'distance_seattle'],
#       dtype='object')

# %% [markdown]
# ### df with dummies

# %%
df_dummies = pd.concat([df, dummies,], axis=1)

# %%
df_dummies.drop(['grade', 'bedrooms', 'bathrooms', 'age'], axis=1, inplace=True)

# %%
df_dummies.columns
# Out:
# Index(['price', 'sqm_living', 'sqm_living15', 'distance_seattle', 'grade_8',
#        'grade_9', 'grade_10', 'grade_11', 'grade_12', 'grade_13', 'bed_2',
#        'bed_3', 'bed_4', 'bed_5', 'bed_6', 'bed_7', 'bed_8', 'bathrooms_1',
#        'bathrooms_2', 'bathrooms_3', 'bathrooms_4', 'bathrooms_5',
#        'home_age_10', 'home_age_20', 'home_age_30', 'home_age_40',
#        'home_age_50', 'home_age_60', 'home_age_70', 'home_age_80',
#        'home_age_90', 'home_age_100', 'home_age_110', 'home_age_120'],
#       dtype='object')

# %%
## apply minmax scaling to continuous data
scaler = MinMaxScaler()

# %%
cont = data.copy()

# %%
cont.drop(['bathrooms', 'bedrooms', 'grade',  'price' ], axis=1,inplace=True)

# %%
cont.columns
# Out:
# Index(['age', 'sqm_living', 'sqm_living15', 'distance_seattle'], dtype='object')

# %%
cont[['sqm_living', 'sqm_living15', 'distance_seattle', 'age']] = scaler.fit_transform(cont[['sqm_living', 'sqm_living15', 'distance_seattle', 'age' ]])

# %%
cont
# Out:
#             age  sqm_living  sqm_living15  distance_seattle
# 0      0.517241    0.066386      0.161934          0.220627
# 1      0.551724    0.212856      0.222165          0.531527
# 3      0.431034    0.148577      0.165376          0.297806
# 4      0.250000    0.119073      0.241094          0.394877
# 5      0.120690    0.513172      0.750473          0.462886
# ...         ...         ...           ...               ...
# 21592  0.051724    0.103267      0.194631          0.507900
# 21593  0.017241    0.185458      0.246257          0.267155
# 21594  0.051724    0.049526      0.106866          0.348430
# 21595  0.103448    0.110643      0.173980          0.275968
# 21596  0.060345    0.049526      0.106866          0.348012
#
# [19264 rows x 4 columns]

# %% [markdown]
# #  dataset without dummies

# %%
results = [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)' ]]
for idx, val in enumerate(['bedrooms', 'bathrooms', 'grade',
                           'distance_seattle', 'sqm_living', 
                           'sqm_living15']):
    print ("King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~" + val)
    print ("-------------------------------------------------------------------------------------")

    f = 'price~' + val
#   
    model = smf.ols(formula=f, data=data).fit()
    
    X_new = pd.DataFrame({val: [data[val].min(), data[val].max()]});
    preds = model.predict(X_new)
    data.plot(kind='scatter', x=val, y='price');
    plt.plot(X_new, preds, c='red', linewidth=2);
    plt.show()
    fig = plt.figure(figsize=(15,8))
    fig = sm.graphics.plot_regress_exog(model, val, fig=fig)
    fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True,   )
    plt.show()
    
    results.append([val, model.rsquared, model.params[0], model.params[1], model.pvalues[1], sms.jarque_bera(model.resid)[0] ])
    display(results)
    input("Press Enter to continue...")
# Out:
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~bedrooms
# -------------------------------------------------------------------------------------
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.07807768759261469,
#   157116.0067525935,
#   118758.76897869131,
#   0.0,
#   491325.7340547552]]
# Press Enter to continue...
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~bathrooms
# -------------------------------------------------------------------------------------
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.07807768759261469,
#   157116.0067525935,
#   118758.76897869131,
#   0.0,
#   491325.7340547552],
#  ['bathrooms',
#   0.23141757091621062,
#   28076.940329992896,
#   243130.7830575506,
#   0.0,
#   417291.63055173465]]
# Press Enter to continue...
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~grade
# -------------------------------------------------------------------------------------
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.07807768759261469,
#   157116.0067525935,
#   118758.76897869131,
#   0.0,
#   491325.7340547552],
#  ['bathrooms',
#   0.23141757091621062,
#   28076.940329992896,
#   243130.7830575506,
#   0.0,
#   417291.63055173465],
#  ['grade',
#   0.4495833859894873,
#   -1275212.888048384,
#   234157.95226712272,
#   0.0,
#   694922.7665552329]]
# Press Enter to continue...
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~distance_seattle
# -------------------------------------------------------------------------------------
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.07807768759261469,
#   157116.0067525935,
#   118758.76897869131,
#   0.0,
#   491325.7340547552],
#  ['bathrooms',
#   0.23141757091621062,
#   28076.940329992896,
#   243130.7830575506,
#   0.0,
#   417291.63055173465],
#  ['grade',
#   0.4495833859894873,
#   -1275212.888048384,
#   234157.95226712272,
#   0.0,
#   694922.7665552329],
#  ['distance_seattle',
#   0.06775974206989421,
#   567346.6713558972,
#   94656.86984928015,
#   7.354384377154458e-296,
#   601440.4959228556]]
# Press Enter to continue...
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~sqm_living
# -------------------------------------------------------------------------------------
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.07807768759261469,
#   157116.0067525935,
#   118758.76897869131,
#   0.0,
#   491325.7340547552],
#  ['bathrooms',
#   0.23141757091621062,
#   28076.940329992896,
#   243130.7830575506,
#   0.0,
#   417291.63055173465],
#  ['grade',
#   0.4495833859894873,
#   -1275212.888048384,
#   234157.95226712272,
#   0.0,
#   694922.7665552329],
#  ['distance_seattle',
#   0.06775974206989421,
#   567346.6713558972,
#   94656.86984928015,
#   7.354384377154458e-296,
#   601440.4959228556],
#  ['sqm_living',
#   0.4653396532572217,
#   -46130.038686865446,
#   3022.6334044628084,
#   0.0,
#   238995.57441406438]]
# Press Enter to continue...
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~sqm_living15
# -------------------------------------------------------------------------------------
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.07807768759261469,
#   157116.0067525935,
#   118758.76897869131,
#   0.0,
#   491325.7340547552],
#  ['bathrooms',
#   0.23141757091621062,
#   28076.940329992896,
#   243130.7830575506,
#   0.0,
#   417291.63055173465],
#  ['grade',
#   0.4495833859894873,
#   -1275212.888048384,
#   234157.95226712272,
#   0.0,
#   694922.7665552329],
#  ['distance_seattle',
#   0.06775974206989421,
#   567346.6713558972,
#   94656.86984928015,
#   7.354384377154458e-296,
#   601440.4959228556],
#  ['sqm_living',
#   0.4653396532572217,
#   -46130.038686865446,
#   3022.6334044628084,
#   0.0,
#   238995.57441406438],
#  ['sqm_living15',
#   0.32056784137069405,
#   -57295.20272482486,
#   3268.8700385431093,
#   0.0,
#   676141.754690611]]
# Press Enter to continue...

# %% [markdown]
# ## build model with df

# %%
# define target variable 'price'
labels = df['price']

features = df.copy()
features.drop(['price'], axis=1, inplace=True)

# %%
X_fin = features
X_with_intercept = sm.add_constant(features)
model = sm.OLS(labels, X_with_intercept).fit()
model.summary()
# Out:
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.640
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     4893.
# Date:                Thu, 14 May 2020   Prob (F-statistic):               0.00
# Time:                        15:35:39   Log-Likelihood:            -2.6414e+05
# No. Observations:               19264   AIC:                         5.283e+05
# Df Residuals:                   19256   BIC:                         5.284e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -1.061e+06   1.81e+04    -58.652      0.000    -1.1e+06   -1.03e+06
# bedrooms         -3.811e+04   2331.230    -16.348      0.000   -4.27e+04   -3.35e+04
# bathrooms         6.392e+04   3522.169     18.147      0.000     5.7e+04    7.08e+04
# grade             1.355e+05   2528.548     53.585      0.000    1.31e+05     1.4e+05
# age               3691.2297     66.429     55.566      0.000    3561.022    3821.437
# sqm_living        1702.4711     40.752     41.776      0.000    1622.593    1782.349
# sqm_living15       290.1773     40.070      7.242      0.000     211.637     368.718
# distance_seattle  6.523e+04   1614.706     40.399      0.000    6.21e+04    6.84e+04
# ==============================================================================
# Omnibus:                    14932.463   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           828112.748
# Skew:                           3.257   Prob(JB):                         0.00
# Kurtosis:                      34.453   Cond. No.                     3.45e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.45e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
my_model = LinearRegression()
my_model.fit(features, labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = my_model.predict(features)
mse = mean_squared_error(labels, predictions)
rmse = np.sqrt(mse)

print(rmse)
# Out:
# 218139.22199373323

# %%
predict_test = my_model.predict(features)
predict_test
# Out:
# array([231170.89702221, 683002.34756186, 439637.07052789, ...,
#         72613.01268464, 376440.44183713,  76132.47290135])

# %%
# get intercept and coef
print('The intercept for model is {:.8}'.format(my_model.intercept_))


#loop through dict to print
for cf in zip(features.columns, my_model.coef_):
    print('The coefficient for {} is {:7}'.format(cf[0], cf[1]))
# Out:
# The intercept for model is -1060540.7
# The coefficient for bedrooms is -38110.11526932107
# The coefficient for bathrooms is 63916.93817539014
# The coefficient for grade is 135492.91340198112
# The coefficient for age is 3691.22966239812
# The coefficient for sqm_living is 1702.4711297616975
# The coefficient for sqm_living15 is 290.1773366008847
# The coefficient for distance_seattle is 65233.03890091623

# %%
scores = cross_val_score(
            my_model, 
            features,
            labels,
            cv=20,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)

# %%
display(rmse_scores)

print(f'Mean: {rmse_scores.mean()}')
print(f'Std Dev: {rmse_scores.std()}')
# Out:
# array([210210.68671654, 257611.05272508, 225647.44212258, 264448.09506922,
#        216994.05268423, 211247.02850179, 219822.25195384, 220799.84284113,
#        180039.98425038, 190623.12053363, 218574.75300727, 197832.0893233 ,
#        219059.7482952 , 217447.54620633, 215750.9920441 , 199936.54490799,
#        227191.7966943 , 207108.07336793, 240132.65533073, 217216.1931249 ])
# Mean: 217884.6974850227
# Std Dev: 19399.773415695083

# %%
pd.DataFrame(data=my_model.coef_.reshape(1,-1), columns= features.columns)
# Out:
#        bedrooms     bathrooms          grade          age  sqm_living  \
# 0 -38110.115269  63916.938175  135492.913402  3691.229662  1702.47113
#
#    sqm_living15  distance_seattle
# 0    290.177337      65233.038901

# %% [markdown]
# the data clearly needs to be normalized as the coefficients show

# %%
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(my_model, features, labels, scoring='r2', cv=crossvalidation))

baseline
# Out:
# 0.639342839838708

# %% [markdown]
# ## regression on datasets with dummies

# %% [markdown]
# ### with minmax scaling applied to dataset, log transformed price

# %%
# create dataframe with scaling applied to continuous variables
df_scale_dummies = df_dummies.copy()
df_scale_dummies.drop(['price'], axis=1, inplace=True)
X_s = scaler.fit_transform(df_scale_dummies)

# %%
# create x & y
y_s = price_log

# %%
#create model for 
X_fin = X_s
X_with_intercept = sm.add_constant(X_s)
model1 = sm.OLS(y_s, X_with_intercept).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     1523.
# Date:                Thu, 14 May 2020   Prob (F-statistic):               0.00
# Time:                        01:27:48   Log-Likelihood:                -1649.0
# No. Observations:               19264   AIC:                             3366.
# Df Residuals:                   19230   BIC:                             3633.
# Df Model:                          33
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.0024      0.069    173.470      0.000      11.867      12.138
# x1             1.7077      0.043     39.529      0.000       1.623       1.792
# x2             0.6087      0.027     22.869      0.000       0.557       0.661
# x3             0.9979      0.012     79.957      0.000       0.973       1.022
# x4             0.2014      0.005     39.923      0.000       0.191       0.211
# x5             0.3773      0.008     48.504      0.000       0.362       0.392
# x6             0.5185      0.011     46.303      0.000       0.497       0.540
# x7             0.6343      0.017     36.419      0.000       0.600       0.668
# x8             0.7801      0.033     23.708      0.000       0.716       0.845
# x9             0.8303      0.087      9.582      0.000       0.660       1.000
# x10            0.0895      0.033      2.741      0.006       0.026       0.154
# x11            0.0653      0.032      2.020      0.043       0.002       0.129
# x12            0.0414      0.033      1.269      0.204      -0.023       0.105
# x13            0.0323      0.033      0.968      0.333      -0.033       0.098
# x14           -0.0096      0.037     -0.259      0.795      -0.082       0.063
# x15           -0.0427      0.056     -0.764      0.445      -0.152       0.067
# x16           -0.0051      0.083     -0.062      0.951      -0.168       0.158
# x17           -0.0436      0.062     -0.698      0.485      -0.166       0.079
# x18            0.0328      0.062      0.525      0.600      -0.090       0.155
# x19            0.0986      0.063      1.568      0.117      -0.025       0.222
# x20            0.1263      0.065      1.952      0.051      -0.001       0.253
# x21            0.1713      0.075      2.285      0.022       0.024       0.318
# x22           -0.0438      0.009     -4.842      0.000      -0.061      -0.026
# x23           -0.0747      0.010     -7.846      0.000      -0.093      -0.056
# x24           -0.0363      0.010     -3.687      0.000      -0.056      -0.017
# x25            0.0018      0.010      0.182      0.855      -0.017       0.021
# x26            0.0658      0.010      6.550      0.000       0.046       0.085
# x27            0.1491      0.010     14.714      0.000       0.129       0.169
# x28            0.2233      0.012     18.216      0.000       0.199       0.247
# x29            0.2902      0.015     20.003      0.000       0.262       0.319
# x30            0.3697      0.012     30.116      0.000       0.346       0.394
# x31            0.3972      0.014     28.824      0.000       0.370       0.424
# x32            0.3992      0.015     26.680      0.000       0.370       0.429
# x33            0.3969      0.035     11.492      0.000       0.329       0.465
# ==============================================================================
# Omnibus:                      341.433   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              637.356
# Skew:                           0.109   Prob(JB):                    3.98e-139
# Kurtosis:                       3.864   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### with minmax scaling applied to continuous, log transformed price

# %%
# dataframe with only continuous transformed
df_scont_dummies = pd.concat([cont, dummies],axis=1)

# %%
#create model
X_fin = df_scont_dummies
X_with_intercept = sm.add_constant(df_scont_dummies)
model1 = sm.OLS(y_s, X_with_intercept).fit()
model1.summary()
# Out:
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     1481.
# Date:                Thu, 14 May 2020   Prob (F-statistic):               0.00
# Time:                        01:41:18   Log-Likelihood:                -1631.9
# No. Observations:               19264   AIC:                             3334.
# Df Residuals:                   19229   BIC:                             3609.
# Df Model:                          34
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               11.9919      0.069    173.410      0.000      11.856      12.127
# age                  0.4753      0.081      5.857      0.000       0.316       0.634
# sqm_living           1.7027      0.043     39.440      0.000       1.618       1.787
# sqm_living15         0.6041      0.027     22.707      0.000       0.552       0.656
# distance_seattle     0.9966      0.012     79.909      0.000       0.972       1.021
# grade_8              0.2027      0.005     40.175      0.000       0.193       0.213
# grade_9              0.3793      0.008     48.760      0.000       0.364       0.395
# grade_10             0.5205      0.011     46.505      0.000       0.499       0.542
# grade_11             0.6360      0.017     36.546      0.000       0.602       0.670
# grade_12             0.7847      0.033     23.860      0.000       0.720       0.849
# grade_13             0.8305      0.087      9.592      0.000       0.661       1.000
# bed_2                0.0903      0.033      2.766      0.006       0.026       0.154
# bed_3                0.0661      0.032      2.047      0.041       0.003       0.129
# bed_4                0.0421      0.033      1.293      0.196      -0.022       0.106
# bed_5                0.0330      0.033      0.990      0.322      -0.032       0.098
# bed_6               -0.0095      0.037     -0.259      0.796      -0.082       0.063
# bed_7               -0.0465      0.056     -0.833      0.405      -0.156       0.063
# bed_8               -0.0059      0.083     -0.071      0.943      -0.169       0.157
# bathrooms_1         -0.0431      0.062     -0.692      0.489      -0.165       0.079
# bathrooms_2          0.0341      0.062      0.546      0.585      -0.088       0.156
# bathrooms_3          0.1009      0.063      1.606      0.108      -0.022       0.224
# bathrooms_4          0.1314      0.065      2.032      0.042       0.005       0.258
# bathrooms_5          0.1750      0.075      2.336      0.019       0.028       0.322
# home_age_10         -0.0752      0.011     -7.159      0.000      -0.096      -0.055
# home_age_20         -0.1467      0.016     -9.437      0.000      -0.177      -0.116
# home_age_30         -0.1466      0.021     -6.900      0.000      -0.188      -0.105
# home_age_40         -0.1472      0.027     -5.412      0.000      -0.201      -0.094
# home_age_50         -0.1279      0.035     -3.701      0.000      -0.196      -0.060
# home_age_60         -0.0851      0.041     -2.063      0.039      -0.166      -0.004
# home_age_70         -0.0500      0.048     -1.036      0.300      -0.145       0.045
# home_age_80         -0.0213      0.055     -0.387      0.699      -0.129       0.087
# home_age_90          0.0128      0.062      0.206      0.837      -0.109       0.135
# home_age_100        -0.0025      0.070     -0.036      0.971      -0.139       0.134
# home_age_110        -0.0369      0.076     -0.485      0.627      -0.186       0.112
# home_age_120        -0.0650      0.086     -0.755      0.450      -0.234       0.104
# ==============================================================================
# Omnibus:                      339.673   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              633.953
# Skew:                           0.107   Prob(JB):                    2.18e-138
# Kurtosis:                       3.862   Cond. No.                         155.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### no scaling applied to continuous, log transformed price

# %%
y = price_log
X = df_dummies.copy()
X.drop(['price'], axis=1, inplace=True)

# %%
# create model
X_with_intercept = sm.add_constant(X)
model2 = sm.OLS(y, X_with_intercept).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     1523.
# Date:                Thu, 14 May 2020   Prob (F-statistic):               0.00
# Time:                        01:41:20   Log-Likelihood:                -1649.0
# No. Observations:               19264   AIC:                             3366.
# Df Residuals:                   19230   BIC:                             3633.
# Df Model:                          33
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               12.2044      0.069    176.257      0.000      12.069      12.340
# sqm_living           0.0019    4.9e-05     39.529      0.000       0.002       0.002
# sqm_living15         0.0011   4.93e-05     22.869      0.000       0.001       0.001
# distance_seattle     0.1582      0.002     79.957      0.000       0.154       0.162
# grade_8              0.2014      0.005     39.923      0.000       0.191       0.211
# grade_9              0.3773      0.008     48.504      0.000       0.362       0.392
# grade_10             0.5185      0.011     46.303      0.000       0.497       0.540
# grade_11             0.6343      0.017     36.419      0.000       0.600       0.668
# grade_12             0.7801      0.033     23.708      0.000       0.716       0.845
# grade_13             0.8303      0.087      9.582      0.000       0.660       1.000
# bed_2                0.0895      0.033      2.741      0.006       0.026       0.154
# bed_3                0.0653      0.032      2.020      0.043       0.002       0.129
# bed_4                0.0414      0.033      1.269      0.204      -0.023       0.105
# bed_5                0.0323      0.033      0.968      0.333      -0.033       0.098
# bed_6               -0.0096      0.037     -0.259      0.795      -0.082       0.063
# bed_7               -0.0427      0.056     -0.764      0.445      -0.152       0.067
# bed_8               -0.0051      0.083     -0.062      0.951      -0.168       0.158
# bathrooms_1         -0.0436      0.062     -0.698      0.485      -0.166       0.079
# bathrooms_2          0.0328      0.062      0.525      0.600      -0.090       0.155
# bathrooms_3          0.0986      0.063      1.568      0.117      -0.025       0.222
# bathrooms_4          0.1263      0.065      1.952      0.051      -0.001       0.253
# bathrooms_5          0.1713      0.075      2.285      0.022       0.024       0.318
# home_age_10         -0.0438      0.009     -4.842      0.000      -0.061      -0.026
# home_age_20         -0.0747      0.010     -7.846      0.000      -0.093      -0.056
# home_age_30         -0.0363      0.010     -3.687      0.000      -0.056      -0.017
# home_age_40          0.0018      0.010      0.182      0.855      -0.017       0.021
# home_age_50          0.0658      0.010      6.550      0.000       0.046       0.085
# home_age_60          0.1491      0.010     14.714      0.000       0.129       0.169
# home_age_70          0.2233      0.012     18.216      0.000       0.199       0.247
# home_age_80          0.2902      0.015     20.003      0.000       0.262       0.319
# home_age_90          0.3697      0.012     30.116      0.000       0.346       0.394
# home_age_100         0.3972      0.014     28.824      0.000       0.370       0.424
# home_age_110         0.3992      0.015     26.680      0.000       0.370       0.429
# home_age_120         0.3969      0.035     11.492      0.000       0.329       0.465
# ==============================================================================
# Omnibus:                      341.433   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              637.356
# Skew:                           0.109   Prob(JB):                    3.98e-139
# Kurtosis:                       3.864   Cond. No.                     2.39e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
#  the durbin watson score shows that there is some autocorrelation prsent in the data, so stepwise selection may reverse this occurence

# %% [markdown]
# ### no scaling to variables or price

# %%
y_b = df_dummies.price
X_b = df_dummies.copy()
X_b.drop(['price'], axis=1, inplace=True)

# %%
X_fin3 = X_b
X_with_intercept = sm.add_constant(X_b)
model3 = sm.OLS(y_b, X_with_intercept).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     1176.
# Date:                Thu, 14 May 2020   Prob (F-statistic):               0.00
# Time:                        01:41:25   Log-Likelihood:            -2.6335e+05
# No. Observations:               19264   AIC:                         5.268e+05
# Df Residuals:                   19230   BIC:                         5.270e+05
# Df Model:                          33
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1.584e+04    5.5e+04      0.288      0.773   -9.19e+04    1.24e+05
# sqm_living        1489.3773     38.913     38.274      0.000    1413.104    1565.650
# sqm_living15       471.5382     39.156     12.043      0.000     394.790     548.286
# distance_seattle   6.43e+04   1571.778     40.906      0.000    6.12e+04    6.74e+04
# grade_8           9.004e+04   4005.692     22.478      0.000    8.22e+04    9.79e+04
# grade_9           2.156e+05   6176.767     34.905      0.000    2.03e+05    2.28e+05
# grade_10           3.88e+05   8892.501     43.627      0.000    3.71e+05    4.05e+05
# grade_11          6.393e+05   1.38e+04     46.223      0.000    6.12e+05    6.66e+05
# grade_12          1.082e+06   2.61e+04     41.389      0.000    1.03e+06    1.13e+06
# grade_13          1.694e+06   6.88e+04     24.621      0.000    1.56e+06    1.83e+06
# bed_2             2.742e+04   2.59e+04      1.057      0.291   -2.34e+04    7.83e+04
# bed_3             2470.5649   2.57e+04      0.096      0.923   -4.79e+04    5.28e+04
# bed_4            -3.819e+04   2.59e+04     -1.475      0.140   -8.89e+04    1.26e+04
# bed_5            -3.865e+04   2.65e+04     -1.459      0.145   -9.06e+04    1.33e+04
# bed_6            -1.063e+05   2.93e+04     -3.634      0.000   -1.64e+05    -4.9e+04
# bed_7            -8.991e+04   4.43e+04     -2.029      0.042   -1.77e+05   -3049.811
# bed_8            -2.397e+04   6.61e+04     -0.363      0.717   -1.54e+05    1.06e+05
# bathrooms_1      -1.089e+04   4.96e+04     -0.220      0.826   -1.08e+05    8.62e+04
# bathrooms_2       2.518e+04   4.96e+04      0.507      0.612   -7.21e+04    1.22e+05
# bathrooms_3        9.02e+04   4.99e+04      1.807      0.071   -7654.618    1.88e+05
# bathrooms_4       2.304e+05   5.14e+04      4.483      0.000     1.3e+05    3.31e+05
# bathrooms_5       4.594e+05   5.95e+04      7.716      0.000    3.43e+05    5.76e+05
# home_age_10      -2.917e+04   7178.900     -4.063      0.000   -4.32e+04   -1.51e+04
# home_age_20      -6.144e+04   7556.682     -8.130      0.000   -7.62e+04   -4.66e+04
# home_age_30      -2.309e+04   7811.984     -2.956      0.003   -3.84e+04   -7782.578
# home_age_40       2.247e+04   7662.025      2.932      0.003    7449.373    3.75e+04
# home_age_50       7.369e+04   7976.240      9.239      0.000    5.81e+04    8.93e+04
# home_age_60       1.217e+05   8048.136     15.123      0.000    1.06e+05    1.37e+05
# home_age_70       1.506e+05   9736.511     15.463      0.000    1.31e+05     1.7e+05
# home_age_80       2.166e+05   1.15e+04     18.797      0.000    1.94e+05    2.39e+05
# home_age_90       2.327e+05   9748.875     23.866      0.000    2.14e+05    2.52e+05
# home_age_100      2.501e+05   1.09e+04     22.855      0.000    2.29e+05    2.72e+05
# home_age_110       2.58e+05   1.19e+04     21.715      0.000    2.35e+05    2.81e+05
# home_age_120      2.357e+05   2.74e+04      8.596      0.000    1.82e+05    2.89e+05
# ==============================================================================
# Omnibus:                    13227.108   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           581244.928
# Skew:                           2.762   Prob(JB):                         0.00
# Kurtosis:                      29.337   Cond. No.                     2.39e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## using model 2, log transformed price

# %%
my_model = LinearRegression()
my_model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
crossvalidation = KFold(n_splits=100, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(my_model, X, y, scoring='r2', cv=crossvalidation))

baseline
# Out:
# 0.7182559143227746

# %%
coef = my_model.coef_.reshape(-1,1)
coef
# Out:
# array([[ 0.00193689],
#        [ 0.00112754],
#        [ 0.15824885],
#        [ 0.20136839],
#        [ 0.37725403],
#        [ 0.51846969],
#        [ 0.63425428],
#        [ 0.78014342],
#        [ 0.83033352],
#        [ 0.08953392],
#        [ 0.06534023],
#        [ 0.04137937],
#        [ 0.03228608],
#        [-0.00955173],
#        [-0.04265167],
#        [-0.00514796],
#        [-0.0435713 ],
#        [ 0.03279574],
#        [ 0.09858523],
#        [ 0.12634188],
#        [ 0.17129773],
#        [-0.04376859],
#        [-0.07465422],
#        [-0.03626352],
#        [ 0.0017583 ],
#        [ 0.06578714],
#        [ 0.14911548],
#        [ 0.22332589],
#        [ 0.2902025 ],
#        [ 0.36969576],
#        [ 0.39715675],
#        [ 0.39920228],
#        [ 0.39685981]])

# %%
y_hat = my_model.predict(X)
y_hat.reshape(-1,1)
# Out:
# array([[12.60538311],
#        [13.27877243],
#        [12.85971602],
#        ...,
#        [12.54548369],
#        [12.82836621],
#        [12.54506699]])

# %%
scores = cross_val_score(
            my_model, 
            X,
            y,
            cv=8,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)
display(rmse_scores)

print(f'Mean: {rmse_scores.mean()}')
print(f'Std Dev: {rmse_scores.std()}')
# Out:
# array([0.26753749, 0.27038565, 0.25941507, 0.26019719, 0.27003764,
#        0.27270289, 0.26464164, 0.2616457 ])
# Mean: 0.26582041095738673
# Std Dev: 0.004748817171552576

# %% [markdown]
# ## train/test split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=29)
print(X_train.shape); print(X_test.shape)
# Out:
# (13484, 33)
# (5780, 33)

# %%
train_model = LinearRegression()
train_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#run model with trianing data
pred_train_lr= train_model.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_lr)))
print(r2_score(y_train, pred_train_lr))


# run model with test data 
pred_test_lr= train_model.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_lr))) 
print(r2_score(y_test, pred_test_lr))
# Out:
# 0.26375358192881904
# 0.7266583735365648
# 0.26369660883660784
# 0.7138249133363811

# %%
predict_train = train_model.predict(X_train)
predict_train
# Out:
# array([12.39250191, 12.74806436, 12.89811433, ..., 13.76784589,
#        13.08386823, 13.1326204 ])

# %%
predict_test = train_model.predict(X_test)
predict_test
# Out:
# array([13.72054507, 13.64484435, 12.37358064, ..., 12.98201914,
#        12.92670637, 13.30680109])

# %% [markdown]
# ### visualize training data vs test data

# %%
import seaborn as sns

ax1 = sns.distplot(predict_train, hist=False, color="r", label="Train")
sns.distplot(predict_test, hist=False, color="b", label="Test" , ax=ax1)

# %%
train_model.coef_.reshape(-1,1)
# Out:
# array([[ 0.00192037],
#        [ 0.00117745],
#        [ 0.15872237],
#        [ 0.19817975],
#        [ 0.36958967],
#        [ 0.51345944],
#        [ 0.63429823],
#        [ 0.8011607 ],
#        [ 0.86931325],
#        [ 0.06260758],
#        [ 0.03583498],
#        [ 0.00572852],
#        [ 0.00425393],
#        [-0.0270742 ],
#        [-0.13761298],
#        [-0.04114669],
#        [-0.05182842],
#        [ 0.0285527 ],
#        [ 0.09152316],
#        [ 0.12674446],
#        [ 0.20530167],
#        [-0.04377443],
#        [-0.07902676],
#        [-0.03863756],
#        [-0.00580895],
#        [ 0.05330557],
#        [ 0.15082618],
#        [ 0.22556019],
#        [ 0.27738017],
#        [ 0.35646688],
#        [ 0.40323285],
#        [ 0.38563751],
#        [ 0.38089213]])

# %%
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(train_model, X_train, y_train, scoring='r2', cv=crossvalidation))

baseline
# Out:
# 0.7243858780803623

# %% [markdown]
# ## perform stepwise selection on model and review variable significance

# %%
stepwise_selection(X, y)
# Out:
# Add  grade_9                        with p-value 0.0
# Add  grade_10                       with p-value 0.0
# Add  sqm_living                     with p-value 0.0
# Add  distance_seattle               with p-value 0.0
# Add  sqm_living15                   with p-value 1.19243e-132
# Add  home_age_90                    with p-value 2.81613e-135
# Add  home_age_100                   with p-value 3.84319e-122
# Add  home_age_110                   with p-value 1.56792e-124
# Add  grade_8                        with p-value 3.89972e-108
# Add  grade_11                       with p-value 6.16472e-173
# Add  grade_12                       with p-value 3.44719e-97
# Add  home_age_80                    with p-value 2.62783e-84
# Add  home_age_70                    with p-value 8.88847e-82
# Add  home_age_60                    with p-value 5.40756e-95
# Add  home_age_120                   with p-value 3.08384e-31
# Add  home_age_50                    with p-value 8.84039e-26
# Add  bathrooms_1                    with p-value 3.66013e-31
# Add  grade_13                       with p-value 1.23507e-24
# Add  bathrooms_2                    with p-value 4.22326e-22
# Add  home_age_20                    with p-value 5.0085e-16
# Add  home_age_40                    with p-value 4.60717e-06
# Add  bed_2                          with p-value 0.000108795
# Add  bed_3                          with p-value 1.6236e-08
# Add  home_age_10                    with p-value 0.00228464
# Add  home_age_30                    with p-value 0.000149908
# Drop home_age_40                    with p-value 0.984962
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:44: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
# ['grade_9',
#  'grade_10',
#  'sqm_living',
#  'distance_seattle',
#  'sqm_living15',
#  'home_age_90',
#  'home_age_100',
#  'home_age_110',
#  'grade_8',
#  'grade_11',
#  'grade_12',
#  'home_age_80',
#  'home_age_70',
#  'home_age_60',
#  'home_age_120',
#  'home_age_50',
#  'bathrooms_1',
#  'grade_13',
#  'bathrooms_2',
#  'home_age_20',
#  'bed_2',
#  'bed_3',
#  'home_age_10',
#  'home_age_30']

# %%
# model with columns from stepwise selection
X_fin = X[['grade_9',
 'sqm_living',
 'distance_seattle',
 'sqm_living15',
 'home_age_90',
 'home_age_100',
 'home_age_110',
 'grade_10',
 'grade_8',
 'grade_11',
 'grade_12',
 'home_age_80',
 'home_age_70',
 'home_age_60',
 'home_age_120',
 'home_age_50',
 'bathrooms_1',
 'grade_13',
 'home_age_20',
 'bathrooms_2',
 'bed_2',
 'bed_3',
 'home_age_10',
 'home_age_30']]

X_with_intercept = sm.add_constant(X_fin)
model = sm.OLS(y, X_with_intercept).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.723
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     2092.
# Date:                Thu, 14 May 2020   Prob (F-statistic):               0.00
# Time:                        02:07:42   Log-Likelihood:                -1658.9
# No. Observations:               19264   AIC:                             3368.
# Df Residuals:                   19239   BIC:                             3564.
# Df Model:                          24
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               12.3390      0.014    905.038      0.000      12.312      12.366
# grade_9              0.3779      0.008     49.529      0.000       0.363       0.393
# sqm_living           0.0019   4.69e-05     41.298      0.000       0.002       0.002
# distance_seattle     0.1582      0.002     80.004      0.000       0.154       0.162
# sqm_living15         0.0011   4.91e-05     23.064      0.000       0.001       0.001
# home_age_90          0.3678      0.010     36.103      0.000       0.348       0.388
# home_age_100         0.3936      0.012     33.007      0.000       0.370       0.417
# home_age_110         0.3963      0.013     29.713      0.000       0.370       0.422
# grade_10             0.5213      0.011     47.093      0.000       0.500       0.543
# grade_8              0.2015      0.005     40.238      0.000       0.192       0.211
# grade_11             0.6429      0.017     37.452      0.000       0.609       0.677
# grade_12             0.7964      0.032     24.530      0.000       0.733       0.860
# home_age_80          0.2891      0.013     22.549      0.000       0.264       0.314
# home_age_70          0.2219      0.010     22.006      0.000       0.202       0.242
# home_age_60          0.1473      0.007     20.040      0.000       0.133       0.162
# home_age_120         0.3931      0.034     11.610      0.000       0.327       0.459
# home_age_50          0.0631      0.007      8.653      0.000       0.049       0.077
# bathrooms_1         -0.1388      0.008    -16.568      0.000      -0.155      -0.122
# grade_13             0.8614      0.085     10.088      0.000       0.694       1.029
# home_age_20         -0.0753      0.007    -10.572      0.000      -0.089      -0.061
# bathrooms_2         -0.0635      0.007     -9.476      0.000      -0.077      -0.050
# bed_2                0.0506      0.008      6.265      0.000       0.035       0.066
# bed_3                0.0269      0.005      5.807      0.000       0.018       0.036
# home_age_10         -0.0436      0.007     -6.679      0.000      -0.056      -0.031
# home_age_30         -0.0374      0.007     -5.043      0.000      -0.052      -0.023
# ==============================================================================
# Omnibus:                      343.623   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              641.987
# Skew:                           0.110   Prob(JB):                    3.93e-140
# Kurtosis:                       3.867   Cond. No.                     1.33e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.33e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# Your code here
SS_Residual = np.sum((y-y_hat)**2)
SS_Total = np.sum((y-np.mean(y))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X_fin.shape[1]-1)
print(SS_Residual)
print(SS_Total)
print(r_squared)
print(adjusted_r_squared)
# Out:
# 1338.518639781431
# 4836.160509915235
# 0.7232270026941493
# 0.7228817377669005

# %%
y_hat = model.predict(X_fin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-185-e5631c9d8709> in <module>
# ----> 1 y_hat = model.predict(X_fin)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1036
#    1037         predict_results = self.model.predict(self.params, exog, *args,
# -> 1038                                              **kwargs)
#    1039
#    1040         if exog_index is not None and not hasattr(predict_results,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     362             exog = self.exog
#     363
# --> 364         return np.dot(exog, params)
#     365
#     366     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# ValueError: shapes (19264,24) and (25,) not aligned: 24 (dim 1) != 25 (dim 0)

# %%
resid = y_hat - y
resid
# Out:
# 0        0.295401
# 1        0.083159
# 3       -0.451613
# 4       -0.132390
# 5        0.533134
#            ...
# 21592    0.265920
# 21593    0.111915
# 21594   -0.358975
# 21595   -0.070854
# 21596   -0.146513
# Name: price, Length: 19264, dtype: float64

# %%
rmse = rmse(y, y_hat)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-78dce7dc043e> in <module>
# ----> 1 rmse = rmse(y, y_hat)
#
# TypeError: 'numpy.float64' object is not callable

# %%
# recreate model to utilize for visualizing

# %%
X2 = sm.add_constant(X_fin)

model = sm.OLS(y, X2)
est = model.fit()
est.summary()

# %%
est.conf_int()

# %%
lm, lm_pval, f_val, f_pval = diagnostic.het_breuschpagan(est.resid, est.model.exog)
print('p-value of lagrange multiplier test {:.3}'.format(lm_pval))
print('the f value is {:.3}'.format(f_val))
print('the f p-value is {:.3}'.format(f_pval))

# %% [markdown]
# The null hypothesis assumes homoskedasticity. for p_val > 0.05, fail to reject the null and conclude there may not be heteroskedasticity.

# %% [markdown]
# ## residuals

# %%
import pylab
sm.qqplot(est.resid, line = 's')
pylab.show()


mean_resid = sum(est.resid)/len(est.resid)
mean_resid

# %%
y_hat = est.predict()
print(y_hat)

# %%
ax1 = sns.distplot(y, hist=False, color="r", label="Actual")
sns.distplot(y_hat, hist=False, color="b", label="Predicted" , ax=ax1)

# %%
est.params

# %% [markdown]
# # rename model for save

# %%
X_df = df_dummies[['grade_9',
 'sqm_living',
 'distance_seattle',
 'sqm_living15',
 'home_age_90',
 'home_age_100',
 'home_age_110',
 'grade_10',
 'grade_8',
 'grade_11',
 'grade_12',
 'home_age_80',
 'home_age_70',
 'home_age_60',
 'home_age_120',
 'home_age_50',
 'bathrooms_1',
 'grade_13',
 'home_age_20',
 'bathrooms_2',
 'bed_2',
 'bed_3',
 'home_age_10',
 'home_age_30']]

# %%
regression_model = LinearRegression()
regression_model.fit(X_df, y)

# %%
rmse =np.sqrt(mean_squared_error(y, yhat2))
print(rmse)
yhat2 =np.exp(regression_model.predict(X_df))
print(yhat2)

# %%
scores = cross_val_score(
            regression_model, 
            X_df,
            y,
            cv=10,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)

# %%
display(rmse_scores)
display(rmse_scores.mean())
display(rmse_scores.std())

# %%
display(regression_model.coef_)
display(regression_model.intercept_)

# %%
y_df = data['price']

complete_df = pd.concat([y_df, X_df], axis=1)
complete_df.columns

# %%
complete_df.to_csv(r'dsc-mod-2-project-v2-1-onl01-dtsc-pt-012120\complete_df.csv')

# %%
import pickle

#pickle model
pickle.dump(regression_model, open('regression_king_county_pickle.pkl','wb'))
