# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Final Project Submission</a></span></li></ul></li><li><span><a href="#data-scrubbing-and-cleaning" data-toc-modified-id="data-scrubbing-and-cleaning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>data scrubbing and cleaning</a></span><ul class="toc-item"><li><span><a href="#import-modules-and-data" data-toc-modified-id="import-modules-and-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>import modules and data</a></span></li><li><span><a href="#functions" data-toc-modified-id="functions-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>functions</a></span></li><li><span><a href="#create-series-to-present-price-in-readable-way-for-visualizations" data-toc-modified-id="create-series-to-present-price-in-readable-way-for-visualizations-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>create series to present price in readable way for visualizations</a></span></li><li><span><a href="#fill-in-missing-values-(NaN)-where-applicable" data-toc-modified-id="fill-in-missing-values-(NaN)-where-applicable-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>fill in missing values (NaN) where applicable</a></span></li><li><span><a href="#assess-whether-renovation-has-direct-impact-on-home-price" data-toc-modified-id="assess-whether-renovation-has-direct-impact-on-home-price-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>assess whether renovation has direct impact on home price</a></span></li><li><span><a href="#convert-date-column-to-DateTime-format,-then-separate-date-to-month,-day,-year-columns-due-to-datetime-being-unusable-in-regression,-(drop-'data'-column-once-all-necessary-calculations-have-been-done)" data-toc-modified-id="convert-date-column-to-DateTime-format,-then-separate-date-to-month,-day,-year-columns-due-to-datetime-being-unusable-in-regression,-(drop-'data'-column-once-all-necessary-calculations-have-been-done)-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>convert date column to DateTime format, then separate date to month, day, year columns due to datetime being unusable in regression, (drop 'data' column once all necessary calculations have been done)</a></span></li><li><span><a href="#create-age-column-from-date-of-sale-and-year-built" data-toc-modified-id="create-age-column-from-date-of-sale-and-year-built-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>create age column from date of sale and year built</a></span></li><li><span><a href="#find-out-if-there-are-historic-homes-on-dataset.-washington-state-qualifies-as-over-50-and-retaining-original-structure.-assess-whether-these-are-abnormalities" data-toc-modified-id="find-out-if-there-are-historic-homes-on-dataset.-washington-state-qualifies-as-over-50-and-retaining-original-structure.-assess-whether-these-are-abnormalities-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>find out if there are historic homes on dataset. washington state qualifies as over 50 and retaining original structure. assess whether these are abnormalities</a></span></li><li><span><a href="#assess-whether-renovating-a-historic-home-increases-market-value-as-far-as-price" data-toc-modified-id="assess-whether-renovating-a-historic-home-increases-market-value-as-far-as-price-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>assess whether renovating a historic home increases market value as far as price</a></span><ul class="toc-item"><li><span><a href="#drop-columns-not-to-be-utilized" data-toc-modified-id="drop-columns-not-to-be-utilized-1.9.1"><span class="toc-item-num">1.9.1&nbsp;&nbsp;</span>drop columns not to be utilized</a></span></li></ul></li><li><span><a href="#sqft_basement-column-contains-string-characters,-remove-these-and-convert-to-int-to-match-other-similar-columns" data-toc-modified-id="sqft_basement-column-contains-string-characters,-remove-these-and-convert-to-int-to-match-other-similar-columns-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>sqft_basement column contains string characters, remove these and convert to int to match other similar columns</a></span></li><li><span><a href="#convert-sq_ft-areas-to-square-meters" data-toc-modified-id="convert-sq_ft-areas-to-square-meters-1.11"><span class="toc-item-num">1.11&nbsp;&nbsp;</span>convert sq_ft areas to square meters</a></span></li><li><span><a href="#bedrooms-outlier-present-as-33-bedroom-house,-appears-to-be-typo-due-to-other-info,-should-be-3-bedrooms-as-this-listing-only-has-1.75-bathrooms" data-toc-modified-id="bedrooms-outlier-present-as-33-bedroom-house,-appears-to-be-typo-due-to-other-info,-should-be-3-bedrooms-as-this-listing-only-has-1.75-bathrooms-1.12"><span class="toc-item-num">1.12&nbsp;&nbsp;</span>bedrooms outlier present as 33 bedroom house, appears to be typo due to other info, should be 3 bedrooms as this listing only has 1.75 bathrooms</a></span></li><li><span><a href="#assessing-grade-category" data-toc-modified-id="assessing-grade-category-1.13"><span class="toc-item-num">1.13&nbsp;&nbsp;</span>assessing grade category</a></span><ul class="toc-item"><li><span><a href="#assess-the-affect-that-the-grade-of-the-house-hs-on-the-sale-value" data-toc-modified-id="assess-the-affect-that-the-grade-of-the-house-hs-on-the-sale-value-1.13.1"><span class="toc-item-num">1.13.1&nbsp;&nbsp;</span>assess the affect that the grade of the house hs on the sale value</a></span></li><li><span><a href="#assess-condition-category" data-toc-modified-id="assess-condition-category-1.13.2"><span class="toc-item-num">1.13.2&nbsp;&nbsp;</span>assess condition category</a></span></li><li><span><a href="#assess-lot-size-and-home-type" data-toc-modified-id="assess-lot-size-and-home-type-1.13.3"><span class="toc-item-num">1.13.3&nbsp;&nbsp;</span>assess lot size and home type</a></span></li></ul></li><li><span><a href="#assess-for-duplicates" data-toc-modified-id="assess-for-duplicates-1.14"><span class="toc-item-num">1.14&nbsp;&nbsp;</span>assess for duplicates</a></span></li><li><span><a href="#evaluate-duplicate-ids" data-toc-modified-id="evaluate-duplicate-ids-1.15"><span class="toc-item-num">1.15&nbsp;&nbsp;</span>evaluate duplicate ids</a></span></li><li><span><a href="#use-latitude-and-longitude-in-existing-dataset-to-get-the-distance-from-home-to-Seattle(closest-major-city)" data-toc-modified-id="use-latitude-and-longitude-in-existing-dataset-to-get-the-distance-from-home-to-Seattle(closest-major-city)-1.16"><span class="toc-item-num">1.16&nbsp;&nbsp;</span>use latitude and longitude in existing dataset to get the distance from home to Seattle(closest major city)</a></span><ul class="toc-item"><li><span><a href="#import-geopy-modules" data-toc-modified-id="import-geopy-modules-1.16.1"><span class="toc-item-num">1.16.1&nbsp;&nbsp;</span>import geopy modules</a></span></li><li><span><a href="#use-geopy-to-set-up-points-and-calculate-distance" data-toc-modified-id="use-geopy-to-set-up-points-and-calculate-distance-1.16.2"><span class="toc-item-num">1.16.2&nbsp;&nbsp;</span>use geopy to set up points and calculate distance</a></span></li><li><span><a href="#assess-data-by-zipcode" data-toc-modified-id="assess-data-by-zipcode-1.16.3"><span class="toc-item-num">1.16.3&nbsp;&nbsp;</span>assess data by zipcode</a></span></li><li><span><a href="#dropping-columns" data-toc-modified-id="dropping-columns-1.16.4"><span class="toc-item-num">1.16.4&nbsp;&nbsp;</span>dropping columns</a></span></li></ul></li><li><span><a href="#dropping-all-sqft-columns-due-to-conversion-to-metric-system" data-toc-modified-id="dropping-all-sqft-columns-due-to-conversion-to-metric-system-1.17"><span class="toc-item-num">1.17&nbsp;&nbsp;</span>dropping all sqft columns due to conversion to metric system</a></span></li><li><span><a href="#create-id-dataframe-to-attach-once-model-is-complete.-remove-id-from-dataset-as-it-isn't-relevant-but-just-identifies-homes" data-toc-modified-id="create-id-dataframe-to-attach-once-model-is-complete.-remove-id-from-dataset-as-it-isn't-relevant-but-just-identifies-homes-1.18"><span class="toc-item-num">1.18&nbsp;&nbsp;</span>create id dataframe to attach once model is complete. remove id from dataset as it isn't relevant but just identifies homes</a></span></li></ul></li><li><span><a href="#check-for-multicollinearity" data-toc-modified-id="check-for-multicollinearity-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>check for multicollinearity</a></span><ul class="toc-item"><li><span><a href="#heatmap-for-correlation-assessment" data-toc-modified-id="heatmap-for-correlation-assessment-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>heatmap for correlation assessment</a></span></li><li><span><a href="#create-new-dataframe-to-further-assess-correlation" data-toc-modified-id="create-new-dataframe-to-further-assess-correlation-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>create new dataframe to further assess correlation</a></span></li><li><span><a href="#scatter-matrix-to-further-assess-multicollinearity" data-toc-modified-id="scatter-matrix-to-further-assess-multicollinearity-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>scatter matrix to further assess multicollinearity</a></span><ul class="toc-item"><li><span><a href="#assess-for-outliers" data-toc-modified-id="assess-for-outliers-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>assess for outliers</a></span></li></ul></li></ul></li><li><span><a href="#data-exploration" data-toc-modified-id="data-exploration-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>data exploration</a></span><ul class="toc-item"><li><span><a href="#histograms" data-toc-modified-id="histograms-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>histograms</a></span></li><li><span><a href="#pairplot" data-toc-modified-id="pairplot-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>pairplot</a></span></li><li><span><a href="#kde" data-toc-modified-id="kde-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>kde</a></span></li><li><span><a href="#check-price-skew,-visualize-tranformed-data,-normalize-price-using-log-transformation" data-toc-modified-id="check-price-skew,-visualize-tranformed-data,-normalize-price-using-log-transformation-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>check price skew, visualize tranformed data, normalize price using log transformation</a></span></li><li><span><a href="#regression-plots-with-transformed-data" data-toc-modified-id="regression-plots-with-transformed-data-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>regression plots with transformed data</a></span></li><li><span><a href="#age/price-scatter" data-toc-modified-id="age/price-scatter-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>age/price scatter</a></span></li><li><span><a href="#distance-to-seattle/price-scatter" data-toc-modified-id="distance-to-seattle/price-scatter-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>distance to seattle/price scatter</a></span></li><li><span><a href="#visualize-categorical-variables-by-price" data-toc-modified-id="visualize-categorical-variables-by-price-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>visualize categorical variables by price</a></span><ul class="toc-item"><li><span><a href="#comparing-grade-and-condition-columns-visually" data-toc-modified-id="comparing-grade-and-condition-columns-visually-3.8.1"><span class="toc-item-num">3.8.1&nbsp;&nbsp;</span>comparing grade and condition columns visually</a></span></li></ul></li></ul></li><li><span><a href="#one-hot-encoding,-create-new-df:-dummies" data-toc-modified-id="one-hot-encoding,-create-new-df:-dummies-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>one hot encoding, create new df: dummies</a></span><ul class="toc-item"><li><span><a href="#create-dummy-df" data-toc-modified-id="create-dummy-df-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>create dummy df</a></span></li></ul></li><li><span><a href="#models" data-toc-modified-id="models-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>models</a></span><ul class="toc-item"><li><span><a href="#import-libraries" data-toc-modified-id="import-libraries-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>import libraries</a></span><ul class="toc-item"><li><span><a href="#no-dummies-dataframe" data-toc-modified-id="no-dummies-dataframe-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>no dummies dataframe</a></span></li><li><span><a href="#df-with-dummies" data-toc-modified-id="df-with-dummies-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>df with dummies</a></span></li></ul></li></ul></li><li><span><a href="#individually-assess-variables-compared-to-price" data-toc-modified-id="individually-assess-variables-compared-to-price-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>individually assess variables compared to price</a></span><ul class="toc-item"><li><span><a href="#assessing-grade-affect-on-price,-converting-grade-to-grade/13-as-there-are-only-13-possible-grades" data-toc-modified-id="assessing-grade-affect-on-price,-converting-grade-to-grade/13-as-there-are-only-13-possible-grades-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>assessing grade affect on price, converting grade to grade/13 as there are only 13 possible grades</a></span></li></ul></li><li><span><a href="#build-model-with-df" data-toc-modified-id="build-model-with-df-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>build model with df</a></span><ul class="toc-item"><li><span><a href="#where-X=-data,-with-dummies,-y-=price" data-toc-modified-id="where-X=-data,-with-dummies,-y-=price-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>where X= data, with dummies, y =price</a></span></li><li><span><a href="#where-X=data,-y-=-price,-no-dummies" data-toc-modified-id="where-X=data,-y-=-price,-no-dummies-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>where X=data, y = price, no dummies</a></span></li><li><span><a href="#regression-on-datasets-with-dummies" data-toc-modified-id="regression-on-datasets-with-dummies-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>regression on datasets with dummies</a></span></li><li><span><a href="#where-X=-minmax-scaling-applied-to-dataset,-y=log-transformed-price" data-toc-modified-id="where-X=-minmax-scaling-applied-to-dataset,-y=log-transformed-price-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>where X= minmax scaling applied to dataset, y=log transformed price</a></span></li><li><span><a href="#model-where-X=-data,-no-scaling-applied-to-continuous/y-=-log-transformed-price" data-toc-modified-id="model-where-X=-data,-no-scaling-applied-to-continuous/y-=-log-transformed-price-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>model where X= data, no scaling applied to continuous/y = log transformed price</a></span><ul class="toc-item"><li><span><a href="#same-as-above-dropping-sqm_lot" data-toc-modified-id="same-as-above-dropping-sqm_lot-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>same as above dropping sqm_lot</a></span></li></ul></li></ul></li><li><span><a href="#final-model-assessment" data-toc-modified-id="final-model-assessment-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>final model assessment</a></span><ul class="toc-item"><li><span><a href="#using-model-with-no-scaling,---with-target-=-price/10000,-log-transformed-price,-dropping-sqm_lot" data-toc-modified-id="using-model-with-no-scaling,---with-target-=-price/10000,-log-transformed-price,-dropping-sqm_lot-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>using model with no scaling,   with target = price/10000, log transformed price, dropping sqm_lot</a></span></li><li><span><a href="#y-=-log-transformed-price(og)" data-toc-modified-id="y-=-log-transformed-price(og)-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>y = log transformed price(og)</a></span></li><li><span><a href="#model-with-price-/10000-log-transformed" data-toc-modified-id="model-with-price-/10000-log-transformed-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>model with price /10000 log transformed</a></span></li><li><span><a href="#model-with-price-log" data-toc-modified-id="model-with-price-log-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>model with price log</a></span></li><li><span><a href="#residuals" data-toc-modified-id="residuals-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>residuals</a></span></li><li><span><a href="#train/test-split-data" data-toc-modified-id="train/test-split-data-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>train/test split data</a></span><ul class="toc-item"><li><span><a href="#visualize-training-data-vs-test-data" data-toc-modified-id="visualize-training-data-vs-test-data-8.6.1"><span class="toc-item-num">8.6.1&nbsp;&nbsp;</span>visualize training data vs test data</a></span></li></ul></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Conclusion</a></span><ul class="toc-item"><li><span><a href="#Feature-Engineering-and-Feature-Selection" data-toc-modified-id="Feature-Engineering-and-Feature-Selection-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Feature Engineering and Feature Selection</a></span></li></ul></li><li><span><a href="#Future-Assessments" data-toc-modified-id="Future-Assessments-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Future Assessments</a></span></li></ul></div>

# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Brennan Mathis
# * Student pace: part time
# * Scheduled project review date/time:
# * Instructor name: Victor G
# * Blog post URL:

# %% [markdown]
# H0 = features of a house have no effect on price/value of house
# Ha = features of a house have an effect on price/value of house

# %% [markdown]
# # data scrubbing and cleaning

# %% [markdown]
# ## import modules and data

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm

# %%
data = pd.read_csv("kc_house_data.csv")

# %% [markdown]
# ## functions

# %%
# normalize values
def norm_feat(series):
    return (series - series.mean())/series.std()

# %%
#one hot encode return dummies
def one_hot(series):
    return (pd.get_dummies(series, prefix=series.name, drop_first=True))

# %%
# perform log transformation
def get_log(series):
    return np.log(series)

# %% [markdown]
# In metric terms a square foot is a square with sides 0.3048 metres in length.
# One square foot is the equivalent to 0.09290304 square metres

# %%
# 1 sq ft = 0.092903 sq m
def ft_to_meter(x):
    return x * 0.092903

# %%
# step wise selection to assess p values
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.01, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Arguments:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    Always set threshold_in < threshold_out to avoid infinite looping.
    See https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

# %% [markdown]
# ## create series to present price in readable way for visualizations

# %%
# create series to present price in readable way for visualizations
data['price/10000'] = data['price']/10000
data['price/1000'] = data['price']/1000

# %% [markdown]
# ## fill in missing values (NaN) where applicable

# %%
data.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# price/10000         0
# price/1000          0
# dtype: int64

# %%
#fill nan values
data.waterfront.unique()
# Out:
# array([nan,  0.,  1.])

# %%
data['waterfront'] = data.waterfront.fillna(0)

# %%
# convert to int
data['waterfront'] = data['waterfront'].astype(int)

# %%
#fill nan values
data.yr_renovated = data.yr_renovated.fillna(0)

# %% [markdown]
# ## assess whether renovation has direct impact on home price

# %%
data.yr_renovated = data.yr_renovated.astype(int)

# %%
# create dataframes for renovated and non renovated homes for comparison
renovated = data[data["yr_renovated"]>1]
non_renovated = data[data["yr_renovated"]<1]

# %%
non_renovated.shape
# Out:
# (20853, 23)

# %%
non_renovated.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.085300e+04  2.085300e+04  20853.000000  20853.000000  20853.000000
# mean   4.586246e+09  5.321403e+05      3.370115      2.109037   2071.507313
# std    2.875507e+09  3.518947e+05      0.920686      0.763118    910.209733
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.125059e+09  3.200000e+05      3.000000      1.500000   1420.000000
# 50%    3.904931e+09  4.490000e+05      3.000000      2.250000   1900.000000
# 75%    7.326200e+09  6.350000e+05      4.000000      2.500000   2540.000000
# max    9.900000e+09  6.890000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.085300e+04  20853.000000  20853.000000  20791.000000  20853.000000
# mean   1.505959e+04      1.493718      0.005611      0.220769      3.416631
# std    4.152180e+04      0.541274      0.074696      0.741496      0.653691
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.050000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.620000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.062600e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#        ...    sqft_above      yr_built  yr_renovated       zipcode  \
# count  ...  20853.000000  20853.000000       20853.0  20853.000000
# mean   ...   1785.381432   1972.125114           0.0  98077.321345
# std    ...    826.815098     28.974784           0.0     53.357658
# min    ...    370.000000   1900.000000           0.0  98001.000000
# 25%    ...   1190.000000   1953.000000           0.0  98032.000000
# 50%    ...   1560.000000   1976.000000           0.0  98065.000000
# 75%    ...   2210.000000   1998.000000           0.0  98117.000000
# max    ...   9410.000000   2015.000000           0.0  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15   price/10000  \
# count  20853.000000  20853.000000   20853.000000   20853.000000  20853.000000
# mean      47.559363   -122.212268    1986.539778   12735.717499     53.214032
# std        0.139088      0.140805     684.145745   27311.862519     35.189473
# min       47.155900   -122.519000     399.000000     651.000000      7.800000
# 25%       47.468600   -122.327000    1490.000000    5100.000000     32.000000
# 50%       47.570600   -122.227000    1840.000000    7622.000000     44.900000
# 75%       47.678300   -122.123000    2360.000000   10061.000000     63.500000
# max       47.777600   -121.315000    6210.000000  871200.000000    689.000000
#
#         price/1000
# count  20853.00000
# mean     532.14032
# std      351.89473
# min       78.00000
# 25%      320.00000
# 50%      449.00000
# 75%      635.00000
# max     6890.00000
#
# [8 rows x 21 columns]

# %%
renovated.shape
# Out:
# (744, 23)

# %%
renovated.describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  7.440000e+02  7.440000e+02  744.000000  744.000000    744.000000
# mean   4.418716e+09  7.689019e+05    3.459677    2.306116   2327.377688
# std    2.908265e+09  6.271258e+05    1.068823    0.898233   1089.002040
# min    3.600057e+06  1.100000e+05    1.000000    0.750000    520.000000
# 25%    1.922985e+09  4.122500e+05    3.000000    1.750000   1560.000000
# 50%    3.899100e+09  6.075020e+05    3.000000    2.250000   2200.000000
# 75%    7.014200e+09  9.000000e+05    4.000000    2.750000   2872.500000
# max    9.829200e+09  7.700000e+06   11.000000    8.000000  12050.000000
#
#             sqft_lot      floors  waterfront        view   condition  ...  \
# count     744.000000  744.000000  744.000000  743.000000  744.000000  ...
# mean    16215.530914    1.504704    0.038978    0.600269    3.219086  ...
# std     38235.308760    0.493202    0.193674    1.212180    0.520494  ...
# min      1024.000000    1.000000    0.000000    0.000000    1.000000  ...
# 25%      5000.000000    1.000000    0.000000    0.000000    3.000000  ...
# 50%      7375.000000    1.500000    0.000000    0.000000    3.000000  ...
# 75%     12670.750000    2.000000    0.000000    0.000000    3.000000  ...
# max    478288.000000    3.000000    1.000000    4.000000    5.000000  ...
#
#         sqft_above     yr_built  yr_renovated       zipcode         lat  \
# count   744.000000   744.000000    744.000000    744.000000  744.000000
# mean   1878.719086  1939.455645   1995.928763  98095.623656   47.580564
# std     849.441413    22.088850     15.599946     54.861316    0.120855
# min     520.000000  1900.000000   1934.000000  98001.000000   47.196000
# 25%    1267.500000  1921.000000   1987.000000  98040.000000   47.523350
# 50%    1730.000000  1941.500000   2000.000000  98112.000000   47.602800
# 75%    2300.000000  1955.000000   2007.250000  98126.000000   47.670950
# max    8570.000000  2003.000000   2015.000000  98199.000000   47.777000
#
#              long  sqft_living15     sqft_lot15  price/10000   price/1000
# count  744.000000     744.000000     744.000000   744.000000   744.000000
# mean  -122.262043    1988.877688   13390.768817    76.890189   768.901892
# std      0.129586     715.440144   26213.648057    62.712579   627.125794
# min   -122.497000     828.000000    1281.000000    11.000000   110.000000
# 25%   -122.358000    1460.000000    5000.000000    41.225000   412.250000
# 50%   -122.292000    1850.000000    7455.000000    60.750200   607.502000
# 75%   -122.210000    2380.000000   10925.750000    90.000000   900.000000
# max   -121.359000    5500.000000  310582.000000   770.000000  7700.000000
#
# [8 rows x 21 columns]

# %%
# price mean
renovated.price.mean()
# Out:
# 768901.8924731183

# %%
# grade mean
renovated.grade.mean()
# Out:
# 7.752688172043011

# %%
# price standard deviation
renovated.price.std()
# Out:
# 627125.7940449169

# %%
# price mean
non_renovated.price.mean()
# Out:
# 532140.319858054

# %%
# grade mean
non_renovated.grade.mean()
# Out:
# 7.654534119790918

# %%
# price std
non_renovated.price.std()
# Out:
# 351894.7303060593

# %%
# assess the number of non renovated homes over grade 7 (renovated homes grade mean)
non_renovated_grade = non_renovated[non_renovated["grade"]>7]
non_renovated_grade.shape
# Out:
# (9925, 23)

# %%
len(non_renovated_grade)/len(non_renovated)
# Out:
# 0.47595070253680527

# %%
len(non_renovated)/len(data)
# Out:
# 0.9655507709404084

# %%
len(renovated)/len(data)
# Out:
# 0.03444922905959161

# %%
# price mean
non_renovated_grade.price.mean()
# Out:
# 701337.1032745591

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(18,10))
sns.kdeplot(non_renovated['price/10000'], color='r', shade=True, Label='Non-Renovated Homes')
sns.kdeplot(renovated['price/10000'], color='g', shade=True, Label='Renovated Homes') 

plt.xlabel('Price/10000', fontsize=20) 
plt.ylabel('Probability Density', fontsize=20) 
plt.title('Renovated vs Non-Renovated Home Price Density', fontsize=30)
plt.show()

# %% [markdown]
# i will be dropping the year renovated column due to the fact that many non renovated properties with same grade from king county housing deparment sell for similiar price

# %% [markdown]
# ## convert date column to DateTime format, then separate date to month, day, year columns due to datetime being unusable in regression, (drop 'data' column once all necessary calculations have been done)

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'price/10000',
#        'price/1000'],
#       dtype='object')

# %%
data['date']= pd.to_datetime(data['date'])

# %%
data['sale_year'] = data.date.dt.year

# %% [markdown]
# ## create age column from date of sale and year built

# %%
# subtract the year built from sale year to get age of home when sold
data['age'] = data['sale_year'] - (data['yr_built'] - 1)

# %%
renovated_df = data.loc[data['yr_renovated'] > 1]
non_reno_df = data.loc[data['yr_renovated'] < 1]

# %% [markdown]
# ## find out if there are historic homes on dataset. washington state qualifies as over 50 and retaining original structure. assess whether these are abnormalities

# %%
ren_historic_df = data[(data.age > 50) & (data.yr_renovated > 1)]
ren_historic_df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570
# 35     9547205180 2014-06-13   696000.0         3       2.50         2300
# 95     1483300570 2014-09-08   905000.0         4       2.50         3300
# 103    2450000295 2014-10-07  1090000.0         3       2.50         2920
# 125    4389200955 2015-03-02  1450000.0         4       2.75         2750
# ...           ...        ...        ...       ...        ...          ...
# 19472  8075400530 2014-06-27   234000.0         4       1.00         1390
# 19497  6821101285 2014-08-14   819000.0         3       1.75         1850
# 19524   923000115 2014-10-29   588000.0         3       1.75         2310
# 19602  6392000625 2014-07-12   451000.0         2       1.00          900
# 20428  4305600360 2015-02-25   500012.0         4       2.50         2400
#
#        sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode  \
# 1          7242     2.0           0   0.0  ...          1991    98125
# 35         3060     1.5           0   0.0  ...          2002    98115
# 95        10250     1.0           0   0.0  ...          1991    98040
# 103        8113     2.0           0   0.0  ...          2010    98004
# 125       17789     1.5           0   0.0  ...          1992    98004
# ...         ...     ...         ...   ...  ...           ...      ...
# 19472     18000     1.0           0   0.0  ...          2013    98032
# 19497      6000     1.5           0   0.0  ...          1999    98199
# 19524      7620     2.0           0   0.0  ...          1988    98177
# 19602      6000     1.0           0   0.0  ...          2004    98115
# 20428      9612     1.0           0   0.0  ...          2009    98059
#
#            lat     long  sqft_living15  sqft_lot15  price/10000  price/1000  \
# 1      47.7210 -122.319           1690        7639      53.8000     538.000
# 35     47.6827 -122.310           1590        3264      69.6000     696.000
# 95     47.5873 -122.249           1950        6045      90.5000     905.000
# 103    47.5814 -122.196           2370        8113     109.0000    1090.000
# 125    47.6141 -122.212           3060       11275     145.0000    1450.000
# ...        ...      ...            ...         ...          ...         ...
# 19472  47.3885 -122.284           1390       18000      23.4000     234.000
# 19497  47.6528 -122.401           1540        6000      81.9000     819.000
# 19524  47.7266 -122.363           2200        7672      58.8000     588.000
# 19602  47.6855 -122.289           1460        4800      45.1000     451.000
# 20428  47.4799 -122.127           2430        5539      50.0012     500.012
#
#        sale_year  age
# 1           2014   64
# 35          2014   85
# 95          2014   69
# 103         2014   65
# 125         2015  102
# ...          ...  ...
# 19472       2014   60
# 19497       2014  102
# 19524       2014   73
# 19602       2014   71
# 20428       2015   54
#
# [642 rows x 25 columns]

# %%
ren_historic_df.describe()
# Out:
#                  id         price    bedrooms   bathrooms  sqft_living  \
# count  6.420000e+02  6.420000e+02  642.000000  642.000000    642.00000
# mean   4.420703e+09  7.567015e+05    3.439252    2.266745   2284.76947
# std    2.903391e+09  6.206395e+05    1.094684    0.888923   1049.53633
# min    3.600057e+06  1.340000e+05    1.000000    0.750000    520.00000
# 25%    1.912710e+09  4.117500e+05    3.000000    1.750000   1540.00000
# 50%    3.980950e+09  6.084520e+05    3.000000    2.000000   2180.00000
# 75%    7.012701e+09  8.931250e+05    4.000000    2.750000   2802.25000
# max    9.828702e+09  7.700000e+06   11.000000    8.000000  12050.00000
#
#             sqft_lot      floors  waterfront        view   condition  ...  \
# count     642.000000  642.000000  642.000000  641.000000  642.000000  ...
# mean    15300.685358    1.500000    0.034268    0.597504    3.239875  ...
# std     38856.642185    0.484551    0.182058    1.202962    0.540207  ...
# min      1033.000000    1.000000    0.000000    0.000000    1.000000  ...
# 25%      4803.750000    1.000000    0.000000    0.000000    3.000000  ...
# 50%      7082.500000    1.500000    0.000000    0.000000    3.000000  ...
# 75%     11622.000000    2.000000    0.000000    0.000000    3.000000  ...
# max    478288.000000    3.000000    1.000000    4.000000    5.000000  ...
#
#        yr_renovated       zipcode         lat        long  sqft_living15  \
# count    642.000000    642.000000  642.000000  642.000000     642.000000
# mean    1994.738318  98099.755452   47.587178 -122.275407    1951.761682
# std       16.174942     53.636650    0.117805    0.121197     694.879391
# min     1934.000000  98001.000000   47.196000 -122.497000     830.000000
# 25%     1985.000000  98052.000000   47.529475 -122.361000    1440.000000
# 50%     1998.000000  98115.000000   47.609950 -122.302500    1810.000000
# 75%     2007.000000  98133.000000   47.673925 -122.221000    2340.000000
# max     2015.000000  98199.000000   47.776300 -121.359000    5500.000000
#
#           sqft_lot15  price/10000   price/1000    sale_year         age
# count     642.000000   642.000000   642.000000   642.000000  642.000000
# mean    12584.098131    75.670153   756.701533  2014.274143   81.369159
# std     25877.346653    62.063951   620.639510     0.446429   18.188796
# min      1281.000000    13.400000   134.000000  2014.000000   51.000000
# 25%      5000.000000    41.175000   411.750000  2014.000000   65.000000
# 50%      7000.000000    60.845200   608.452000  2014.000000   79.000000
# 75%     10264.750000    89.312500   893.125000  2015.000000   97.000000
# max    310582.000000   770.000000  7700.000000  2015.000000  116.000000
#
# [8 rows x 23 columns]

# %%
ren_historic_df.price.mean()
# Out:
# 756701.5327102804

# %%
non_ren_historic_df =  data[(data.age > 50) & (data.yr_renovated < 1)]
non_ren_historic_df
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3        1.0         1180
# 2      5631500400 2015-02-25  180000.0         2        1.0          770
# 7      2008000270 2015-01-15  291850.0         3        1.5         1060
# 8      2414600126 2015-04-15  229500.0         3        1.0         1780
# 10     1736800520 2015-04-03  662500.0         3        2.5         3560
# ...           ...        ...       ...       ...        ...          ...
# 21287   522059130 2015-04-29  465000.0         3        1.0         1150
# 21316  9266700190 2015-05-11  245000.0         1        1.0          390
# 21327  2924079034 2014-09-25  332220.0         3        1.5         2580
# 21454   121039156 2015-01-09  249000.0         3        1.0         1030
# 21567  2025049203 2014-06-10  399950.0         2        1.0          710
#
#        sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode  \
# 0          5650     1.0           0   0.0  ...             0    98178
# 2         10000     1.0           0   0.0  ...             0    98028
# 7          9711     1.0           0   NaN  ...             0    98198
# 8          7470     1.0           0   0.0  ...             0    98146
# 10         9796     1.0           0   0.0  ...             0    98007
# ...         ...     ...         ...   ...  ...           ...      ...
# 21287     18200     1.0           0   0.0  ...             0    98058
# 21316      2000     1.0           0   0.0  ...             0    98103
# 21327     47480     1.0           0   0.0  ...             0    98024
# 21454     24750     1.0           0   2.0  ...             0    98023
# 21567      1157     2.0           0   0.0  ...             0    98102
#
#            lat     long  sqft_living15  sqft_lot15  price/10000  price/1000  \
# 0      47.5112 -122.257           1340        5650       22.190      221.90
# 2      47.7379 -122.233           2720        8062       18.000      180.00
# 7      47.4095 -122.315           1650        9711       29.185      291.85
# 8      47.5123 -122.337           1780        8113       22.950      229.50
# 10     47.6007 -122.145           2210        8925       66.250      662.50
# ...        ...      ...            ...         ...          ...         ...
# 21287  47.4262 -122.187           1714       18200       46.500      465.00
# 21316  47.6938 -122.347           1340        5100       24.500      245.00
# 21327  47.5333 -121.933           1760       48181       33.222      332.22
# 21454  47.3343 -122.362           2810       28800       24.900      249.00
# 21567  47.6413 -122.329           1370        1173       39.995      399.95
#
#        sale_year  age
# 0           2014   60
# 2           2015   83
# 7           2015   53
# 8           2015   56
# 10          2015   51
# ...          ...  ...
# 21287       2015   57
# 21316       2015   96
# 21327       2014   62
# 21454       2015   73
# 21567       2014   72
#
# [8015 rows x 25 columns]

# %%
non_ren_historic_df.describe()
# Out:
#                  id         price     bedrooms    bathrooms  sqft_living  \
# count  8.015000e+03  8.015000e+03  8015.000000  8015.000000  8015.000000
# mean   4.469057e+09  4.966354e+05     3.174298     1.618590  1696.627199
# std    2.816738e+09  3.166074e+05     1.044523     0.654423   724.842751
# min    1.200019e+06  7.800000e+04     1.000000     0.500000   370.000000
# 25%    2.061450e+09  2.950000e+05     3.000000     1.000000  1170.000000
# 50%    3.935900e+09  4.250000e+05     3.000000     1.500000  1570.000000
# 75%    7.132801e+09  6.000000e+05     4.000000     2.000000  2080.000000
# max    9.900000e+09  3.650000e+06    33.000000     6.750000  7710.000000
#
#            sqft_lot       floors   waterfront         view    condition  ...  \
# count  8.015000e+03  8015.000000  8015.000000  7987.000000  8015.000000  ...
# mean   1.119232e+04     1.190643     0.007611     0.261800     3.657268  ...
# std    3.413447e+04     0.337750     0.086912     0.788216     0.763164  ...
# min    5.200000e+02     1.000000     0.000000     0.000000     1.000000  ...
# 25%    5.000000e+03     1.000000     0.000000     0.000000     3.000000  ...
# 50%    7.200000e+03     1.000000     0.000000     0.000000     4.000000  ...
# 75%    9.600000e+03     1.500000     0.000000     0.000000     4.000000  ...
# max    1.651359e+06     3.500000     1.000000     4.000000     5.000000  ...
#
#        yr_renovated       zipcode          lat         long  sqft_living15  \
# count        8015.0   8015.000000  8015.000000  8015.000000    8015.000000
# mean            0.0  98105.456893    47.586820  -122.288600    1703.783157
# std             0.0     53.911632     0.119622     0.098689     523.944732
# min             0.0  98001.000000    47.155900  -122.514000     460.000000
# 25%             0.0  98058.500000    47.509200  -122.355000    1340.000000
# 50%             0.0  98116.000000    47.600700  -122.308000    1600.000000
# 75%             0.0  98136.000000    47.682700  -122.255000    1950.000000
# max             0.0  98199.000000    47.777600  -121.315000    4950.000000
#
#           sqft_lot15  price/10000   price/1000    sale_year          age
# count    8015.000000  8015.000000  8015.000000  8015.000000  8015.000000
# mean     9412.897817    49.663538   496.635385  2014.332002    73.805739
# std     17228.379012    31.660744   316.607438     0.470961    17.973924
# min       660.000000     7.800000    78.000000  2014.000000    51.000000
# 25%      5000.000000    29.500000   295.000000  2014.000000    59.000000
# 50%      7200.000000    42.500000   425.000000  2014.000000    68.000000
# 75%      9146.500000    60.000000   600.000000  2015.000000    89.000000
# max    425581.000000   365.000000  3650.000000  2015.000000   116.000000
#
# [8 rows x 23 columns]

# %%
non_ren_historic_df.price.mean()
# Out:
# 496635.38477854023

# %%
non_ren_historic_df.median()
# Out:
# id               3.935900e+09
# price            4.250000e+05
# bedrooms         3.000000e+00
# bathrooms        1.500000e+00
# sqft_living      1.570000e+03
# sqft_lot         7.200000e+03
# floors           1.000000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        4.000000e+00
# grade            7.000000e+00
# sqft_above       1.260000e+03
# yr_built         1.947000e+03
# yr_renovated     0.000000e+00
# zipcode          9.811600e+04
# lat              4.760070e+01
# long            -1.223080e+02
# sqft_living15    1.600000e+03
# sqft_lot15       7.200000e+03
# price/10000      4.250000e+01
# price/1000       4.250000e+02
# sale_year        2.014000e+03
# age              6.800000e+01
# dtype: float64

# %%
historic_df_mil =  data[(data.age > 100) & (data.price > 1000000)]
historic_df_mil
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 125    4389200955 2015-03-02  1450000.0         4       2.75         2750
# 282    7424700045 2015-05-13  2050000.0         5       3.00         3830
# 779    1954700695 2014-06-12  2250000.0         5       4.25         4860
# 1326   4232400860 2014-06-30  1200000.0         4       2.00         2120
# 1704   1336300445 2015-04-22  1270000.0         4       3.00         3130
# ...           ...        ...        ...       ...        ...          ...
# 18908   809002290 2014-05-19  1190000.0         4       3.00         2240
# 19118  7151700360 2014-12-11  1030000.0         5       3.25         2680
# 19257  1337300145 2014-07-21  1800000.0         4       2.50         3320
# 19261  2397100705 2014-07-14  1520000.0         4       4.25         3650
# 19510  7011201325 2014-10-28  1010000.0         4       2.75         2940
#
#        sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode  \
# 125       17789     1.5           0   0.0  ...          1992    98004
# 282        8480     2.0           0   1.0  ...          1994    98122
# 779        9453     1.5           0   1.0  ...             0    98112
# 1326       3360     2.0           0   0.0  ...             0    98112
# 1704       2646     2.5           0   0.0  ...             0    98102
# ...         ...     ...         ...   ...  ...           ...      ...
# 18908      6000     1.5           0   0.0  ...             0    98109
# 19118      3011     2.0           0   0.0  ...             0    98122
# 19257      8325     2.5           0   0.0  ...             0    98112
# 19261      5328     1.5           0   0.0  ...          2014    98119
# 19510      5400     1.5           0   2.0  ...             0    98119
#
#            lat     long  sqft_living15  sqft_lot15  price/10000  price/1000  \
# 125    47.6141 -122.212           3060       11275        145.0      1450.0
# 282    47.6166 -122.287           3050        7556        205.0      2050.0
# 779    47.6196 -122.286           3150        8557        225.0      2250.0
# 1326   47.6227 -122.310           2090        3600        120.0      1200.0
# 1704   47.6272 -122.316           2920        4500        127.0      1270.0
# ...        ...      ...            ...         ...          ...         ...
# 18908  47.6369 -122.350           2240        4250        119.0      1190.0
# 19118  47.6115 -122.287           3440        5165        103.0      1030.0
# 19257  47.6263 -122.314           3680        6050        180.0      1800.0
# 19261  47.6380 -122.362           1710        3600        152.0      1520.0
# 19510  47.6366 -122.369           1970        2008        101.0      1010.0
#
#        sale_year  age
# 125         2015  102
# 282         2015  111
# 779         2014  110
# 1326        2014  110
# 1704        2015  110
# ...          ...  ...
# 18908       2014  101
# 19118       2014  105
# 19257       2014  110
# 19261       2014  108
# 19510       2014  105
#
# [102 rows x 25 columns]

# %%
data_mil_df = data.loc[data['price'] > 1000000]
data_mil_df
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 5      7237550310 2014-05-12  1230000.0         4       4.50         5420
# 21     2524049179 2014-08-26  2000000.0         3       2.75         3050
# 49      822039084 2015-03-11  1350000.0         3       2.50         2753
# 69     1802000060 2014-06-12  1330000.0         5       2.25         3200
# 70     1525059190 2014-09-12  1040000.0         5       3.25         4770
# ...           ...        ...        ...       ...        ...          ...
# 21574  7430200100 2014-05-14  1220000.0         4       3.50         4910
# 21577  8672200110 2015-03-17  1090000.0         5       3.75         4170
# 21581   191100405 2015-04-21  1580000.0         4       3.25         3410
# 21584   249000205 2014-10-15  1540000.0         5       3.75         4470
# 21590  7936000429 2015-03-26  1010000.0         4       3.50         3510
#
#        sqft_lot  floors  waterfront  view  ...  yr_renovated  zipcode  \
# 5        101930     1.0           0   0.0  ...             0    98053
# 21        44867     1.0           0   4.0  ...             0    98040
# 49        65005     1.0           1   2.0  ...             0    98070
# 69        20158     1.0           0   0.0  ...             0    98004
# 70        50094     1.0           0   0.0  ...             0    98005
# ...         ...     ...         ...   ...  ...           ...      ...
# 21574      9444     1.5           0   0.0  ...             0    98074
# 21577      8142     2.0           0   2.0  ...             0    98056
# 21581     10125     2.0           0   0.0  ...             0    98040
# 21584      8088     2.0           0   0.0  ...             0    98004
# 21590      7200     2.0           0   0.0  ...             0    98136
#
#            lat     long  sqft_living15  sqft_lot15  price/10000  price/1000  \
# 5      47.6561 -122.005           4760      101930        123.0      1230.0
# 21     47.5316 -122.233           4110       20336        200.0      2000.0
# 49     47.4041 -122.451           2680       72513        135.0      1350.0
# 69     47.6303 -122.215           3390       20158        133.0      1330.0
# 70     47.6525 -122.160           3530       38917        104.0      1040.0
# ...        ...      ...            ...         ...          ...         ...
# 21574  47.6502 -122.066           4560       11063        122.0      1220.0
# 21577  47.5354 -122.181           3030        7980        109.0      1090.0
# 21581  47.5653 -122.223           2290       10125        158.0      1580.0
# 21584  47.6321 -122.200           2780        8964        154.0      1540.0
# 21590  47.5537 -122.398           2050        6200        101.0      1010.0
#
#        sale_year  age
# 5           2014   14
# 21          2014   47
# 49          2015   63
# 69          2014   50
# 70          2014   42
# ...          ...  ...
# 21574       2014    8
# 21577       2015   10
# 21581       2015    9
# 21584       2014    7
# 21590       2015    7
#
# [1458 rows x 25 columns]

# %%
len(historic_df_mil)/len(data_mil_df)
# Out:
# 0.06995884773662552

# %% [markdown]
# ## assess whether renovating a historic home increases market value as far as price

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(18,10))
sns.kdeplot(non_ren_historic_df['price/10000'], color='y', shade=True, Label='Non-Renovated Historic Homes')
sns.kdeplot(ren_historic_df['price/10000'], color='b', shade=True, Label='Renovated Historic Homes') 

plt.xlabel('price/10000') 
plt.ylabel('Probability Density') 
plt.show()

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(18,10))
sns.distplot(non_ren_historic_df['price'], bins=20, color='y')
sns.distplot(ren_historic_df['price'], bins=20, color='b')

plt.xlabel('price/10000') 
plt.ylabel('Probability Density') 
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.set_style(style="whitegrid",rc= {'patch.edgecolor': 'white'})

plt.figure(figsize=(30,20))
x=ren_historic_df.grade
y=ren_historic_df["price/10000"]
sns.violinplot(x, y, data=ren_historic_df, palette="mako_r")


plt.xlabel('Grade', fontsize=20) 
plt.ylabel('Price/$10,000', fontsize=20) 
plt.title('Home Grade Affect on Value of Historic Renovated Home', fontsize=30)
plt.tick_params(labelsize=20)
plt.show()

# %%
sns.set_style(style="whitegrid",rc= {'patch.edgecolor': 'white'})
plt.figure(figsize=(18,10))
x=ren_historic_df.grade
y=ren_historic_df["price/10000"]
sns.violinplot(x, y, data=non_ren_historic_df, palette="mako_r", saturation=1)

plt.xlabel('Grade', fontsize=20) 
plt.ylabel('Price/$10,000', fontsize=20) 
plt.title('Home Grade Affect on Value of Historic Non-Renovated Home', fontsize=30)
plt.tick_params(labelsize=20)
plt.show()

# %% [markdown]
# 1/3 of the properties with listed price over 1 million dollars qualifies as possible historic home

# %% [markdown]
# ### drop columns not to be utilized

# %%
data.drop(['yr_renovated', 'waterfront', 'view'], axis=1, inplace=True)

# %% [markdown]
# ## sqft_basement column contains string characters, remove these and convert to int to match other similar columns

# %%
#convert to int format, coercing strings to 0
data['sqft_basement'] = pd.to_numeric(data['sqft_basement'], 
                        downcast= 'integer', errors ='coerce')

# %%
# replace missing values using data provided for homes without nan values
# sqft_basement + sqft_above = sqft_living
data['sqft_basement'] = data['sqft_basement'].fillna(data['sqft_living'] 
                             - data['sqft_above'])
data['sqft_basement'] = data['sqft_basement'].astype(int)

# %% [markdown]
# this column will probably be dropped due to direct correlation to sqft_living (and sqft_above )

# %% [markdown]
# ## convert sq_ft areas to square meters

# %%
# ft_to_meters 
data['sqm_living'] = ft_to_meter(data.sqft_living)
data['sqm_living15'] = ft_to_meter(data.sqft_living15)
data['sqm_lot'] = ft_to_meter(data.sqft_lot)
data['sqm_lot15'] = ft_to_meter(data.sqft_lot15)

# %% [markdown]
# omitting sqft_above and sqft_basement due to correlation with sqft_living, and will most likely be dropped

# %% [markdown]
# ##  bedrooms outlier present as 33 bedroom house, appears to be typo due to other info, should be 3 bedrooms as this listing only has 1.75 bathrooms

# %%
data['bedrooms'].describe()
# Out:
# count    21597.000000
# mean         3.373200
# std          0.926299
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %%
data.loc[data["bedrooms"] == 33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15856  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  condition  grade  ...  sqft_living15  sqft_lot15  \
# 15856      6000     1.0          5      7  ...           1330        4700
#
#        price/10000  price/1000  sale_year  age  sqm_living  sqm_living15  \
# 15856         64.0       640.0       2014   68   150.50286     123.56099
#
#        sqm_lot  sqm_lot15
# 15856  557.418   436.6441
#
# [1 rows x 26 columns]

# %%
data["bedrooms"].replace({33: 3}, inplace=True)

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(18,10))

plt.figure(figsize=(18,10))
data['bedrooms'].hist()
plt.xlabel('Number of Bedrooms in Home', fontsize=20) 
plt.ylabel('Count', fontsize=20) 
plt.title('Distribution of Bedroom Count Per Home', fontsize=20)
plt.show()

# %% [markdown]
# data = data[data.bathrooms < 6]
# data = data[data.bedrooms < ]
# data.bathrooms.astype(float)

# %%
data = data[data.bathrooms > 0.75]

# %%
data.shape
# Out:
# (21522, 26)

# %%
sns.set_style(style="whitegrid",rc= {'patch.edgecolor': 'white'})

plt.figure(figsize=(18,10))
sns.violinplot(x="bedrooms", y="price/10000",
                    data=data, palette="plasma")
plt.xlabel('Bedrooms', fontsize=20) 
plt.ylabel('Price', fontsize=20) 
plt.title('Number of Bedrooms Affect on Value', fontsize=30)
plt.show()

# %%
print(data.price.mean().round(2))
print('--------------')
bed1 = data.loc[(data['bedrooms'] == 1)]
bed2 = data.loc[(data['bedrooms'] == 2)]
bed3 = data.loc[(data['bedrooms'] == 3)]
bed4 = data.loc[(data['bedrooms'] ==4)]
bed5 = data.loc[(data['bedrooms']==5)]
bed6 = data.loc[(data['bedrooms']==6)]
b1m = (bed1.price.mean().round(2))
b2m = (bed2.price.mean().round(2))
b3m = (bed3.price.mean().round(2))
b4m = (bed4.price.mean().round(2))
b5m = (bed5.price.mean().round(2))
b6m = (bed6.price.mean().round(2))
print(b1m)
print(b2m)
print(b3m)
print(b4m)
print(b5m)
print(b6m)
print('--------------')

print((b1m/1).round(2))
print((b2m/2).round(2))
print((b3m/3).round(2))
print((b4m/4).round(2))
print((b5m/5).round(2))
print((b6m/6).round(2))
# Out:
# 541162.3
# --------------
# 329413.6
# 402244.81
# 466546.75
# 635700.12
# 786874.13
# 825853.5
# --------------
# 329413.6
# 201122.4
# 155515.58
# 158925.03
# 157374.83
# 137642.25

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(18,10))

br = data.groupby('bedrooms').price.mean().plot()
plt.xlabel('Bedrooms', fontsize=20) 
plt.ylabel('Price Mean', fontsize=20) 
plt.title('Average Price by Bedroom Count', fontsize=30)
plt.show()

# %% [markdown]
# ## assessing grade category

# %% [markdown]
# * from king county website regarding grade category
#
# Represents the construction quality of improvements. Grades run from grade 1 to 13. Generally defined as:
#
# 1-3 Falls short of minimum building standards. Normally cabin or inferior structure.
#
# 4 Generally older, low quality construction. Does not meet code.
#
# 5 Low construction costs and workmanship. Small, simple design.
#
# 6 Lowest grade currently meeting building code. Low quality materials and simple designs.
#
# 7 Average grade of construction and design. Commonly seen in plats and older sub-divisions.
#
# 8 Just above average in construction and design. Usually better materials in both the exterior and interior finish work.
#
# 9 Better architectural design with extra interior and exterior design and quality.
#
# 10 Homes of this quality generally have high quality features. Finish work is better and more design quality is seen in the floor plans. Generally have a larger square footage.
#
# 11 Custom design and higher quality finish work with added amenities of solid woods, bathroom fixtures and more luxurious options.
#
# 12 Custom design and excellent builders. All materials are of the highest quality and all conveniences are present.
#
# 13 Generally custom designed and built. Mansion level. Large amount of highest quality cabinet work, wood trim, marble, entry ways etc.

# %%
#removing homes that do not meet code
data = data[data.grade > 5]

# %% [markdown]
# ### assess the affect that the grade of the house hs on the sale value

# %%
plt.figure(figsize=(18,10))
sns.violinplot(x="grade", y="price/10000",
                    data=data, palette="rainbow")
plt.xlabel('Grade', fontsize=20) 
plt.ylabel('Price', fontsize=20) 
plt.title('Home Grade Affect on Value', fontsize=30)
plt.show()

# %% [markdown]
# ### assess condition category

# %% [markdown]
# 1 = Poor- Worn out. Repair and overhaul needed on painted surfaces, roofing, plumbing, heating and numerous functional inadequacies. Excessive deferred maintenance and abuse, limited value-in-use, approaching abandonment or major reconstruction; reuse or change in occupancy is imminent. Effective age is near the end of the scale regardless of the actual chronological age.
#
# 2 = Fair- Badly worn. Much repair needed. Many items need refinishing or overhauling, deferred maintenance obvious, inadequate building utility and systems all shortening the life expectancy and increasing the effective age.
#
# 3 = Average- Some evidence of deferred maintenance and normal obsolescence with age in that a few minor repairs are needed, along with some refinishing. All major components still functional and contributing toward an extended life expectancy. Effective age and utility is standard for like properties of its class and usage.
#
# 4 = Good- No obvious maintenance required but neither is everything new. Appearance and utility are above the standard and the overall effective age will be lower than the typical property.
#
# 5= Very Good- All items well maintained, many having been overhauled and repaired as they have shown signs of wear, increasing the life expectancy and lowering the effective age with little deterioration or obsolescence evident with a high degree of utility.

# %% [markdown]
# data = data[data.condition > 2]

# %% [markdown]
# ### assess lot size and home type

# %%
under_acres_df = data.loc[data["sqft_lot"] < 43560]

# %%
over_one_acre = data.loc[data["sqft_lot"] > 43560]

# %%
over_one_acre.price.mean()
# Out:
# 678108.5

# %%
under_acres_df.price.mean()
# Out:
# 537559.7014777838

# %%
plt.figure(figsize=(18,10))
sns.kdeplot(under_acres_df['price/10000'], color='r', shade=True, Label='Lot Size < 1 Acre')
sns.kdeplot(over_one_acre['price/10000'], color='g', shade=True, Label='Lot Size > 1 Acre') 
plt.title('Density Plot for Home Price')
plt.xlabel('price per 10000') 
plt.ylabel('Probability Density') 
plt.show()

# %% [markdown]
# ## assess for duplicates

# %%
data.nunique()
# Out:
# id               21113
# date               372
# price             3571
# bedrooms            11
# bathrooms           27
# sqft_living       1020
# sqft_lot          9687
# floors               6
# condition            5
# grade                8
# sqft_above         930
# sqft_basement      306
# yr_built           116
# zipcode             70
# lat               5016
# long               742
# sqft_living15      772
# sqft_lot15        8615
# price/10000       3571
# price/1000        3571
# sale_year            2
# age                117
# sqm_living        1020
# sqm_living15       772
# sqm_lot           9687
# sqm_lot15         8615
# dtype: int64

# %% [markdown]
# ## evaluate duplicate ids

# %%
dups = data[data['id'].duplicated(keep=False)]

# %%
dups.head()
# Out:
#              id       date      price  bedrooms  bathrooms  sqft_living  \
# 93   6021501535 2014-07-25   430000.0         3       1.50         1580
# 94   6021501535 2014-12-23   700000.0         3       1.50         1580
# 313  4139480200 2014-06-18  1380000.0         4       3.25         4290
# 314  4139480200 2014-12-09  1400000.0         4       3.25         4290
# 324  7520000520 2014-09-05   232000.0         2       1.00         1240
#
#      sqft_lot  floors  condition  grade  ...  sqft_living15  sqft_lot15  \
# 93       5000     1.0          3      8  ...           1570        4500
# 94       5000     1.0          3      8  ...           1570        4500
# 313     12103     1.0          3     11  ...           3860       11244
# 314     12103     1.0          3     11  ...           3860       11244
# 324     12092     1.0          3      6  ...           1820        7460
#
#      price/10000  price/1000  sale_year  age  sqm_living  sqm_living15  \
# 93          43.0       430.0       2014   76   146.78674     145.85771
# 94          70.0       700.0       2014   76   146.78674     145.85771
# 313        138.0      1380.0       2014   18   398.55387     358.60558
# 314        140.0      1400.0       2014   18   398.55387     358.60558
# 324         23.2       232.0       2014   93   115.19972     169.08346
#
#          sqm_lot    sqm_lot15
# 93    464.515000   418.063500
# 94    464.515000   418.063500
# 313  1124.405009  1044.601332
# 314  1124.405009  1044.601332
# 324  1123.383076   693.056380
#
# [5 rows x 26 columns]

# %% [markdown]
# these occurences are from when the house was turned over and sold again, so I am keeping these rows

# %% [markdown]
# ## use latitude and longitude in existing dataset to get the distance from home to Seattle(closest major city)

# %% [markdown]
# ### import geopy modules

# %%
from geopy.distance import geodesic
from geopy import Point

# %%
#seattle coordinates
seattle_lat = 47.3635
seattle_long = -122.1959
seattle_point = Point(latitude=seattle_lat, longitude =seattle_long)

# %% [markdown]
# ### use geopy to set up points and calculate distance

# %%
#create points for each home using longitude and latitude
data['point'] = data.apply(lambda row: Point(latitude=row['lat'], 
                                             longitude=row['long']), axis=1)

# %%
# get distance in km from point to seattle
data['distance_seattle'] = data.apply(lambda row: 
                                      geodesic(row['point'], 
                                      seattle_point).km, axis=1)

# %%
# round distance to seattle values for simplicity
data['distance_seattle'] = data['distance_seattle'].round(3)

# %%
data.dtypes
# Out:
# id                           int64
# date                datetime64[ns]
# price                      float64
# bedrooms                     int64
# bathrooms                  float64
# sqft_living                  int64
# sqft_lot                     int64
# floors                     float64
# condition                    int64
# grade                        int64
# sqft_above                   int64
# sqft_basement                int64
# yr_built                     int64
# zipcode                      int64
# lat                        float64
# long                       float64
# sqft_living15                int64
# sqft_lot15                   int64
# price/10000                float64
# price/1000                 float64
# sale_year                    int64
# age                          int64
# sqm_living                 float64
# sqm_living15               float64
# sqm_lot                    float64
# sqm_lot15                  float64
# point                       object
# distance_seattle           float64
# dtype: object

# %% [markdown]
# ### assess data by zipcode

# %%
plt.figure(figsize=(18,10))
data_dist = data.groupby(['zipcode'])['distance_seattle'].mean()

data_dist.plot.bar()
plt.title('Zipcode by average distance to seattle')
# Out:
# Text(0.5, 1.0, 'Zipcode by average distance to seattle')

# %%
plt.figure(figsize=(18,10))
data_zip = data.groupby(['zipcode'])['price/10000'].mean()

data_zip.plot.bar()
plt.title('Mean Price Per Zipcode')
plt.ylabel('Average Price/$10,000')
# Out:
# Text(0, 0.5, 'Average Price/$10,000')

# %% [markdown]
# 98039 zipcode has most expensive properties

# %% [markdown]
# ### dropping columns

# %% [markdown]
# dropping point, lat and long columns, derived data needed from these for distance to seattle

# %%
data.drop(['point', 'lat', 'long'], axis=1, inplace=True)

# %% [markdown]
# drop date column due to derived data needed and this column will just cause issues. also dropping view column, as it just tells if the home has been viewed according to documentation. yr_built and sale_year used for age column and can be dropped as well. # drop condition due to the fact that it is contingent on perspective, whereas
# the 'grade' category is qualified by king county as an official rating
# regarding the home inspection and quality of materials

# %%
data.drop(['date','sale_year', 'yr_built', 'zipcode' ], axis=1, inplace=True)

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.128100e+04  2.128100e+04  21281.000000  21281.000000  21281.000000
# mean   4.590204e+09  5.445079e+05      3.388093      2.131808   2096.747521
# std    2.876689e+09  3.681367e+05      0.892843      0.762240    913.782621
# min    1.000102e+06  8.200000e+04      1.000000      1.000000    390.000000
# 25%    2.125400e+09  3.250000e+05      3.000000      1.750000   1440.000000
# 50%    3.905040e+09  4.548000e+05      3.000000      2.250000   1930.000000
# 75%    7.334500e+09  6.499500e+05      4.000000      2.500000   2560.000000
# max    9.900000e+09  7.700000e+06     11.000000      8.000000  13540.000000
#
#            sqft_lot        floors     condition         grade    sqft_above  \
# count  2.128100e+04  21281.000000  21281.000000  21281.000000  21281.000000
# mean   1.499660e+04      1.500117      3.408909      7.695691   1801.413420
# std    4.062604e+04      0.540761      0.645825      1.137148    826.026771
# min    5.200000e+02      1.000000      1.000000      6.000000    390.000000
# 25%    5.040000e+03      1.000000      3.000000      7.000000   1200.000000
# 50%    7.620000e+03      1.500000      3.000000      7.000000   1570.000000
# 75%    1.065000e+04      2.000000      4.000000      8.000000   2230.000000
# max    1.651359e+06      3.500000      5.000000     13.000000   9410.000000
#
#        ...  sqft_living15     sqft_lot15   price/10000    price/1000  \
# count  ...   21281.000000   21281.000000  21281.000000  21281.000000
# mean   ...    1995.193788   12707.300456     54.450795    544.507948
# std    ...     684.850377   27169.420990     36.813671    368.136712
# min    ...     399.000000     651.000000      8.200000     82.000000
# 25%    ...    1494.000000    5100.000000     32.500000    325.000000
# 50%    ...    1850.000000    7620.000000     45.480000    454.800000
# 75%    ...    2370.000000   10071.000000     64.995000    649.950000
# max    ...    6210.000000  871200.000000    770.000000   7700.000000
#
#                 age    sqm_living  sqm_living15        sqm_lot     sqm_lot15  \
# count  21281.000000  21281.000000  21281.000000   21281.000000  21281.000000
# mean      43.815986    194.794135    185.359488    1393.229337   1180.546334
# std       29.195397     84.893147     63.624655    3774.280674   2524.120718
# min        0.000000     36.232170     37.068297      48.309560     60.479853
# 25%       18.000000    133.780320    138.797082     468.231120    473.805300
# 50%       40.000000    179.302790    171.870550     707.920860    707.920860
# 75%       63.000000    237.831680    220.180110     989.416950    935.626113
# max      116.000000   1257.906620    576.927630  153416.205177  80937.093600
#
#        distance_seattle
# count      21281.000000
# mean          26.193832
# std           12.078914
# min            0.196000
# 25%           15.611000
# 50%           26.923000
# 75%           36.655000
# max           76.866000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## dropping all sqft columns due to conversion to metric system
# #dropping correlating columns above and basement

# %%
data.drop(['sqft_living', 'sqft_lot', 'sqft_living15','sqft_above', 'sqft_basement',
       'sqft_lot15', 'floors', 'sqm_lot15'], axis=1,inplace=True)

# %% [markdown]
# ## create id dataframe to attach once model is complete. remove id from dataset as it isn't relevant but just identifies homes

# %%
id_df = data['id']

# %%
data.drop(['id'], axis=1, inplace=True)

# %% [markdown]
# # check for multicollinearity

# %%
data.cov()

# %%
data.corr()

# %%
abs(data.corr()) > 0.75

# %% [markdown]
#  HIGHLY CORRELATED VARIABLES OVER 0.75:
#
#  sqft_living/bathrooms
#  sqft_above/sqft_living
#  bathrooms/sqft_living
#  bathrooms/sqft_above
#  sqft_living/sqft_living15
#  sqft_living/sqft_above
#  sqft_living15/sqft_above
#  sqft_lot/sqft_lot15
# Consider dropping redundant variables

# %% [markdown]
# ## heatmap for correlation assessment

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.heatmap(data.corr(), annot = True,  fmt='.2g', vmin=-1, vmax=1, center= 0, 
            cmap= 'coolwarm', linewidths=1, linecolor='black')

# %% [markdown]
# ## create new dataframe to further assess correlation

# %%
data_before = data.copy()
data_before.drop(['price', 'price/1000', 'price/10000'], axis=1, inplace=True)

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

X1 = sm.tools.add_constant(data_before)
                          
series_before = pd.Series([variance_inflation_factor(X1.values, i) for i in range(X1.shape[1])], index = X1.columns)

print('data before')


display(series_before)

# %% [markdown]
# no columns over 5, no need to reassess

# %% [markdown]
# ## scatter matrix to further assess multicollinearity

# %%
#define plot
pd.plotting.scatter_matrix(data, alpha=1, figsize = (30, 20))
# show plot
plt.show()

# %% [markdown]
# ### assess for outliers

# %%
# get summary
desc_data = data.describe()

# add std metric
desc_data.loc['+3_std'] = desc_data.loc['mean']+(desc_data.loc['std']*3)
desc_data.loc['-3_std'] = desc_data.loc['mean']-(desc_data.loc['std']*3)
desc_data

# %% [markdown]
# # data exploration

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.set_style('whitegrid')
sns.boxplot(x='bedrooms', y='sqm_living', data=data)

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.boxplot(x='bedrooms', y='price/10000', data=data)

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.boxplot(x='grade', y='price/10000', data=data)

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.boxplot(x='condition', y='price/10000', data=data)

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.boxplot(x='grade', y='age', data=data)
plt.title('Age of Property by Grade')

# %%
fig, ax = plt.subplots(figsize=(18,12))
sns.boxplot(x='condition', y='age', data=data)
plt.title('Age of Property by Condition')

# %% [markdown]
# ## histograms

# %%
data.hist(figsize=(18, 10))

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(data)

# %% [markdown]
# ## kde

# %%
data.sqm_living.plot.kde()
data.sqm_living15.plot.kde()
#data.sqm_lot.plot.kde()

plt.legend()
plt.show()

# %% [markdown]
# ## check price skew, visualize tranformed data, normalize price using log transformation

# %%
price_th_log = pd.DataFrame
price_th_log = get_log(data['price/1000'])
price_th_log.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", price_th_log.skew())
plt.hist(price_th_log)
plt.show()
# Out:
# Skew is: 0.4751113895525085

# %%
price_tenth_log = pd.DataFrame
price_tenth_log = get_log(data['price/10000'])
price_tenth_log.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", price_tenth_log.skew())
plt.hist(price_tenth_log)
plt.show()
# Out:
# Skew is: 0.4751113895525098

# %%
price_log= pd.DataFrame
price_log = get_log(data.price)
price_log.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", price_log.skew())
plt.hist(price_log)
plt.show()
# Out:
# Skew is: 0.47511138955251003

# %%
data['price'].plot.kde()
plt.legend()
plt.show()
print ("Skew is:", data['price'].skew())
plt.hist(data['price'])
plt.show()

# %% [markdown]
# skew shows this is not a normal distribution, neccessary for regression analysis

# %%
data['price/10000'].plot.kde()
plt.legend()
plt.show()
print ("Skew is:", data['price/10000'].skew())
plt.hist(data['price/10000'])
plt.show()

# %%
price_th_log = pd.DataFrame
price_th_log = np.log(data['price/1000'])
price_th_log.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", price_th_log.skew())
plt.hist(price_th_log)
plt.show()

# %%
price_tenth_log = pd.DataFrame
price_tenth_log = np.log(data['price/10000'])
price_tenth_log.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", price_tenth_log.skew())
plt.hist(price_tenth_log)
plt.show()

# %%
price_log= pd.DataFrame
price_log = get_log(data.price)
price_log.plot.kde()
plt.legend()
plt.show()
print ("Skew is:", price_log.skew())
plt.hist(price_log)
plt.show()

# %% [markdown]
# the skew after log transformation is much closer to normal, and is acceptable as 'fairly normal' as it is betwee -0.5 - 0.5

# %% [markdown]
# ## regression plots with transformed data

# %%
x = get_log(data.sqm_living)
y = data['price/10000']
sns.regplot(x, y, data=data)

# %%
x = get_log(data.sqm_living15)
y = data['price/10000']
sns.regplot(x, y, data=data)

# %%
x = norm_feat(data.distance_seattle)
y = data['price/10000']
sns.regplot(x, y, data=data)

# %% [markdown]
# ## age/price scatter

# %%
# define x & y
x = data['age']
y = data['price']
# create scatter plot
plt.figure(figsize=(10,6))
plt.plot(x, y, 'o', markersize= 2, label='House Sale Price')

# format
plt.title('Home Age x Price')
plt.xlabel('Age')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# ## distance to seattle/price scatter

# %%
x = data.distance_seattle
y = data['price/10000']
# create scatter plot
plt.figure(figsize=(10,6))
plt.plot(x, y, 'o', markersize= 2, label='House Sale Price')

# format
plt.title('Price X Distance(Seattle)')
plt.xlabel('Distance From Seattle (km)')
plt.ylabel('Price/$10,000')
plt.legend()
plt.show()

# %%
data['distance_seattle'].plot.kde()
plt.legend()
plt.show()
print ("Skew is:", data['distance_seattle'].skew())
plt.hist(data['distance_seattle'])
plt.show()

# %% [markdown]
# ## visualize categorical variables by price

# %%
data.dtypes

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(30,20), sharey=True)

categoricals = ['bathrooms', 'grade', 'bedrooms', 'age' ]

for col, ax in zip(categoricals, axes.flatten()):
    (data.groupby(col)               # group values together by column of interest
         .mean()['price/10000']        # take the mean of the saleprice for each group
         .sort_values()              # sort the groups in ascending order
         .plot
         .bar(ax=ax))                # create a bar graph on the ax
    
    ax.set_title(col)                # Make the title the name of the column
    
fig.tight_layout()

# %%
for col in zip(categoricals):
    print (data.groupby(col)               # group values together by column of interest
         .mean()['price/10000']        # take the mean of the saleprice for each group
         .sort_values(ascending=True) )

# %%
data['age_decade'] = data['age']//10

# %%
plt.figure(figsize=(18,10))
data_dist = data.groupby(['age_decade'])['price/10000'].mean()

data_dist.plot.bar()
plt.title('Age (by tens of years) by average price')

# %%
for column in data:
    data[column].plot.hist(density=True, label = column+'histogram')
    data[column].plot.kde(label =column+'kde')
    plt.legend()
    plt.show()

# %% [markdown]
# ### comparing grade and condition columns visually

# %%
plt.figure(figsize=(30,20))
sns.lmplot(x="sqm_living", y="price/10000",  hue="condition", data=data, scatter_kws={'alpha':0.5});

# %%
plt.figure(figsize=(30,20))
sns.lmplot(x="sqm_living", y="price/10000",  hue="grade", data=data, scatter_kws={'alpha':0.5});

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x="distance_seattle", y="price/10000",
                   data=data)
plt.title('Home Price by Distance to Seattle')
plt.ylabel('Price/$10,000')
plt.xlabel('Distance to Seattle (km)')

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x="age", y="price/10000",
                   data=data)
plt.title('Home Price by Age of House')

# %% [markdown]
# # one hot encoding, create new df: dummies

# %%
#round  bathrooms to simplify
data['bathrooms'] = data['bathrooms'].round()

# %%
# create bedroom dummies
dumbed = pd.get_dummies(data['bedrooms'], prefix= 'bed', drop_first=True)

#create grade dummies
dumgrade = pd.get_dummies(data['grade'], prefix= 'grade', drop_first=True)

#create condition dummies
con_dum = pd.get_dummies(data['condition'], prefix='condition', drop_first=True)

# create bathroom dummies
bath_dummy = pd.get_dummies(data['bathrooms'], prefix="bathrooms", drop_first=True)

# %% [markdown]
# ## create dummy df

# %%
dummies = pd.concat([dumgrade, dumbed, bath_dummy, con_dum], axis=1)

# %%
dummies.columns
# Out:
# Index(['grade_7', 'grade_8', 'grade_9', 'grade_10', 'grade_11', 'grade_12',
#        'grade_13', 'bed_2', 'bed_3', 'bed_4', 'bed_5', 'bed_6', 'bed_7',
#        'bed_8', 'bed_9', 'bed_10', 'bed_11', 'bathrooms_2.0', 'bathrooms_3.0',
#        'bathrooms_4.0', 'bathrooms_5.0', 'bathrooms_6.0', 'bathrooms_7.0',
#        'bathrooms_8.0', 'condition_2', 'condition_3', 'condition_4',
#        'condition_5'],
#       dtype='object')

# %% [markdown]
# # models

# %% [markdown]
# ## import libraries

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.formula.api import ols
from statsmodels.stats import diagnostic
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
from statsmodels.graphics.gofplots import ProbPlot

# %% [markdown]
# ### no dummies dataframe

# %%
data.drop(['price/10000', 'age_decade', 'price/1000' ], axis=1, inplace=True)

# %%
df = data.copy()

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'condition', 'grade', 'age',
#        'sqm_living', 'sqm_living15', 'sqm_lot', 'distance_seattle'],
#       dtype='object')

# %% [markdown]
# ### df with dummies

# %%
df_dummies = pd.concat([df, dummies,], axis=1)

# %%
df_dummies.drop(['grade', 'bedrooms', 'bathrooms', 'condition' ], axis=1, inplace=True)

# %%
## apply minmax scaling to continuous data
scaler = MinMaxScaler()

# %%
cont = data.copy()

# %%
cont.drop(['bathrooms', 'bedrooms', 'grade',   'condition',  ], axis=1,inplace=True)

# %%
cont.columns
# Out:
# Index(['price', 'age', 'sqm_living', 'sqm_living15', 'sqm_lot',
#        'distance_seattle'],
#       dtype='object')

# %%
cont[['sqm_living', 'sqm_living15', 'sqm_lot', 'distance_seattle', 'age', 'price']] = scaler.fit_transform(cont[['sqm_living', 'sqm_living', 'sqm_lot', 'distance_seattle', 'age', 'price']])

# %%
cont
# Out:
#           price       age  sqm_living  sqm_living15   sqm_lot  \
# 0      0.018364  0.517241    0.060076      0.060076  0.003108
# 1      0.059858  0.551724    0.165779      0.165779  0.004072
# 2      0.012864  0.715517    0.028897      0.028897  0.005743
# 3      0.068522  0.431034    0.119392      0.119392  0.002714
# 4      0.056183  0.250000    0.098099      0.098099  0.004579
# ...         ...       ...         ...           ...       ...
# 21590  0.121817  0.060345    0.237262      0.237262  0.004046
# 21591  0.051588  0.068966    0.069962      0.069962  0.000469
# 21592  0.036493  0.051724    0.086692      0.086692  0.000370
# 21593  0.041743  0.017241    0.146008      0.146008  0.003206
# 21595  0.041743  0.103448    0.092015      0.092015  0.001132
#
#        distance_seattle
# 0              0.219903
# 1              0.529764
# 2              0.541594
# 3              0.296818
# 4              0.393570
# ...                 ...
# 21590          0.337407
# 21591          0.371645
# 21592          0.506221
# 21593          0.266271
# 21595          0.275062
#
# [21281 rows x 6 columns]

# %% [markdown]
# # individually assess variables compared to price

# %%
results = [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)' ]]
for idx, val in enumerate(['bedrooms', 'bathrooms', 'grade', 'sqm_living15', 'condition', 'age', 
                           'distance_seattle', 'sqm_living', 'sqm_lot']):
    print ("King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~" + val)
    print ("-------------------------------------------------------------------------------------")

    f = 'price~' + val
   
    model = smf.ols(formula=f, data=data).fit()
    
    X_new = pd.DataFrame({val: [data[val].min(), data[val].max()]});
    preds = model.predict(X_new)
    data.plot(kind='scatter', x=val, y='price');
    plt.plot(X_new, preds, linewidth=2);
    plt.show()
    fig = plt.figure(figsize=(15,8))
    fig = sm.graphics.plot_regress_exog(model, val, fig=fig)
    fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True,   )
    plt.show()
    display('For 1 unit change in  {}, y is affected by change of {}'.format(val, model.params[1]))
    results.append([val, model.rsquared, model.params[0], model.params[1], model.pvalues[1], sms.jarque_bera(model.resid)[0] ])
    display(results)
    continue
    input("Press Enter to continue...")
# Out:
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~bedrooms
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  bedrooms, y is affected by change of 127573.96305334882'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~bathrooms
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  bathrooms, y is affected by change of 252731.20091351232'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~grade
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  grade, y is affected by change of 217277.88650392147'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478],
#  ['grade',
#   0.45045033263916157,
#   -1127595.5257516203,
#   217277.88650392147,
#   0.0,
#   1978259.2831838073]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~sqm_living15
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  sqm_living15, y is affected by change of 3367.981432611404'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478],
#  ['grade',
#   0.45045033263916157,
#   -1127595.5257516203,
#   217277.88650392147,
#   0.0,
#   1978259.2831838073],
#  ['sqm_living15',
#   0.3388223060553017,
#   -79779.36737566686,
#   3367.981432611404,
#   0.0,
#   1862427.6259618588]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~condition
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  condition, y is affected by change of 21090.066715765788'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478],
#  ['grade',
#   0.45045033263916157,
#   -1127595.5257516203,
#   217277.88650392147,
#   0.0,
#   1978259.2831838073],
#  ['sqm_living15',
#   0.3388223060553017,
#   -79779.36737566686,
#   3367.981432611404,
#   0.0,
#   1862427.6259618588],
#  ['condition',
#   0.0013688857745454142,
#   472613.8224286813,
#   21090.066715765788,
#   6.706217533760368e-08,
#   1123508.873910037]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~age
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  age, y is affected by change of -520.5761854377679'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478],
#  ['grade',
#   0.45045033263916157,
#   -1127595.5257516203,
#   217277.88650392147,
#   0.0,
#   1978259.2831838073],
#  ['sqm_living15',
#   0.3388223060553017,
#   -79779.36737566686,
#   3367.981432611404,
#   0.0,
#   1862427.6259618588],
#  ['condition',
#   0.0013688857745454142,
#   472613.8224286813,
#   21090.066715765788,
#   6.706217533760368e-08,
#   1123508.873910037],
#  ['age',
#   0.0017044297611669146,
#   567317.5070701132,
#   -520.5761854377679,
#   1.6928092197687363e-09,
#   1124267.988771292]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~distance_seattle
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  distance_seattle, y is affected by change of 7976.4817385044535'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478],
#  ['grade',
#   0.45045033263916157,
#   -1127595.5257516203,
#   217277.88650392147,
#   0.0,
#   1978259.2831838073],
#  ['sqm_living15',
#   0.3388223060553017,
#   -79779.36737566686,
#   3367.981432611404,
#   0.0,
#   1862427.6259618588],
#  ['condition',
#   0.0013688857745454142,
#   472613.8224286813,
#   21090.066715765788,
#   6.706217533760368e-08,
#   1123508.873910037],
#  ['age',
#   0.0017044297611669146,
#   567317.5070701132,
#   -520.5761854377679,
#   1.6928092197687363e-09,
#   1124267.988771292],
#  ['distance_seattle',
#   0.0684952232190279,
#   335573.3269815814,
#   7976.4817385044535,
#   0.0,
#   1411618.732521016]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~sqm_living
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  sqm_living, y is affected by change of 3034.4034398085932'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478],
#  ['grade',
#   0.45045033263916157,
#   -1127595.5257516203,
#   217277.88650392147,
#   0.0,
#   1978259.2831838073],
#  ['sqm_living15',
#   0.3388223060553017,
#   -79779.36737566686,
#   3367.981432611404,
#   0.0,
#   1862427.6259618588],
#  ['condition',
#   0.0013688857745454142,
#   472613.8224286813,
#   21090.066715765788,
#   6.706217533760368e-08,
#   1123508.873910037],
#  ['age',
#   0.0017044297611669146,
#   567317.5070701132,
#   -520.5761854377679,
#   1.6928092197687363e-09,
#   1124267.988771292],
#  ['distance_seattle',
#   0.0684952232190279,
#   335573.3269815814,
#   7976.4817385044535,
#   0.0,
#   1411618.732521016],
#  ['sqm_living',
#   0.48963634833076397,
#   -46576.04503142349,
#   3034.4034398085932,
#   0.0,
#   520960.52115509054]]
# King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~sqm_lot
# -------------------------------------------------------------------------------------
# 'For 1 unit change in  sqm_lot, y is affected by change of 9.208768359095309'
# [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)'],
#  ['bedrooms',
#   0.09573172578658995,
#   112275.53972686615,
#   127573.96305334882,
#   0.0,
#   1141750.6057302426],
#  ['bathrooms',
#   0.26492761081520755,
#   20376.618762419253,
#   252731.20091351232,
#   0.0,
#   827799.0649422478],
#  ['grade',
#   0.45045033263916157,
#   -1127595.5257516203,
#   217277.88650392147,
#   0.0,
#   1978259.2831838073],
#  ['sqm_living15',
#   0.3388223060553017,
#   -79779.36737566686,
#   3367.981432611404,
#   0.0,
#   1862427.6259618588],
#  ['condition',
#   0.0013688857745454142,
#   472613.8224286813,
#   21090.066715765788,
#   6.706217533760368e-08,
#   1123508.873910037],
#  ['age',
#   0.0017044297611669146,
#   567317.5070701132,
#   -520.5761854377679,
#   1.6928092197687363e-09,
#   1124267.988771292],
#  ['distance_seattle',
#   0.0684952232190279,
#   335573.3269815814,
#   7976.4817385044535,
#   0.0,
#   1411618.732521016],
#  ['sqm_living',
#   0.48963634833076397,
#   -46576.04503142349,
#   3034.4034398085932,
#   0.0,
#   520960.52115509054],
#  ['sqm_lot',
#   0.00891360173484046,
#   531678.0219367185,
#   9.208768359095309,
#   2.4499988960072526e-43,
#   1136071.3352342178]]

# %%
f = 'price~bedrooms'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
f = 'price~bedrooms+bathrooms'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
f = 'price~bedrooms+bathrooms+grade'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
f = 'price~bedrooms+bathrooms+grade+age'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
f = 'price~bedrooms+bathrooms+grade+age+condition'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
f = 'price~bedrooms+bathrooms+grade+distance_seattle+age+condition'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
f = 'price~sqm_living+bathrooms+grade+sqm_lot+sqm_living15+age+distance_seattle+bedrooms'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
f = 'price~sqm_living'
simple_model = ols(formula=f, data=df).fit()
simple_model.summary()

# %%
data_plog = data.copy()
data_plog['price'] = get_log(data['price'])

# %%
data_plog = pd.concat([data_plog, price_log], axis=1)

# %%
results = [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)' ]]
for idx, val in enumerate(['bedrooms', 'bathrooms', 'grade', 'sqm_living15', 'condition', 'age', 
                           'distance_seattle', 'sqm_living', 'sqm_lot']):
    print ("King County Housing DataSet - Regression Analysis and Diagnostics for formula: price~" + val)
    print ("-------------------------------------------------------------------------------------")

    f = 'price~' + val
   
    model = smf.ols(formula=f, data=data_plog).fit()
    
    X_new = pd.DataFrame({val: [data[val].min(), data[val].max()]});
    preds = model.predict(X_new)
    data.plot(kind='scatter', x=val, y='price');
    plt.plot(X_new, preds, linewidth=2);
    plt.show()
    fig = plt.figure(figsize=(15,8))
    fig = sm.graphics.plot_regress_exog(model, val, fig=fig)
    fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True,   )
    plt.show()
    
    results.append([val, model.rsquared, model.params[0], model.params[1], model.pvalues[1], sms.jarque_bera(model.resid)[0] ])
    display(results)
    input("Press Enter to continue...")

# %%
f = 'price~bedrooms'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()

# %%
data_plog
# Out:
#            price  bedrooms  bathrooms  condition  grade  age  sqm_living  \
# 0      12.309982         3        1.0          3      7   60   109.62554
# 1      13.195614         3        2.0          3      7   64   238.76071
# 2      12.100712         2        1.0          3      6   83    71.53531
# 3      13.311329         4        3.0          5      7   50   182.08988
# 4      13.142166         3        2.0          3      8   29   156.07704
# ...          ...       ...        ...        ...    ...  ...         ...
# 21590  13.825461         4        4.0          3      9    7   326.08953
# 21591  13.071070         3        2.0          3      8    8   121.70293
# 21592  12.793859         3        2.0          3      8    6   142.14159
# 21593  12.899220         4        2.0          3      8    2   214.60593
# 21595  12.899220         3        2.0          3      8   12   148.64480
#
#        sqm_living15     sqm_lot  distance_seattle
# 0         124.49002  524.901950            17.056
# 1         157.00607  672.803526            40.813
# 2         252.69616  929.030000            41.720
# 3         126.34808  464.515000            22.953
# 4         167.22540  750.656240            30.371
# ...             ...         ...               ...
# 21590     190.45115  668.901600            26.065
# 21591     123.56099  120.216482            28.690
# 21592     142.14159  105.073293            39.008
# 21593     170.01249  540.045139            20.611
# 21595     130.99323  221.852364            21.285
#
# [21281 rows x 10 columns]

# %%
data_plog = data.copy()
data_plog.drop(['price'], axis=1, inplace=True)

# %%
data_plog = pd.concat([data_plog, price_log], axis=1)

# %%
data_plog['bedrooms'] = data_plog['bedrooms']**2

# %%
# polynomial regression on bedrooms **2
f = 'price~bedrooms'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.115
# Model:                            OLS   Adj. R-squared:                  0.115
# Method:                 Least Squares   F-statistic:                     2753.
# Date:                Wed, 20 May 2020   Prob (F-statistic):               0.00
# Time:                        12:12:49   Log-Likelihood:                -15006.
# No. Observations:               21281   AIC:                         3.002e+04
# Df Residuals:                   21279   BIC:                         3.003e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.3900      0.013    940.309      0.000      12.364      12.416
# bedrooms       0.1973      0.004     52.470      0.000       0.190       0.205
# ==============================================================================
# Omnibus:                      604.911   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              708.800
# Skew:                           0.374   Prob(JB):                    1.22e-154
# Kurtosis:                       3.490   Cond. No.                         14.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data_plog = data.copy()
data_plog.drop(['price'], axis=1, inplace=True)

# %%
data_plog = pd.concat([data_plog, price_log], axis=1)

# %%
data_plog['bedrooms'] = data_plog['bedrooms']**3

# %%
# polynomial regression on bedrooms **3
f = 'price~bedrooms'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()

# %%
f = 'price~sqm_living'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.478
# Method:                 Least Squares   F-statistic:                 1.948e+04
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        12:43:02   Log-Likelihood:                -9385.0
# No. Observations:               21281   AIC:                         1.877e+04
# Df Residuals:                   21279   BIC:                         1.879e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.2329      0.006   1895.579      0.000      12.220      12.246
# sqm_living     0.0042   3.04e-05    139.573      0.000       0.004       0.004
# ==============================================================================
# Omnibus:                        9.920   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):                9.883
# Skew:                           0.047   Prob(JB):                      0.00714
# Kurtosis:                       2.950   Cond. No.                         532.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# each added square meter of living area increases the price by 0.4%

# %%
data_plog = data.copy()
data_plog.drop(['price'], axis=1, inplace=True)

# %%
data_plog = pd.concat([data_plog, price_log], axis=1)

# %%
f = 'price~grade+condition'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.509
# Method:                 Least Squares   F-statistic:                 1.102e+04
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        12:56:10   Log-Likelihood:                -8734.3
# No. Observations:               21281   AIC:                         1.747e+04
# Df Residuals:                   21278   BIC:                         1.750e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.1121      0.023    432.150      0.000      10.066      10.158
# grade          0.3299      0.002    148.276      0.000       0.326       0.334
# condition      0.1195      0.004     30.507      0.000       0.112       0.127
# ==============================================================================
# Omnibus:                       91.901   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.135
# Skew:                           0.133   Prob(JB):                     4.90e-22
# Kurtosis:                       3.200   Cond. No.                         80.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
f = 'price~age+grade+condition'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.563
# Model:                            OLS   Adj. R-squared:                  0.563
# Method:                 Least Squares   F-statistic:                     9136.
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        12:48:44   Log-Likelihood:                -7493.3
# No. Observations:               21281   AIC:                         1.499e+04
# Df Residuals:                   21277   BIC:                         1.503e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.7600      0.023    422.197      0.000       9.715       9.805
# age            0.0049   9.52e-05     51.303      0.000       0.005       0.005
# grade          0.3782      0.002    164.417      0.000       0.374       0.383
# condition      0.0512      0.004     13.020      0.000       0.043       0.059
# ==============================================================================
# Omnibus:                       83.734   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              113.837
# Skew:                          -0.022   Prob(JB):                     1.91e-25
# Kurtosis:                       3.356   Cond. No.                         524.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# condition and grade more influential over price but age is helpful combined with these variables but not on its own

# %%
f = 'price~bathrooms'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()

# %% [markdown]
# ## assessing grade affect on price, converting grade to grade/13 as there are only 13 possible grades

# %%
f = 'price~grade'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.487
# Model:                            OLS   Adj. R-squared:                  0.487
# Method:                 Least Squares   F-statistic:                 2.024e+04
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        12:37:14   Log-Likelihood:                -9189.9
# No. Observations:               21281   AIC:                         1.838e+04
# Df Residuals:                   21279   BIC:                         1.840e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.5992      0.017    606.474      0.000      10.565      10.633
# grade          0.3196      0.002    142.250      0.000       0.315       0.324
# ==============================================================================
# Omnibus:                      121.492   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.312
# Skew:                           0.177   Prob(JB):                     1.01e-27
# Kurtosis:                       3.119   Cond. No.                         54.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# price is affected by 32% increase per unit increase of grade of home

# %%
f = 'price~age'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     74.97
# Date:                Tue, 19 May 2020   Prob (F-statistic):           5.10e-18
# Time:                        11:56:54   Log-Likelihood:                -16264.
# No. Observations:               21281   AIC:                         3.253e+04
# Df Residuals:                   21279   BIC:                         3.255e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.1049      0.006   2040.035      0.000      13.092      13.117
# age           -0.0011      0.000     -8.659      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                      983.569   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1230.886
# Skew:                           0.487   Prob(JB):                    5.21e-268
# Kurtosis:                       3.663   Cond. No.                         95.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
f = 'price~condition'
simple_model = ols(formula=f, data=data_plog).fit()
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     31.49
# Date:                Tue, 19 May 2020   Prob (F-statistic):           2.03e-08
# Time:                        11:57:25   Log-Likelihood:                -16285.
# No. Observations:               21281   AIC:                         3.257e+04
# Df Residuals:                   21279   BIC:                         3.259e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.9529      0.019    676.191      0.000      12.915      12.990
# condition      0.0310      0.006      5.612      0.000       0.020       0.042
# ==============================================================================
# Omnibus:                      952.253   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1204.408
# Skew:                           0.472   Prob(JB):                    2.93e-262
# Kurtosis:                       3.684   Cond. No.                         20.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # build model with df

# %% [markdown]
# ## where X= data, with dummies, y =price

# %%
y_b = df_dummies.price
X_b = df_dummies.copy()
X_b.drop(['price',], axis=1, inplace=True)

# %%
X_fin3 = X_b
X_with_intercept = sm.add_constant(X_b)
model3 = sm.OLS(y_b, X_with_intercept).fit()
model3.summary()

# %% [markdown]
# ## where X=data, y = price, no dummies

# %%
# define target variable 'price'
labels = data['price']

features = df.copy()
features.drop(['price', ], axis=1, inplace=True)

# %%
# create model
X_fin = features
X_with_intercept = sm.add_constant(features)
model = sm.OLS(labels, X_with_intercept).fit()
model.summary()

# %%
my_model = LinearRegression()
my_model.fit(features, labels)

# %%
predictions = my_model.predict(features)
mse = mean_squared_error(labels, predictions)
rmse = np.sqrt(mse)

print(rmse)

# %%
predict_test = my_model.predict(features)
predict_test

# %%
# get intercept and coef
print('The intercept for model is {:.8}'.format(my_model.intercept_))


#loop through dict to print
for cf in zip(features.columns, my_model.coef_):
    print('The coefficient for {} is {:7}'.format(cf[0], cf[1]))

# %%
scores = cross_val_score(
            my_model, 
            features,
            labels,
            cv=20,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)

# %%
display(rmse_scores)

print(f'Mean: {rmse_scores.mean()}')
print(f'Std Dev: {rmse_scores.std()}')

# %%
pd.DataFrame(data=my_model.coef_.reshape(1,-1), columns= features.columns)

# %% [markdown]
# the data clearly needs to be normalized as the coefficients show

# %%
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(my_model, features, labels, scoring='r2', cv=crossvalidation))

baseline

# %% [markdown]
# ## regression on datasets with dummies

# %%
df_dummies.columns

# %% [markdown]
# ## where X= minmax scaling applied to dataset, y=log transformed price

# %%
# create dataframe with scaling applied to continuous variables
df_scale_dummies = df_dummies.copy()
df_scale_dummies.drop(['price',  ], axis=1, inplace=True)
X_s = scaler.fit_transform(df_scale_dummies)

# %%
# create x & y
y_s = price_log

# %%
#create model for 
X_fin = X_s
X_with_intercept = sm.add_constant(X_s)
model1 = sm.OLS(y_s, X_with_intercept).fit()
model1.summary()

# %%
# removing sqm_lot data

# %%
# create dataframe with scaling applied to continuous variables
y_s = get_log(data['price'])
df_scale_dummies = df_dummies.copy()
df_scale_dummies.drop(['price', 'sqm_lot'], axis=1, inplace=True)
X_s = scaler.fit_transform(df_scale_dummies)

# %%
df_scale_dummies.columns

# %%
X_fin = X_s
X_with_intercept = sm.add_constant(X_s)
model1_2 = sm.OLS(y_s, X_with_intercept).fit()
model1_2.summary()

# %% [markdown]
# ## model where X= data, no scaling applied to continuous/y = log transformed price

# %%
df_dummies.columns

# %%
# create model
X = df_dummies.copy()
X.drop(['price', ], axis=1, inplace=True)

y = price_log
X_with_intercept = sm.add_constant(X)
model2 = sm.OLS(y, X_with_intercept).fit()
model2.summary()

# %% [markdown]
#  the durbin watson score shows that there my be some autocorrelation present in the data, but it is very close to 2, which is the cut off that starts the non-autocorrelation spec(2-4)

# %% [markdown]
# ### same as above dropping sqm_lot

# %%
y = price_log
X = df_dummies.copy()
X.drop(['price','sqm_lot'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'condition', 'grade', 'age',
#        'sqm_living', 'sqm_living15', 'sqm_lot', 'distance_seattle'],
#       dtype='object')

# %%
# create model
X_with_intercept = sm.add_constant(X)
model2_6 = sm.OLS(y, X_with_intercept).fit()
model2_6.summary()

# %% [markdown]
# # final model assessment

# %% [markdown]
# ## using model with no scaling,   with target = price/10000, log transformed price, dropping sqm_lot

# %%
#log price of price/1000
y3 = price_tenth_log
X3 = df_dummies.copy()
X3.drop(['price', 'sqm_lot'], axis=1, inplace=True)
X_intercept = sm.add_constant(X3)
model_10 = sm.OLS(y3, X_intercept).fit()
model_10.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            price/10000   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     1815.
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        11:14:11   Log-Likelihood:                -2282.6
# No. Observations:               21281   AIC:                             4631.
# Df Residuals:                   21248   BIC:                             4894.
# Df Model:                          32
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                2.0942      0.066     31.557      0.000       1.964       2.224
# age                  0.0042   8.26e-05     50.409      0.000       0.004       0.004
# sqm_living           0.0019   4.88e-05     38.421      0.000       0.002       0.002
# sqm_living15         0.0011   4.83e-05     22.512      0.000       0.001       0.001
# distance_seattle     0.0137      0.000     85.938      0.000       0.013       0.014
# grade_7              0.2082      0.007     28.049      0.000       0.194       0.223
# grade_8              0.4192      0.009     48.045      0.000       0.402       0.436
# grade_9              0.6125      0.011     56.534      0.000       0.591       0.634
# grade_10             0.7416      0.014     54.148      0.000       0.715       0.768
# grade_11             0.8478      0.019     43.974      0.000       0.810       0.886
# grade_12             0.9878      0.034     29.242      0.000       0.922       1.054
# grade_13             1.0869      0.083     13.108      0.000       0.924       1.249
# bed_2                0.0253      0.024      1.054      0.292      -0.022       0.072
# bed_3               -0.0267      0.024     -1.115      0.265      -0.074       0.020
# bed_4               -0.0439      0.024     -1.808      0.071      -0.091       0.004
# bed_5               -0.0545      0.025     -2.160      0.031      -0.104      -0.005
# bed_6               -0.0958      0.030     -3.233      0.001      -0.154      -0.038
# bed_7               -0.1844      0.051     -3.621      0.000      -0.284      -0.085
# bed_8               -0.0482      0.079     -0.610      0.542      -0.203       0.107
# bed_9               -0.0684      0.116     -0.592      0.554      -0.295       0.158
# bed_10               0.0123      0.158      0.077      0.938      -0.298       0.322
# bed_11              -0.1434      0.271     -0.530      0.596      -0.674       0.387
# bathrooms_2.0        0.0930      0.006     14.379      0.000       0.080       0.106
# bathrooms_3.0        0.1602      0.009     17.610      0.000       0.142       0.178
# bathrooms_4.0        0.2212      0.012     18.281      0.000       0.197       0.245
# bathrooms_5.0        0.3291      0.039      8.540      0.000       0.254       0.405
# bathrooms_6.0        0.2281      0.061      3.761      0.000       0.109       0.347
# bathrooms_7.0       -0.1097      0.194     -0.566      0.572      -0.490       0.271
# bathrooms_8.0       -0.1361      0.148     -0.922      0.357      -0.425       0.153
# condition_2          0.0921      0.066      1.401      0.161      -0.037       0.221
# condition_3          0.2228      0.062      3.588      0.000       0.101       0.344
# condition_4          0.2626      0.062      4.229      0.000       0.141       0.384
# condition_5          0.3279      0.062      5.260      0.000       0.206       0.450
# ==============================================================================
# Omnibus:                      329.974   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              593.290
# Skew:                           0.097   Prob(JB):                    1.47e-129
# Kurtosis:                       3.795   Cond. No.                     4.25e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.25e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## y = log transformed price(og)

# %%
#y as  log of y
y = price_log
X = df_dummies.copy()
X.drop(['price', 'sqm_lot'], axis=1, inplace=True)
# create model
X_with_intercept = sm.add_constant(X)
model = sm.OLS(y, X_with_intercept).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     1815.
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        11:09:23   Log-Likelihood:                -2282.6
# No. Observations:               21281   AIC:                             4631.
# Df Residuals:                   21248   BIC:                             4894.
# Df Model:                          32
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               11.3045      0.066    170.348      0.000      11.174      11.435
# age                  0.0042   8.26e-05     50.409      0.000       0.004       0.004
# sqm_living           0.0019   4.88e-05     38.421      0.000       0.002       0.002
# sqm_living15         0.0011   4.83e-05     22.512      0.000       0.001       0.001
# distance_seattle     0.0137      0.000     85.938      0.000       0.013       0.014
# grade_7              0.2082      0.007     28.049      0.000       0.194       0.223
# grade_8              0.4192      0.009     48.045      0.000       0.402       0.436
# grade_9              0.6125      0.011     56.534      0.000       0.591       0.634
# grade_10             0.7416      0.014     54.148      0.000       0.715       0.768
# grade_11             0.8478      0.019     43.974      0.000       0.810       0.886
# grade_12             0.9878      0.034     29.242      0.000       0.922       1.054
# grade_13             1.0869      0.083     13.108      0.000       0.924       1.249
# bed_2                0.0253      0.024      1.054      0.292      -0.022       0.072
# bed_3               -0.0267      0.024     -1.115      0.265      -0.074       0.020
# bed_4               -0.0439      0.024     -1.808      0.071      -0.091       0.004
# bed_5               -0.0545      0.025     -2.160      0.031      -0.104      -0.005
# bed_6               -0.0958      0.030     -3.233      0.001      -0.154      -0.038
# bed_7               -0.1844      0.051     -3.621      0.000      -0.284      -0.085
# bed_8               -0.0482      0.079     -0.610      0.542      -0.203       0.107
# bed_9               -0.0684      0.116     -0.592      0.554      -0.295       0.158
# bed_10               0.0123      0.158      0.077      0.938      -0.298       0.322
# bed_11              -0.1434      0.271     -0.530      0.596      -0.674       0.387
# bathrooms_2.0        0.0930      0.006     14.379      0.000       0.080       0.106
# bathrooms_3.0        0.1602      0.009     17.610      0.000       0.142       0.178
# bathrooms_4.0        0.2212      0.012     18.281      0.000       0.197       0.245
# bathrooms_5.0        0.3291      0.039      8.540      0.000       0.254       0.405
# bathrooms_6.0        0.2281      0.061      3.761      0.000       0.109       0.347
# bathrooms_7.0       -0.1097      0.194     -0.566      0.572      -0.490       0.271
# bathrooms_8.0       -0.1361      0.148     -0.922      0.357      -0.425       0.153
# condition_2          0.0921      0.066      1.401      0.161      -0.037       0.221
# condition_3          0.2228      0.062      3.588      0.000       0.101       0.344
# condition_4          0.2626      0.062      4.229      0.000       0.141       0.384
# condition_5          0.3279      0.062      5.260      0.000       0.206       0.450
# ==============================================================================
# Omnibus:                      329.974   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              593.290
# Skew:                           0.097   Prob(JB):                    1.47e-129
# Kurtosis:                       3.795   Cond. No.                     4.25e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.25e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y.std()

# %%
y.mean()

# %% [markdown]
# ## model with price /10000 log transformed

# %%
my_model_10 = LinearRegression(normalize=True)
my_model_10.fit(X3, y3)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
crossvalidation = KFold(n_splits=100, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(my_model_10, X3, y3, scoring='r2', cv=crossvalidation))

baseline
# Out:
# 0.7271862671224956

# %%
y_hat_10 = my_model_10.predict(X3)
y_hat_10
# Out:
# array([3.32229227, 4.03403367, 3.66686692, ..., 3.78155674, 3.66254072,
#        3.56446769])

# %%
# get coefficients
coef_10 = my_model_10.coef_.reshape(-1,1)
# back translate coefficients
coef_10
# Out:
# array([[ 0.00416397],
#        [ 0.00187544],
#        [ 0.00108757],
#        [ 0.01366274],
#        [ 0.20817082],
#        [ 0.41923458],
#        [ 0.61252583],
#        [ 0.7416429 ],
#        [ 0.84782026],
#        [ 0.98782263],
#        [ 1.08692433],
#        [ 0.02533465],
#        [-0.02666513],
#        [-0.04388576],
#        [-0.05454633],
#        [-0.09583192],
#        [-0.1843934 ],
#        [-0.04820348],
#        [-0.06842574],
#        [ 0.01225563],
#        [-0.14343681],
#        [ 0.09295155],
#        [ 0.16018524],
#        [ 0.22118816],
#        [ 0.32905125],
#        [ 0.22807716],
#        [-0.10974048],
#        [-0.13605666],
#        [ 0.09210401],
#        [ 0.22276639],
#        [ 0.26259416],
#        [ 0.32787505]])

# %%
scores = cross_val_score(
            my_model_10, 
            X3,
            y3,
            cv=8,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)
display(rmse_scores)

print(f'Mean: {rmse_scores.mean()}')
print(f'Std Dev: {rmse_scores.std()}')
# Out:
# array([0.2701007 , 0.27888252, 0.2680338 , 0.26654135, 0.27272736,
#        0.27212601, 0.27295814, 0.27503076])
# Mean: 0.2720500791698106
# Std Dev: 0.0036594466747543173

# %%
stepwise_selection(X3, y3)
# Out:
# Add  grade_7                        with p-value 0.0
# Add  grade_11                       with p-value 0.0
# Add  grade_10                       with p-value 0.0
# Add  grade_9                        with p-value 0.0
# Add  distance_seattle               with p-value 0.0
# Add  grade_12                       with p-value 0.0
# Add  grade_8                        with p-value 0.0
# Add  age                            with p-value 0.0
# Add  sqm_living15                   with p-value 0.0
# Add  sqm_living                     with p-value 0.0
# Add  condition_5                    with p-value 1.37689e-42
# Add  grade_13                       with p-value 9.4729e-41
# Add  condition_4                    with p-value 1.08885e-19
# Add  bathrooms_4.0                  with p-value 5.86219e-20
# Add  bathrooms_3.0                  with p-value 2.97985e-21
# Add  bathrooms_2.0                  with p-value 8.85186e-30
# Add  bed_2                          with p-value 7.2347e-17
# Add  bathrooms_5.0                  with p-value 1.33969e-15
# Add  condition_3                    with p-value 2.5765e-11
# Add  bed_3                          with p-value 7.49163e-05
# Add  bathrooms_6.0                  with p-value 0.000185274
# Add  bed_7                          with p-value 0.00178
# Add  bed_6                          with p-value 0.00353281
# ['grade_7',
#  'grade_11',
#  'grade_10',
#  'grade_9',
#  'distance_seattle',
#  'grade_12',
#  'grade_8',
#  'age',
#  'sqm_living15',
#  'sqm_living',
#  'condition_5',
#  'grade_13',
#  'condition_4',
#  'bathrooms_4.0',
#  'bathrooms_3.0',
#  'bathrooms_2.0',
#  'bed_2',
#  'bathrooms_5.0',
#  'condition_3',
#  'bed_3',
#  'bathrooms_6.0',
#  'bed_7',
#  'bed_6']

# %%
# model with columns from stepwise selection
X3_sw = X[['grade_7',
 'grade_11',
 'grade_10',
 'grade_9',
 'distance_seattle',
 'grade_12',
 'grade_8',
 'age',
 'sqm_living15',
 'sqm_living',
 'condition_5',
 'grade_13',
 'condition_4',
 'bathrooms_4.0',
 'bathrooms_3.0',
 'bathrooms_2.0',
 'bed_2',
 'bathrooms_5.0',
 'condition_3',
 'bed_3',
 'bathrooms_6.0',
 'bed_7',
 'bed_6',
]]
y3 = price_tenth_log
X_with_intercept = sm.add_constant(X3_sw)
sw3_model = sm.OLS(y3, X_with_intercept).fit()
sw3_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            price/10000   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     2525.
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        11:23:50   Log-Likelihood:                -2287.0
# No. Observations:               21281   AIC:                             4622.
# Df Residuals:                   21257   BIC:                             4813.
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                2.1379      0.024     89.240      0.000       2.091       2.185
# grade_7              0.2077      0.007     28.028      0.000       0.193       0.222
# grade_11             0.8512      0.019     44.361      0.000       0.814       0.889
# grade_10             0.7441      0.014     54.568      0.000       0.717       0.771
# grade_9              0.6138      0.011     56.817      0.000       0.593       0.635
# distance_seattle     0.0137      0.000     86.016      0.000       0.013       0.014
# grade_12             0.9901      0.034     29.440      0.000       0.924       1.056
# grade_8              0.4195      0.009     48.140      0.000       0.402       0.437
# age                  0.0042   8.24e-05     50.514      0.000       0.004       0.004
# sqm_living15         0.0011   4.81e-05     22.707      0.000       0.001       0.001
# sqm_living           0.0018    4.7e-05     39.246      0.000       0.002       0.002
# condition_5          0.2447      0.022     11.146      0.000       0.202       0.288
# grade_13             1.0723      0.080     13.421      0.000       0.916       1.229
# condition_4          0.1794      0.021      8.462      0.000       0.138       0.221
# bathrooms_4.0        0.2207      0.012     18.514      0.000       0.197       0.244
# bathrooms_3.0        0.1593      0.009     17.706      0.000       0.142       0.177
# bathrooms_2.0        0.0927      0.006     14.454      0.000       0.080       0.105
# bed_2                0.0676      0.007      9.277      0.000       0.053       0.082
# bathrooms_5.0        0.3314      0.038      8.680      0.000       0.257       0.406
# condition_3          0.1397      0.021      6.618      0.000       0.098       0.181
# bed_3                0.0170      0.005      3.732      0.000       0.008       0.026
# bathrooms_6.0        0.2346      0.060      3.915      0.000       0.117       0.352
# bed_7               -0.1426      0.044     -3.223      0.001      -0.229      -0.056
# bed_6               -0.0497      0.017     -2.917      0.004      -0.083      -0.016
# ==============================================================================
# Omnibus:                      333.815   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              604.663
# Skew:                           0.096   Prob(JB):                    5.00e-132
# Kurtosis:                       3.803   Cond. No.                     1.29e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## model with price log

# %%
my_model = LinearRegression()
my_model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
crossvalidation = KFold(n_splits=100, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(my_model, X, y, scoring='r2', cv=crossvalidation))

baseline
# Out:
# 0.7271862671224956

# %%
# get coefficients
coef = my_model.coef_.reshape(-1,1)
coef
# Out:
# array([[ 0.00416397],
#        [ 0.00187544],
#        [ 0.00108757],
#        [ 0.01366274],
#        [ 0.20817082],
#        [ 0.41923458],
#        [ 0.61252583],
#        [ 0.7416429 ],
#        [ 0.84782026],
#        [ 0.98782263],
#        [ 1.08692433],
#        [ 0.02533465],
#        [-0.02666513],
#        [-0.04388576],
#        [-0.05454633],
#        [-0.09583192],
#        [-0.1843934 ],
#        [-0.04820348],
#        [-0.06842574],
#        [ 0.01225563],
#        [-0.14343681],
#        [ 0.09295155],
#        [ 0.16018524],
#        [ 0.22118816],
#        [ 0.32905125],
#        [ 0.22807716],
#        [-0.10974048],
#        [-0.13605666],
#        [ 0.09210401],
#        [ 0.22276639],
#        [ 0.26259416],
#        [ 0.32787505]])

# %%
y_hat = my_model.predict(X)
y_hat
# Out:
# array([12.53263264, 13.24437404, 12.87720729, ..., 12.99189711,
#        12.87288109, 12.77480806])

# %%
scores = cross_val_score(
            my_model, 
            X,
            y,
            cv=8,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)
display(rmse_scores)

print(f'Mean: {rmse_scores.mean()}')
print(f'Std Dev: {rmse_scores.std()}')
# Out:
# array([0.2701007 , 0.27888252, 0.2680338 , 0.26654135, 0.27272736,
#        0.27212601, 0.27295814, 0.27503076])
# Mean: 0.2720500791698105
# Std Dev: 0.003659446674754199

# %%
stepwise_selection(X, y)
# Out:
# /Users/badmin/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# Add  grade_7                        with p-value 0.0
# Add  grade_11                       with p-value 0.0
# Add  grade_10                       with p-value 0.0
# Add  grade_9                        with p-value 0.0
# Add  distance_seattle               with p-value 0.0
# Add  grade_12                       with p-value 0.0
# Add  grade_8                        with p-value 0.0
# Add  age                            with p-value 0.0
# Add  sqm_living15                   with p-value 0.0
# Add  sqm_living                     with p-value 0.0
# Add  condition_5                    with p-value 1.37689e-42
# Add  grade_13                       with p-value 9.4729e-41
# Add  condition_4                    with p-value 1.08885e-19
# Add  bathrooms_4.0                  with p-value 5.86219e-20
# Add  bathrooms_3.0                  with p-value 2.97985e-21
# Add  bathrooms_2.0                  with p-value 8.85186e-30
# Add  bed_2                          with p-value 7.2347e-17
# Add  bathrooms_5.0                  with p-value 1.33969e-15
# Add  condition_3                    with p-value 2.5765e-11
# Add  bed_3                          with p-value 7.49163e-05
# Add  bathrooms_6.0                  with p-value 0.000185274
# Add  bed_7                          with p-value 0.00178
# Add  bed_6                          with p-value 0.00353281
# ['grade_7',
#  'grade_11',
#  'grade_10',
#  'grade_9',
#  'distance_seattle',
#  'grade_12',
#  'grade_8',
#  'age',
#  'sqm_living15',
#  'sqm_living',
#  'condition_5',
#  'grade_13',
#  'condition_4',
#  'bathrooms_4.0',
#  'bathrooms_3.0',
#  'bathrooms_2.0',
#  'bed_2',
#  'bathrooms_5.0',
#  'condition_3',
#  'bed_3',
#  'bathrooms_6.0',
#  'bed_7',
#  'bed_6']

# %%
### create model using variables dictated by stepwise

# %%
# model with columns from stepwise selection
X_sw = X[['distance_seattle',
 'grade_7',
 'grade_10',
 'grade_11',
 'grade_9',
 'grade_12',
 'sqm_living',
 'grade_8',
 'age',
 'sqm_living15',
 'condition_5',
 'grade_13',
 'condition_4',
 'bathrooms_4.0',
 'bathrooms_3.0',
 'bathrooms_2.0',
 'bed_2',
 'bathrooms_5.0',
 'condition_3',
 'bed_3',
 'bathrooms_6.0',
 'bed_7',
 'bed_6',
]]
y = price_log
X_with_intercept = sm.add_constant(X_sw)
sw_model = sm.OLS(y, X_with_intercept).fit()
sw_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.732
# Method:                 Least Squares   F-statistic:                     2525.
# Date:                Tue, 19 May 2020   Prob (F-statistic):               0.00
# Time:                        11:33:28   Log-Likelihood:                -2287.0
# No. Observations:               21281   AIC:                             4622.
# Df Residuals:                   21257   BIC:                             4813.
# Df Model:                          23
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               11.3482      0.024    473.702      0.000      11.301      11.395
# distance_seattle     0.0137      0.000     86.016      0.000       0.013       0.014
# grade_7              0.2077      0.007     28.028      0.000       0.193       0.222
# grade_10             0.7441      0.014     54.568      0.000       0.717       0.771
# grade_11             0.8512      0.019     44.361      0.000       0.814       0.889
# grade_9              0.6138      0.011     56.817      0.000       0.593       0.635
# grade_12             0.9901      0.034     29.440      0.000       0.924       1.056
# sqm_living           0.0018    4.7e-05     39.246      0.000       0.002       0.002
# grade_8              0.4195      0.009     48.140      0.000       0.402       0.437
# age                  0.0042   8.24e-05     50.514      0.000       0.004       0.004
# sqm_living15         0.0011   4.81e-05     22.707      0.000       0.001       0.001
# condition_5          0.2447      0.022     11.146      0.000       0.202       0.288
# grade_13             1.0723      0.080     13.421      0.000       0.916       1.229
# condition_4          0.1794      0.021      8.462      0.000       0.138       0.221
# bathrooms_4.0        0.2207      0.012     18.514      0.000       0.197       0.244
# bathrooms_3.0        0.1593      0.009     17.706      0.000       0.142       0.177
# bathrooms_2.0        0.0927      0.006     14.454      0.000       0.080       0.105
# bed_2                0.0676      0.007      9.277      0.000       0.053       0.082
# bathrooms_5.0        0.3314      0.038      8.680      0.000       0.257       0.406
# condition_3          0.1397      0.021      6.618      0.000       0.098       0.181
# bed_3                0.0170      0.005      3.732      0.000       0.008       0.026
# bathrooms_6.0        0.2346      0.060      3.915      0.000       0.117       0.352
# bed_7               -0.1426      0.044     -3.223      0.001      -0.229      -0.056
# bed_6               -0.0497      0.017     -2.917      0.004      -0.083      -0.016
# ==============================================================================
# Omnibus:                      333.815   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              604.663
# Skew:                           0.096   Prob(JB):                    5.00e-132
# Kurtosis:                       3.803   Cond. No.                     1.29e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# the skew  looks to prove a fairly normal distribution, but kurtosis shows slightly heavier tails than those found in a normal distribution

# %%
# confidence intervals
sw_model.conf_int()
# Out:
#                           0          1
# const             11.301259  11.395172
# distance_seattle   0.013356   0.013978
# grade_7            0.193130   0.222173
# grade_10           0.717408   0.770866
# grade_11           0.813591   0.888811
# grade_9            0.592640   0.634991
# grade_12           0.924165   1.056002
# sqm_living         0.001754   0.001938
# grade_8            0.402401   0.436560
# age                0.004001   0.004324
# sqm_living15       0.000998   0.001187
# condition_5        0.201644   0.287694
# grade_13           0.915687   1.228882
# condition_4        0.137862   0.220983
# bathrooms_4.0      0.197304   0.244026
# bathrooms_3.0      0.141642   0.176906
# bathrooms_2.0      0.080131   0.105273
# bed_2              0.053316   0.081882
# bathrooms_5.0      0.256554   0.406228
# condition_3        0.098342   0.181109
# bed_3              0.008052   0.025870
# bathrooms_6.0      0.117118   0.352028
# bed_7             -0.229388  -0.055900
# bed_6             -0.083126  -0.016316

# %%
lm, lm_pval, f_val, f_pval = diagnostic.het_breuschpagan(sw_model.resid, sw_model.model.exog)
print('p-value of lagrange multiplier test {:.3}'.format(lm_pval))
print('the f value is {:.3}'.format(f_val))
print('the f p-value is {:.3}'.format(f_pval))
# Out:
# p-value of lagrange multiplier test 2.98e-159
# the f value is 37.2
# the f p-value is 1.32e-162

# %% [markdown]
# The null hypothesis assumes homoskedasticity. for p_val > 0.05, fail to reject the null and conclude there may not be heteroskedasticity.

# %% [markdown]
# ## residuals

# %%
import pylab
sm.qqplot(sw_model.resid, line = 's')
pylab.show()


mean_resid = sum(sw_model.resid)/len(sw_model.resid)
mean_resid
# Out:
# -1.0649293058159106e-14

# %% [markdown]
# mean residual indicates that predicted prices are higher than actual prices

# %%
y_hat = sw_model.predict()
print(y_hat)
# Out:
# [12.53381514 13.24178615 12.87938998 ... 12.99291169 12.87210109
#  12.775489  ]

# %%
rmse =np.sqrt(mean_squared_error(y, y_hat))
print(rmse)
# Out:
# 0.26942277687840677

# %%
SS_Residual = np.sum((y-y_hat)**2)
SS_Total = np.sum((y-np.mean(y))**2)
r_squared = 1 - (float(SS_Residual))/SS_Total
adjusted_r_squared = 1 - (1-r_squared)*(len(y)-1)/(len(y)-X_sw.shape[1]-1)
print(SS_Residual)
print(SS_Total)
print(r_squared)
print(adjusted_r_squared)
# Out:
# 1544.758692507252
# 5765.645728689522
# 0.7320753363633459
# 0.731785442809992

# %%
# comparison graph with log price 
ax1 = sns.distplot(y, hist=False, color="r", label="Actual")
sns.distplot(y_hat, hist=False, color="b", label="Predicted" , ax=ax1)

# %%
sw_model.params
# Out:
# const               11.348215
# distance_seattle     0.013667
# grade_7              0.207652
# grade_10             0.744137
# grade_11             0.851201
# grade_9              0.613815
# grade_12             0.990084
# sqm_living           0.001846
# grade_8              0.419480
# age                  0.004162
# sqm_living15         0.001093
# condition_5          0.244669
# grade_13             1.072285
# condition_4          0.179423
# bathrooms_4.0        0.220665
# bathrooms_3.0        0.159274
# bathrooms_2.0        0.092702
# bed_2                0.067599
# bathrooms_5.0        0.331391
# condition_3          0.139725
# bed_3                0.016961
# bathrooms_6.0        0.234573
# bed_7               -0.142644
# bed_6               -0.049721
# dtype: float64

# %%
sw_params_exp = np.exp(sw_model.params)
sw_params_exp
# Out:
# const               84813.949443
# distance_seattle        1.013761
# grade_7                 1.230784
# grade_10                2.104624
# grade_11                2.342459
# grade_9                 1.847466
# grade_12                2.691459
# sqm_living              1.001848
# grade_8                 1.521170
# age                     1.004171
# sqm_living15            1.001093
# condition_5             1.277198
# grade_13                2.922048
# condition_4             1.196526
# bathrooms_4.0           1.246906
# bathrooms_3.0           1.172659
# bathrooms_2.0           1.097135
# bed_2                   1.069936
# bathrooms_5.0           1.392904
# condition_3             1.149958
# bed_3                   1.017106
# bathrooms_6.0           1.264369
# bed_7                   0.867063
# bed_6                   0.951495
# dtype: float64

# %%
# comparison graph with log price translated to original format
ax1 = sns.distplot(np.exp(y), hist=False, color="r", label="Actual")
sns.distplot(np.exp(y_hat), hist=False, color="b", label="Predicted" , ax=ax1)

# %%
# creating model with scikit learn

# %%
lr_model = LinearRegression()
lr_model.fit(X_sw, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
scores = cross_val_score(
            lr_model, 
            X_sw,
            y,
            cv=8,
            scoring="neg_mean_squared_error"
)

rmse_scores = np.sqrt(-scores)
display(rmse_scores)

print(f'Mean: {rmse_scores.mean()}')
print(f'Std Dev: {rmse_scores.std()}')
# Out:
# array([0.26989514, 0.27779615, 0.26717767, 0.26568165, 0.2723083 ,
#        0.27221958, 0.27303801, 0.27484971])
# Mean: 0.2716207761949839
# Std Dev: 0.003697860336237212

# %%
#perform cross validation on  model
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=23
                       )
baseline = np.mean(cross_val_score(lr_model, X_sw, y, scoring='r2', cv=crossvalidation))

baseline
# Out:
# 0.7307441117038573

# %%
# get intercept and coef
print('The intercept for model is {:.4}'.format(lr_model.intercept_))


#loop through dict to print
for cf in zip(X_sw.columns, lr_model.coef_):
    print('The coefficient for {} is {:.4}'.format(cf[0], cf[1]))
# Out:
# The intercept for model is 11.35
# The coefficient for distance_seattle is 0.01367
# The coefficient for grade_7 is 0.2077
# The coefficient for grade_10 is 0.7441
# The coefficient for grade_11 is 0.8512
# The coefficient for grade_9 is 0.6138
# The coefficient for grade_12 is 0.9901
# The coefficient for sqm_living is 0.001846
# The coefficient for grade_8 is 0.4195
# The coefficient for age is 0.004162
# The coefficient for sqm_living15 is 0.001093
# The coefficient for condition_5 is 0.2447
# The coefficient for grade_13 is 1.072
# The coefficient for condition_4 is 0.1794
# The coefficient for bathrooms_4.0 is 0.2207
# The coefficient for bathrooms_3.0 is 0.1593
# The coefficient for bathrooms_2.0 is 0.0927
# The coefficient for bed_2 is 0.0676
# The coefficient for bathrooms_5.0 is 0.3314
# The coefficient for condition_3 is 0.1397
# The coefficient for bed_3 is 0.01696
# The coefficient for bathrooms_6.0 is 0.2346
# The coefficient for bed_7 is -0.1426
# The coefficient for bed_6 is -0.04972

# %% [markdown]
# ## train/test split data

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sw, y, test_size=0.2, random_state=29)
print(X_train.shape); print(X_test.shape)
# Out:
# (17024, 23)
# (4257, 23)

# %%
train_model = LinearRegression()
train_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#run model with trianing data
pred_train_lr= train_model.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_lr)))
print(r2_score(y_train, pred_train_lr))


# run model with test data 
pred_test_lr= train_model.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_lr))) 
print(r2_score(y_test, pred_test_lr))
# Out:
# 0.27041619822409924
# 0.7326634142950978
# 0.2657524110261689
# 0.7289032997227274

# %%
predict_train = train_model.predict(X_train)
predict_train
# Out:
# array([12.90688927, 12.78365218, 12.86598439, ..., 13.90998005,
#        12.98961306, 12.48268917])

# %%
predict_test = train_model.predict(X_test)
predict_test
# Out:
# array([12.47560594, 13.25739675, 13.18595998, ..., 12.35394452,
#        13.22497495, 12.57120602])

# %%
# get intercept and coef
ax1 = sns.distplot(y, hist=False, color="r", label="Actual")
sns.distplot(predict_train, hist=False, color="b", label="Predicted" , ax=ax1)

# %%
ax1 = sns.distplot(y, hist=False, color="r", label="Actual")
sns.distplot(predict_test, hist=False, color="b", label="Predicted" , ax=ax1)

# %% [markdown]
# ### visualize training data vs test data

# %%
import seaborn as sns

ax1 = sns.distplot(predict_train, hist=False, color="r", label="Train")
sns.distplot(predict_test, hist=False, color="b", label="Test" , ax=ax1)

# %%
train_model.coef_.reshape(-1,1)
# Out:
# array([[ 1.36881507e-02],
#        [ 2.05189902e-01],
#        [ 7.53559733e-01],
#        [ 8.55921265e-01],
#        [ 6.14951539e-01],
#        [ 9.78294221e-01],
#        [ 1.86526590e-03],
#        [ 4.22021979e-01],
#        [ 4.15996605e-03],
#        [ 1.03779555e-03],
#        [ 2.45638182e-01],
#        [ 1.14441427e+00],
#        [ 1.83659334e-01],
#        [ 2.20938398e-01],
#        [ 1.65188514e-01],
#        [ 9.06879169e-02],
#        [ 6.78338516e-02],
#        [ 3.54569411e-01],
#        [ 1.46375084e-01],
#        [ 1.84959968e-02],
#        [ 1.48890223e-01],
#        [-1.33877835e-01],
#        [-6.72389130e-02]])

# %%
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(train_model, X_train, y_train, scoring='r2', cv=crossvalidation))

baseline
# Out:
# 0.7309734832552492

# %%
# comparison graph with log price 
ax1 = sns.distplot(y, hist=False, color="r", label="Actual")
sns.distplot(y_hat, hist=False, color="b", label="Predicted" , ax=ax1)

# %%
y_hat = train_model.predict(X_sw)

# %%
resid = y_hat - y
resid
# Out:
# 0        0.225385
# 1        0.046887
# 2        0.774090
# 3       -0.353794
# 4       -0.114985
#            ...
# 21590   -0.302834
# 21591   -0.263690
# 21592    0.203842
# 21593   -0.024386
# 21595   -0.118594
# Name: price, Length: 21281, dtype: float64

# %%
# get intercept and coef for training model
intercept = np.exp(train_model.intercept_)
print('The intercept for model is {:.7}'.format(intercept))


#loop through dict to print
for cf in zip(X_train.columns, np.exp(train_model.coef_)):
    print('The coefficient for {} is {:.4}'.format(cf[0], cf[1]))
# Out:
# The intercept for model is 84843.79
# The coefficient for distance_seattle is 1.014
# The coefficient for grade_7 is 1.228
# The coefficient for grade_10 is 2.125
# The coefficient for grade_11 is 2.354
# The coefficient for grade_9 is 1.85
# The coefficient for grade_12 is 2.66
# The coefficient for sqm_living is 1.002
# The coefficient for grade_8 is 1.525
# The coefficient for age is 1.004
# The coefficient for sqm_living15 is 1.001
# The coefficient for condition_5 is 1.278
# The coefficient for grade_13 is 3.141
# The coefficient for condition_4 is 1.202
# The coefficient for bathrooms_4.0 is 1.247
# The coefficient for bathrooms_3.0 is 1.18
# The coefficient for bathrooms_2.0 is 1.095
# The coefficient for bed_2 is 1.07
# The coefficient for bathrooms_5.0 is 1.426
# The coefficient for condition_3 is 1.158
# The coefficient for bed_3 is 1.019
# The coefficient for bathrooms_6.0 is 1.161
# The coefficient for bed_7 is 0.8747
# The coefficient for bed_6 is 0.935

# %%
# get intercept and coef for training model
print('The intercept for model is {:.4}'.format(train_model.intercept_))


#loop through dict to print
for cf in zip(X_train.columns,(train_model.coef_)):
    print('The coefficient for {} is {:.4}'.format(cf[0], cf[1]))
    print('With other variables remaining constant, for every 1 unit  change in {}, there is a change in log of y for X by {:.2} units ' .format(cf[0], cf[1]))
# Out:
# The intercept for model is 11.35
# The coefficient for distance_seattle is 0.01369
# With other variables remaining constant, for every 1 unit  change in distance_seattle, there is a change in log of y for X by 0.014 units
# The coefficient for grade_7 is 0.2052
# With other variables remaining constant, for every 1 unit  change in grade_7, there is a change in log of y for X by 0.21 units
# The coefficient for grade_10 is 0.7536
# With other variables remaining constant, for every 1 unit  change in grade_10, there is a change in log of y for X by 0.75 units
# The coefficient for grade_11 is 0.8559
# With other variables remaining constant, for every 1 unit  change in grade_11, there is a change in log of y for X by 0.86 units
# The coefficient for grade_9 is 0.615
# With other variables remaining constant, for every 1 unit  change in grade_9, there is a change in log of y for X by 0.61 units
# The coefficient for grade_12 is 0.9783
# With other variables remaining constant, for every 1 unit  change in grade_12, there is a change in log of y for X by 0.98 units
# The coefficient for sqm_living is 0.001865
# With other variables remaining constant, for every 1 unit  change in sqm_living, there is a change in log of y for X by 0.0019 units
# The coefficient for grade_8 is 0.422
# With other variables remaining constant, for every 1 unit  change in grade_8, there is a change in log of y for X by 0.42 units
# The coefficient for age is 0.00416
# With other variables remaining constant, for every 1 unit  change in age, there is a change in log of y for X by 0.0042 units
# The coefficient for sqm_living15 is 0.001038
# With other variables remaining constant, for every 1 unit  change in sqm_living15, there is a change in log of y for X by 0.001 units
# The coefficient for condition_5 is 0.2456
# With other variables remaining constant, for every 1 unit  change in condition_5, there is a change in log of y for X by 0.25 units
# The coefficient for grade_13 is 1.144
# With other variables remaining constant, for every 1 unit  change in grade_13, there is a change in log of y for X by 1.1 units
# The coefficient for condition_4 is 0.1837
# With other variables remaining constant, for every 1 unit  change in condition_4, there is a change in log of y for X by 0.18 units
# The coefficient for bathrooms_4.0 is 0.2209
# With other variables remaining constant, for every 1 unit  change in bathrooms_4.0, there is a change in log of y for X by 0.22 units
# The coefficient for bathrooms_3.0 is 0.1652
# With other variables remaining constant, for every 1 unit  change in bathrooms_3.0, there is a change in log of y for X by 0.17 units
# The coefficient for bathrooms_2.0 is 0.09069
# With other variables remaining constant, for every 1 unit  change in bathrooms_2.0, there is a change in log of y for X by 0.091 units
# The coefficient for bed_2 is 0.06783
# With other variables remaining constant, for every 1 unit  change in bed_2, there is a change in log of y for X by 0.068 units
# The coefficient for bathrooms_5.0 is 0.3546
# With other variables remaining constant, for every 1 unit  change in bathrooms_5.0, there is a change in log of y for X by 0.35 units
# The coefficient for condition_3 is 0.1464
# With other variables remaining constant, for every 1 unit  change in condition_3, there is a change in log of y for X by 0.15 units
# The coefficient for bed_3 is 0.0185
# With other variables remaining constant, for every 1 unit  change in bed_3, there is a change in log of y for X by 0.018 units
# The coefficient for bathrooms_6.0 is 0.1489
# With other variables remaining constant, for every 1 unit  change in bathrooms_6.0, there is a change in log of y for X by 0.15 units
# The coefficient for bed_7 is -0.1339
# With other variables remaining constant, for every 1 unit  change in bed_7, there is a change in log of y for X by -0.13 units
# The coefficient for bed_6 is -0.06724
# With other variables remaining constant, for every 1 unit  change in bed_6, there is a change in log of y for X by -0.067 units

# %%
final_df = pd.concat([X_sw, y,], axis=1)

# %%
import pickle

#pickle model
pickle.dump(train_model, open('final_king_county_lm_pickle.pkl','wb'))

# %% [markdown]
# # Conclusion

# %% [markdown]
# the data used for regression models is king county washington housing dataset, provided by flatiron school, original available through https://data.kingcounty.gov/
# additional versions of dataset available through kaggle.

# %% [markdown]
# reject null hypothesis.
# fail to reject alternative hypothesis.
# the features of a house display a correlation with the price/value of a house
# pvalues do not exceed 0.5
# model R2 = 0.732
# mean residual = -1.0649293058159106e-14 which indicates target is predicted as higher value than the actual value

# %% [markdown]
# ## Feature Engineering and Feature Selection

# %% [markdown]
# 1. distance from Seattle:
# attributes used to create feature:
# lat, long
# additional data required, obtained lat, long for city of Seattle
# 2. age of house:
# attributes used to create feature:
# yr_built, date
# 3. square meter living area:
# attributes used to create feature:
# sqft_living, sqft_living15
# feature selection from original dataset:
# bedrooms, bathrooms, grade, condition
# (sqft_living, sqft_living15, yr_built, date, lat, long)

# %% [markdown]
# Dummy variables used for categorical data variables:
# bedrooms, bathrooms, grade, condition

# %% [markdown]
# # Future Assessments

# %% [markdown]
# Assess possible standard scaler use on continuous data of same unit of measurement. assess other continuous data to determine scaling and normalizing possibilties to improve model accuracy.
# Assess polynomial regression for variables.
# Assess need for weighted variables with more influence on price
